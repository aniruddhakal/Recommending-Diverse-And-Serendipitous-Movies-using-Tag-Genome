# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_base_dir = '../../../datasets/Movielens/'
data_dir2 = data_base_dir + 'Movielens Latest/ml-latest/'
data_dir = data_base_dir + 'ml-20m/'

genome_scores = data_dir + 'genome-scores.csv'
genome_tags = data_dir + 'genome-tags.csv'
movies = data_dir + 'movies.csv'
ratings = data_dir + 'ratings.csv'
tags = data_dir + 'tags.csv'

# %%
# movies_df = pd.read_csv(movies)
# movies_df
genome_scores_df = pd.read_csv(genome_scores)
genome_score_movies = genome_scores_df['movieId'].unique()

ratings_df = pd.read_csv(ratings, usecols=range(3), dtype={'userId':np.int64, 'movieId':np.int64, 'rating':np.float64}, low_memory=False)
ratings_df = ratings_df[ratings_df['movieId'].isin(genome_score_movies)]
ratings_df
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# 5              1      112     3.5
# 6              1      151     4.0
# 7              1      223     4.0
# 8              1      253     4.0
# 9              1      260     4.0
# 10             1      293     4.0
# 11             1      296     4.0
# 12             1      318     4.0
# 13             1      337     3.5
# 14             1      367     3.5
# 15             1      541     4.0
# 16             1      589     3.5
# 17             1      593     3.5
# 18             1      653     3.0
# 19             1      919     3.5
# 20             1      924     3.5
# 21             1     1009     3.5
# 22             1     1036     4.0
# 23             1     1079     4.0
# 24             1     1080     3.5
# 25             1     1089     3.5
# 26             1     1090     4.0
# 27             1     1097     4.0
# 28             1     1136     3.5
# 29             1     1193     3.5
# ...          ...      ...     ...
# 20000232  138493    50601     3.5
# 20000233  138493    50872     3.5
# 20000234  138493    51086     3.5
# 20000235  138493    51662     4.5
# 20000236  138493    51884     4.5
# 20000237  138493    52579     4.0
# 20000238  138493    52975     4.0
# 20000239  138493    53123     4.0
# 20000240  138493    53125     3.0
# 20000241  138493    53322     4.0
# 20000242  138493    53464     4.0
# 20000243  138493    53996     4.5
# 20000244  138493    55269     5.0
# 20000245  138493    55814     5.0
# 20000246  138493    56757     3.0
# 20000247  138493    56801     3.0
# 20000248  138493    58879     4.5
# 20000249  138493    59315     4.0
# 20000250  138493    59725     3.0
# 20000251  138493    59784     5.0
# 20000252  138493    60069     4.0
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [19800443 rows x 3 columns]

# %%
# genome_scores_df = genome_scores_df.pivot(index='movieId', columns='tagId', values='relevance')
# file_name = 'threshold_0.4_float_movie_genomes_bz2'
file_name = 'movies_lemmatized_threshold_0.25_float_movie_genomes_bz2'
genome_scores_df = pd.read_pickle(data_dir + '/output/' + file_name, compression='bz2')
genome_scores_df
# Out:
#              007    1920s    1930s    1950s    1960s    1970s    1980s  \
# movieId
# 1        0.00000  0.09675  0.14675  0.21700  0.06700  0.26275  0.26200
# 2        0.08350  0.04800  0.11025  0.07250  0.04775  0.10975  0.09925
# 3        0.09825  0.07700  0.00000  0.06850  0.05600  0.18500  0.04925
# 4        0.07675  0.00000  0.06825  0.04050  0.02325  0.08700  0.05125
# 5        0.09475  0.00000  0.07525  0.12525  0.02850  0.08500  0.00000
# 6        0.02825  0.04550  0.09575  0.05500  0.04400  0.24200  0.12850
# 7        0.09850  0.08275  0.11450  0.15625  0.05025  0.11175  0.03950
# 8        0.06625  0.00000  0.00000  0.03650  0.00000  0.07325  0.00000
# 9        0.07550  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 10       1.99950  0.00000  0.06675  0.05450  0.04550  0.12950  0.08550
# 11       0.09200  0.06250  0.11050  0.08075  0.03800  0.18950  0.11000
# 12       0.07675  0.04800  0.28500  0.00000  0.00000  0.10350  0.00000
# 13       0.06800  0.04750  0.00000  0.04875  0.00000  0.00000  0.00000
# 14       0.00000  0.16775  0.14625  0.11750  0.31175  0.24225  0.16150
# 15       0.09750  0.00000  0.07700  0.05500  0.00000  0.00000  0.04275
# 16       0.02825  0.13325  0.16425  0.07800  0.09225  0.63400  0.21075
# 17       0.00000  0.17075  0.24750  0.11175  0.09500  0.11100  0.07400
# 18       0.07000  0.06400  0.06300  0.00000  0.02750  0.10050  0.03875
# 19       0.09700  0.05675  0.06850  0.08000  0.00000  0.07075  0.00000
# 20       0.10850  0.00000  0.07175  0.00000  0.00000  0.00000  0.00000
# 21       0.06550  0.06025  0.18250  0.10075  0.03150  0.11925  0.05125
# 22       0.02975  0.00000  0.15050  0.04875  0.02600  0.08550  0.05075
# 23       0.15175  0.00000  0.00000  0.00000  0.00000  0.00000  0.06825
# 24       0.06825  0.00000  0.00000  0.06050  0.04725  0.10775  0.04850
# 25       0.02700  0.05100  0.00000  0.09425  0.02025  0.12225  0.11050
# 26       0.00000  0.19825  0.31400  0.05225  0.03775  0.16675  0.06000
# 27       0.05650  0.00000  0.06525  0.11400  0.18000  0.57475  0.04950
# 28       0.00000  0.21025  0.21175  0.06650  0.03925  0.27100  0.05325
# 29       0.00000  0.28450  0.15525  0.08450  0.04000  0.11675  0.06675
# 30       0.06200  0.24750  0.77875  0.09825  0.05225  0.11550  0.05925
# ...          ...      ...      ...      ...      ...      ...      ...
# 127323   0.10150  0.00000  0.09725  0.03525  0.00000  0.08775  0.03525
# 128488   0.06250  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 128520   0.00000  0.04350  0.00000  0.00000  0.00000  0.00000  0.00000
# 128542   0.00000  0.04400  0.00000  0.00000  0.00000  0.00000  0.00000
# 128604   0.05625  0.04475  0.00000  0.00000  0.00000  0.07125  0.00000
# 128671   0.00000  0.12175  0.08250  0.11400  0.02525  0.12675  0.17600
# 128832   0.05250  0.03950  0.13275  0.06825  0.02425  0.11250  0.04000
# 128975   0.07600  0.00000  0.00000  0.03625  0.03425  0.07275  0.18200
# 129354   0.06400  0.03950  0.00000  0.03525  0.04475  0.00000  0.00000
# 129370   0.11800  0.03800  0.00000  0.04725  0.02975  0.00000  0.00000
# 129428   0.07950  0.05775  0.14650  0.13175  0.08925  0.18700  0.00000
# 129657   0.08400  0.04400  0.10900  0.00000  0.00000  0.00000  0.00000
# 129659   0.11775  0.15000  0.14600  0.09300  0.03825  0.28025  0.53050
# 129707   0.00000  0.00000  0.00000  0.00000  0.02175  0.00000  0.00000
# 129737   0.08075  0.05100  0.07850  0.00000  0.00000  0.00000  0.03600
# 129779   0.09025  0.06200  0.29600  0.07625  0.13300  0.35425  0.11775
# 129781   0.00000  0.00000  0.00000  0.08325  0.04625  0.12900  0.00000
# 129937   0.11950  0.05250  0.07175  0.00000  0.00000  0.00000  0.00000
# 130052   0.13650  0.05350  0.08125  0.05850  0.02625  0.08275  0.19575
# 130073   0.06100  0.11425  0.10600  0.23200  0.00000  0.00000  0.00000
# 130075   0.06800  0.07475  0.06800  0.00000  0.00000  0.00000  0.00000
# 130087   0.11625  0.03725  0.00000  0.04000  0.00000  0.07500  0.04325
# 130490   0.02700  0.00000  0.00000  0.05375  0.00000  0.00000  0.00000
# 130496   0.06275  0.00000  0.06400  0.00000  0.00000  0.11475  0.24425
# 130520   0.05875  0.04425  0.00000  0.00000  0.00000  0.00000  0.00000
# 130578   0.19425  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 130840   0.03025  0.09375  0.00000  0.06025  0.02100  0.12900  0.11275
# 131013   0.07375  0.05600  0.00000  0.00000  0.00000  0.00000  0.00000
# 131168   0.16350  0.14875  0.27750  0.16250  0.04125  0.25475  0.06900
# 131170   0.13950  0.00000  0.15700  0.09350  0.08550  0.34700  0.14175
#
#               3d     70mm      80s  ...    witch    witty  wizards    women  \
# movieId                             ...
# 1        0.57700  0.11625  0.18800  ...  0.17925  0.77675  0.14500  0.00000
# 2        0.06775  0.08900  0.22575  ...  0.65475  0.18000  0.18725  0.14750
# 3        0.02225  0.07100  0.09050  ...  0.05700  0.19950  0.02825  0.50150
# 4        0.00000  0.03325  0.11750  ...  0.05275  0.00000  0.02825  1.06050
# 5        0.03125  0.06150  0.07175  ...  0.08150  0.12000  0.02925  0.56125
# 6        0.00000  0.04400  0.08000  ...  0.00000  0.40750  0.03375  0.07375
# 7        0.02250  0.08800  0.00000  ...  0.09925  0.28225  0.02975  0.52525
# 8        0.03025  0.02125  0.08000  ...  0.16100  0.00000  0.02825  0.37825
# 9        0.02225  0.02875  0.09950  ...  0.05400  0.00000  0.00000  0.14850
# 10       0.00000  0.07225  0.23225  ...  0.05400  0.26050  0.04150  0.19075
# 11       0.00000  0.06050  0.08150  ...  0.13800  0.42075  0.02975  0.55900
# 12       0.00000  0.03700  0.07000  ...  0.18700  0.11750  0.03200  0.26675
# 13       0.10675  0.03575  0.07475  ...  0.12175  0.14525  0.02750  0.17325
# 14       0.02300  0.02650  0.07675  ...  0.09925  0.22350  0.03150  0.20875
# 15       0.03900  0.03900  0.14400  ...  0.07800  0.17400  0.02800  0.30300
# 16       0.00000  0.05275  0.13600  ...  0.03850  0.41850  0.02825  0.06375
# 17       0.00000  0.00000  0.00000  ...  0.21775  0.68000  0.03075  0.52650
# 18       0.00000  0.07300  0.07725  ...  1.00600  0.24900  0.03650  0.08700
# 19       0.02575  0.02575  0.09050  ...  0.01800  0.12950  0.03500  0.07425
# 20       0.02575  0.02175  0.18575  ...  0.05250  0.00000  0.00000  0.32175
# 21       0.02375  0.02300  0.10600  ...  0.04425  0.69725  0.00000  0.12075
# 22       0.02600  0.05050  0.08350  ...  0.06300  0.13325  0.00000  0.62075
# 23       0.00000  0.04850  0.22050  ...  0.00000  0.00000  0.00000  0.26675
# 24       0.02650  0.03525  0.10350  ...  0.06525  0.00000  0.02575  0.23750
# 25       0.00000  0.00000  0.07400  ...  0.05425  0.38600  0.02625  0.18925
# 26       0.00000  0.04925  0.06875  ...  0.26250  0.51325  0.03950  0.14950
# 27       0.00000  0.02225  0.18850  ...  0.17475  0.00000  0.02925  1.03350
# 28       0.00000  0.02300  0.00000  ...  0.20950  0.55975  0.06800  0.33925
# 29       0.10900  0.04600  0.00000  ...  0.47450  0.34300  0.16425  0.22175
# 30       0.03575  0.02200  0.00000  ...  0.00000  0.17625  0.00000  0.27050
# ...          ...      ...      ...  ...      ...      ...      ...      ...
# 127323   0.02500  0.00000  0.13900  ...  0.02275  0.00000  0.02800  0.39450
# 128488   0.02175  0.00000  0.00000  ...  0.00000  0.00000  0.00000  0.10950
# 128520   0.02650  0.00000  0.00000  ...  0.00000  0.00000  0.00000  0.12450
# 128542   0.02250  0.00000  0.07975  ...  0.56550  0.13375  0.03925  0.19800
# 128604   0.02625  0.00000  0.07575  ...  0.00000  0.00000  0.00000  0.35250
# 128671   0.00000  0.04200  0.00000  ...  0.12350  0.12125  0.00000  0.63975
# 128832   0.02675  0.16750  0.07250  ...  0.05400  0.24175  0.04200  0.32875
# 128975   0.03525  0.03725  0.23025  ...  0.01550  0.12950  0.04825  0.33150
# 129354   0.03225  0.00000  0.00000  ...  0.08375  0.29800  0.02975  0.33275
# 129370   0.54450  0.03350  0.10650  ...  0.02425  0.22575  0.22100  0.05975
# 129428   0.00000  0.03975  0.00000  ...  0.05425  0.28150  0.00000  0.35450
# 129657   0.02500  0.02200  0.07200  ...  0.04150  0.00000  0.04125  0.67650
# 129659   0.00000  0.05225  0.21975  ...  0.35150  0.18450  0.04350  0.28050
# 129707   0.03075  0.00000  0.12500  ...  0.12150  0.00000  0.02850  0.19075
# 129737   0.03300  0.00000  0.08500  ...  0.05775  0.13550  0.00000  0.22375
# 129779   0.00000  0.03425  0.09450  ...  0.09475  0.33050  0.14350  0.20725
# 129781   0.00000  0.00000  0.00000  ...  0.03675  0.00000  0.03400  0.00000
# 129937   0.02625  0.02600  0.00000  ...  0.10000  0.00000  0.02650  0.29875
# 130052   0.02975  0.00000  0.18425  ...  0.30275  0.00000  0.00000  0.00000
# 130073   0.06750  0.02725  0.08725  ...  0.66875  0.16275  0.14150  0.51975
# 130075   0.13825  0.00000  0.00000  ...  0.24075  0.19375  0.04475  0.28875
# 130087   0.05175  0.05200  0.13825  ...  0.08825  0.00000  0.06100  0.16500
# 130490   0.19000  0.00000  0.00000  ...  0.10700  0.00000  0.03675  0.61000
# 130496   0.02850  0.04950  0.63375  ...  0.07275  0.18700  0.03150  0.27825
# 130520   0.51275  0.00000  0.00000  ...  0.06775  0.17800  0.02925  0.19550
# 130578   0.02750  0.00000  0.13775  ...  0.04825  0.00000  0.00000  0.15075
# 130840   0.00000  0.00000  0.12350  ...  0.37950  0.18100  0.00000  0.33125
# 131013   0.02750  0.00000  0.00000  ...  0.05300  0.11325  0.03075  0.21400
# 131168   0.00000  0.00000  0.00000  ...  0.07400  0.19700  0.04075  0.50125
# 131170   0.11025  0.00000  0.15425  ...  0.06925  0.15375  0.02700  0.39375
#
#          workplace    write  writers    wuxia     wwii   zombie
# movieId
# 1          0.10250  0.46825  0.00000  0.00000  0.03625  0.10075
# 2          0.00000  0.00000  0.00000  0.00000  0.01475  0.10900
# 3          0.07325  0.11500  0.00000  0.00000  0.01950  0.11550
# 4          0.28825  0.13625  0.18525  0.00000  0.01525  0.00000
# 5          0.07450  0.00000  0.00000  0.00000  0.01675  0.12575
# 6          0.18800  0.57725  0.29975  0.03525  0.01950  0.01900
# 7          0.06950  0.04875  0.00000  0.00000  0.01050  0.12775
# 8          0.00000  0.00000  0.20975  0.00000  0.01125  0.07000
# 9          0.00000  0.00000  0.00000  0.00000  0.00000  0.07275
# 10         0.07225  0.07825  0.18400  0.00000  0.01775  0.09125
# 11         0.00000  0.17925  0.18600  0.00000  0.03900  0.01625
# 12         0.05825  0.06825  0.16775  0.02600  0.00000  0.13425
# 13         0.00000  0.00000  0.00000  0.00000  0.01050  0.09450
# 14         0.12075  0.24400  0.16550  0.02525  0.03300  0.01700
# 15         0.00000  0.00000  0.17300  0.00000  0.00000  0.13975
# 16         0.11150  0.67875  0.17850  0.02925  0.01525  0.14350
# 17         0.00000  0.37450  0.28100  0.02050  0.02675  0.01800
# 18         0.30575  0.44200  0.31125  0.04275  0.01175  0.10725
# 19         0.11700  0.13575  0.00000  0.00000  0.01000  0.08225
# 20         0.00000  0.11850  0.00000  0.00000  0.01025  0.08250
# 21         0.00000  0.52700  0.39825  0.02550  0.01175  0.08850
# 22         0.21675  0.12050  0.33250  0.02400  0.01450  0.00000
# 23         0.08225  0.10925  0.00000  0.00000  0.00000  0.13450
# 24         0.00000  0.04250  0.26950  0.02325  0.02125  0.11900
# 25         0.13825  0.74175  0.44950  0.02325  0.01425  0.09350
# 26         0.09225  0.15550  0.00000  0.00000  0.01750  0.09975
# 27         0.06700  0.00000  0.00000  0.00000  0.01050  0.01675
# 28         0.00000  0.21175  0.22650  0.02675  0.01225  0.09125
# 29         0.16575  0.35375  0.17175  0.12850  0.02675  0.01700
# 30         0.17325  0.09550  0.00000  0.15800  0.01725  0.09000
# ...            ...      ...      ...      ...      ...      ...
# 127323     0.00000  0.08000  0.41700  0.00000  0.01150  0.10350
# 128488     0.18075  0.06650  0.00000  0.02700  0.00000  0.06925
# 128520     0.06575  0.04875  0.00000  0.00000  0.00000  0.00000
# 128542     0.00000  0.05525  0.19775  0.00000  0.00000  1.90150
# 128604     0.00000  0.08200  0.37800  0.03875  0.00000  0.10425
# 128671     0.06425  0.10200  0.26800  0.03075  0.01450  0.00000
# 128832     0.00000  0.23325  0.51700  0.00000  0.01150  0.13425
# 128975     0.11825  0.16350  0.51600  0.02825  0.00975  0.16025
# 129354     0.00000  0.15175  0.22450  0.00000  0.00000  0.13900
# 129370     0.07000  0.19475  0.26450  0.03875  0.01275  0.00000
# 129428     0.00000  0.18650  0.00000  0.00000  0.02600  0.06975
# 129657     0.22300  0.22500  0.22450  0.08025  0.01000  0.09850
# 129659     0.14425  0.13075  0.17675  0.00000  0.03500  0.12825
# 129707     0.00000  0.00000  0.38025  0.00000  0.00000  0.52800
# 129737     0.55425  0.29075  0.32075  0.00000  0.02150  0.10650
# 129779     0.33600  0.90225  0.66500  0.10875  0.02200  0.01825
# 129781     0.00000  0.06575  0.37175  0.00000  0.00000  0.06925
# 129937     0.07975  0.06475  0.00000  0.00000  0.00000  0.07300
# 130052     0.16350  0.00000  0.17375  0.00000  0.01300  0.53600
# 130073     0.00000  0.04250  0.00000  0.00000  0.01150  0.11400
# 130075     0.05875  0.16875  0.36925  0.00000  0.01425  0.11275
# 130087     0.00000  0.15050  0.26100  0.02325  0.01375  0.00000
# 130490     0.00000  0.12075  0.25950  0.00000  0.00000  0.14675
# 130496     0.00000  0.13600  0.28125  0.05100  0.00000  0.10725
# 130520     0.00000  0.13000  0.26350  0.00000  0.00000  0.00000
# 130578     0.11175  0.00000  0.21000  0.04225  0.00000  0.07575
# 130840     0.08275  0.49375  0.47675  0.06200  0.00000  0.40375
# 131013     0.23650  0.10750  0.20000  0.02500  0.00950  0.09175
# 131168     0.00000  0.41175  0.18175  0.04800  0.51925  0.01725
# 131170     0.00000  0.79925  0.64375  0.00000  0.01575  0.13625
#
# [10380 rows x 702 columns]

# %%
# genome_scores_df[1].value_counts()
genome_scores_df.describe()
# (genome_scores_df == 0.02500).astype(int)
# Out:
#                 007         1920s         1930s         1950s         1960s  \
# count  10380.000000  10380.000000  10380.000000  10380.000000  10380.000000
# mean       0.080619      0.078336      0.125233      0.084990      0.057757
# std        0.128386      0.096504      0.156582      0.102802      0.087724
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.029250      0.037250      0.062000      0.034750      0.019750
# 50%        0.071250      0.051250      0.087000      0.059125      0.032500
# 75%        0.096250      0.097750      0.143000      0.106750      0.067000
# max        1.999750      0.928750      0.981500      0.931500      0.949750
#
#               1970s         1980s            3d          70mm           80s  \
# count  10380.000000  10380.000000  10380.000000  10380.000000  10380.000000
# mean       0.146826      0.105909      0.041392      0.062106      0.146060
# std        0.141258      0.144074      0.085555      0.120026      0.164661
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.052875      0.033750      0.021750      0.019500      0.067750
# 50%        0.115750      0.059500      0.026250      0.031000      0.103500
# 75%        0.208000      0.127750      0.035000      0.061000      0.180562
# max        0.874500      0.993000      0.929000      0.998750      0.979500
#
#        ...         witch         witty       wizards         women  \
# count  ...  10380.000000  10380.000000  10380.000000  10380.000000
# mean   ...      0.111944      0.218007      0.045810      0.276354
# std    ...      0.186434      0.191299      0.088314      0.205704
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.034250      0.084938      0.024750      0.137000
# 50%    ...      0.066250      0.180500      0.031750      0.243625
# 75%    ...      0.114750      0.323500      0.043750      0.348750
# max    ...      1.990750      0.938000      0.996500      1.687250
#
#           workplace         write       writers         wuxia          wwii  \
# count  10380.000000  10380.000000  10380.000000  10380.000000  10380.000000
# mean       0.108182      0.210465      0.217358      0.037500      0.043425
# std        0.121433      0.180913      0.163749      0.074076      0.137722
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.057750      0.080500      0.162500      0.020250      0.009250
# 50%        0.080750      0.166250      0.219750      0.027000      0.013000
# 75%        0.136000      0.284750      0.302250      0.038062      0.021250
# max        0.996750      1.505500      0.980000      0.999750      0.997500
#
#              zombie
# count  10380.000000
# mean       0.123272
# std        0.183958
# min        0.000000
# 25%        0.069750
# 50%        0.100000
# 75%        0.128000
# max        1.989000
#
# [8 rows x 702 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

n_clusters = [2, 3, 4, 5, 6, 8, 10, 12, 15, 17, 20, 25]
metrics = ['cosine', 'euclidean', 'cityblock', 'braycurtis', 'canberra', 'chebyshev', 'correlation', 'dice', 'hamming', 'jaccard', 'kulsinski', 'mahalanobis', 'minkowski', 'rogerstanimoto', 'russellrao', 'seuclidean', 'sokalmichener', 'sokalsneath', 'sqeuclidean', 'yule']
# cosine_ eps = [0.04, 0.07, 0.1, 0.11, 0.13, 0.15, 0.17, 0.2, 0.25, 0.27, 0.29, 0.3, 0.35]
eps = [0.04, 0.07, 0.1, 0.11, 0.13, 0.15, 0.17, 0.2, 0.25, 0.27, 0.29, 0.3, 0.35]

score_history = []
# for e in eps:
for cluster_size in range(2, 40, 5):
# with cluster_size as 1100:
# cluster_size = 700
#     for metric in metrics:
    result = KMeans(n_clusters=cluster_size, random_state=171450, n_jobs=-1).fit_predict(genome_scores_df.values)
#     print("e", e)
    
#     result = DBSCAN(eps=e, metric='cosine').fit_predict(genome_scores_df.values)

    # linkage : {“ward”, “complete”, “average”, “single”}
#     result = AgglomerativeClustering(n_clusters=cluster_size, affinity='euclidean', linkage='ward').fit_predict(genome_scores_df.values)

    score = silhouette_score(genome_scores_df.values, result, metric='cosine')
    score_history.append(score)
    print("N Clusters: ", cluster_size, ", Silhouette Score: ", score, "Result Unique Size", np.unique(result).size)
#     print("EPS: ", e, ", Silhouette Score: ", score, "Result Unique Size", np.unique(result).size)
#     print(", Silhouette Score: ", score, ", Metric: ", metric)
# result.tolist()
# result = kmeans.predict(genome_scores_df.values)
# result
# silhouette_score(genome_scores_df.values)
plt.xlabel('cluster size')
plt.ylabel('silhouette score')
plt.plot(score_history)
# Out:
# N Clusters:  2 , Silhouette Score:  0.08921476382897454 Result Unique Size 2
# N Clusters:  7 , Silhouette Score:  -0.0049081876514099594 Result Unique Size 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-da9818c6b2d5> in <module>
#      15 # cluster_size = 700
#      16 #     for metric in metrics:
# ---> 17     result = KMeans(n_clusters=cluster_size, random_state=171450, n_jobs=-1).fit_predict(genome_scores_df.values)
#      18 #     print("e", e)
#      19
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/k_means_.py in fit_predict(self, X, y, sample_weight)
#     995             Index of the cluster each sample belongs to.
#     996         """
# --> 997         return self.fit(X, sample_weight=sample_weight).labels_
#     998
#     999     def fit_transform(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/k_means_.py in fit(self, X, y, sample_weight)
#     969                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     970                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 971                 return_n_iter=True)
#     972         return self
#     973
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     396                                    # Change seed to ensure variety
#     397                                    random_state=seed)
# --> 398             for seed in seeds)
#     399         # Get results with the lowest inertia
#     400         labels, inertia, centers, n_iters = zip(*results)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# /usr/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

n_clusters = [2, 3, 4, 5, 6, 8, 10, 12, 15, 17, 20, 25]
metrics = ['cosine', 'euclidean', 'cityblock', 'braycurtis', 'canberra', 'chebyshev', 'correlation', 'dice', 'hamming', 'jaccard', 'kulsinski', 'mahalanobis', 'minkowski', 'rogerstanimoto', 'russellrao', 'seuclidean', 'sokalmichener', 'sokalsneath', 'sqeuclidean', 'yule']
# cosine_ eps = [0.04, 0.07, 0.1, 0.11, 0.13, 0.15, 0.17, 0.2, 0.25, 0.27, 0.29, 0.3, 0.35]
# eps = [0.04, 0.07, 0.1, 0.11, 0.13, 0.15, 0.17, 0.2, 0.25, 0.27, 0.29, 0.3, 0.35]

score_history = []
for e in eps[1:]:
# for e in range()
# for cluster_size in range(150,900, 30):
# with cluster_size as 1100:
# cluster_size = 700
#     for metric in metrics:
#     result = KMeans(n_clusters=cluster_size, random_state=171450, n_jobs=-1).fit_predict(genome_scores_df.values)
#     print("e", e)
    
    result = DBSCAN(eps=e, metric='cosine').fit_predict(genome_scores_df.values)

    # linkage : {“ward”, “complete”, “average”, “single”}
#     result = AgglomerativeClustering(n_clusters=cluster_size, affinity='euclidean', linkage='ward').fit_predict(genome_scores_df.values)

    score = silhouette_score(genome_scores_df.values, result, metric='cosine')
    score_history.append(score)
#     print("N Clusters: ", cluster_size, ", Silhouette Score: ", score, "Result Unique Size", np.unique(result).size)
    print("EPS: ", e, ", Silhouette Score: ", score, "Result Unique Size", np.unique(result).size)
    
plt.xlabel('cluster size')
plt.ylabel('silhouette score')
plt.plot(score_history)
#     print(", Silhouette Score: ", score, ", Metric: ", metric)
# result.tolist()
# result = kmeans.predict(genome_scores_df.values)
# result
# silhouette_score(genome_scores_df.values)
# Out:
# EPS:  0.07 , Silhouette Score:  -0.38499585210998943 Result Unique Size 27
# EPS:  0.1 , Silhouette Score:  -0.04367360203699559 Result Unique Size 4
# EPS:  0.11 , Silhouette Score:  0.07886676528967634 Result Unique Size 4
# EPS:  0.13 , Silhouette Score:  0.1683949598646864 Result Unique Size 2
# EPS:  0.15 , Silhouette Score:  0.21025994762366423 Result Unique Size 2
# EPS:  0.17 , Silhouette Score:  0.23290663119831445 Result Unique Size 2
# EPS:  0.2 , Silhouette Score:  0.26313319807248003 Result Unique Size 2
# EPS:  0.25 , Silhouette Score:  0.31371341469592745 Result Unique Size 2
# EPS:  0.27 , Silhouette Score:  0.34856651418907136 Result Unique Size 2
# EPS:  0.29 , Silhouette Score:  0.3678868217558884 Result Unique Size 2
# EPS:  0.3 , Silhouette Score:  0.37629986850077096 Result Unique Size 2
# EPS:  0.35 , Silhouette Score:  0.4601573752620311 Result Unique Size 2

# %%
e = 0.39
result = DBSCAN(eps=e, metric='cosine').fit_predict(genome_scores_df.values)
score = silhouette_score(genome_scores_df.values, result, metric='cosine')
print(score)
result
# Out:
# 0.4931690739300477
# array([0, 0, 0, ..., 0, 0, 0])

# %%
np.unique(result)
# Out:
# array([-1,  0])

# %%
from sklearn.decomposition import PCA

# result = PCA(n_components=10).fit_transform(genome_scores_df.values)
result = PCA(n_components=400).fit(genome_scores_df.values)
result
# Out:
# PCA(copy=True, iterated_power='auto', n_components=400, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
result.explained_variance_.sum()
# Out:
# 35.915699210427

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering

# e = 0.095
eps = [0.04, 0.07, 0.1, 0.11, 0.13, 0.15, 0.17, 0.2, 0.25, 0.27, 0.29, 0.3, 0.35]
e = 0.105
# for e in eps:
metric = 'cosine'
# metrics = ['cosine', 'euclidean', 'cityblock', 'braycurtis', 'canberra', 'chebyshev', 'correlation', 'dice', 'hamming', 'jaccard', 'kulsinski', 'mahalanobis', 'minkowski', 'rogerstanimoto', 'russellrao', 'seuclidean', 'sokalmichener', 'sokalsneath', 'sqeuclidean', 'yule']
result = DBSCAN(eps=e, metric=metric).fit_predict(genome_scores_df.values)

# linkage : {“ward”, “complete”, “average”, “single”}

# result = AgglomerativeClustering(affinity='cosine', 'linkage='ward')
score = silhouette_score(genome_scores_df.values, result, metric='cosine')
print("EPS: ", e, ", Silhouette Score: ", score)

np.unique(result)


movie_clusters_df = pd.DataFrame(index=genome_scores_df.index.values)
movie_clusters_df['cluster'] = result
movie_clusters_df['dummy'] = 1

count_df = movie_clusters_df.groupby('cluster').count()
count_df['dummy'].tolist()
# Out:
# EPS:  0.105 , Silhouette Score:  0.06653719088413797
# [3050, 7325, 5]

# %%
# from __future__ import print_function

# from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, genome_scores_df.values.size + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(genome_scores_df.values)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(genome_scores_df.values, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(genome_scores_df.values, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.13071085073696848
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-79f06706b75d> in <module>
#      74     # 2nd Plot showing the actual clusters formed
#      75     colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
# ---> 76     ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
#      77                 c=colors, edgecolor='k')
#      78
#
# NameError: name 'X' is not defined

# %%
# ratings_df[ratings_df['userId'] == 33]
users_whole_count = ratings_df['userId'].unique().size

# %%
# user's watched movies:
user_id = 11
# type(ratings_matrix_df.loc[user_id, :][3]
# ratings_matrix_df.loc[user_id, :].notnull()
# ratings_matrix_df.index[ratings_matrix_df[user_id].notnull()]
ratings_df[ratings_df['userId'] == user_id]['movieId'].values
# Out:
# array([    1,    10,    19,    32,    39,    65,   110,   145,   150,
#          153,   158,   160,   165,   170,   172,   173,   185,   208,
#          231,   253,   256,   260,   286,   296,   316,   318,   344,
#          356,   364,   367,   377,   380,   384,   405,   410,   441,
#          442,   480,   500,   519,   527,   531,   541,   546,   551,
#          586,   587,   588,   589,   592,   593,   595,   597,   608,
#          610,   611,   616,   631,   648,   653,   671,   673,   736,
#          741,   761,   780,   784,   828,   858,   880,   968,  1028,
#         1029,  1032,  1036,  1046,  1064,  1073,  1077,  1093,  1097,
#         1136,  1168,  1169,  1196,  1197,  1198,  1200,  1210,  1213,
#         1214,  1215,  1225,  1240,  1253,  1255,  1270,  1274,  1291,
#         1320,  1321,  1339,  1367,  1387,  1391,  1432,  1527,  1544,
#         1580,  1584,  1591,  1653,  1676,  1688,  1690,  1721,  1748,
#         1862,  1876,  1882,  1917,  1961,  1977,  1982,  2004,  2011,
#         2012,  2018,  2023,  2028,  2042,  2105,  2107,  2123,  2124,
#         2134,  2140,  2143,  2153,  2232,  2240,  2291,  2294,  2313,
#         2355,  2378,  2396,  2420,  2428,  2455,  2571,  2572,  2600,
#         2628,  2641,  2642,  2683,  2688,  2706,  2716,  2717,  2720,
#         2722,  2761,  2762,  2793,  2810,  2827,  2840,  2858,  2916,
#         2959,  2985,  2990,  3000,  3033,  3054,  3083,  3113,  3114,
#         3159,  3213,  3247,  3269,  3300,  3396,  3438,  3525,  3527,
#         3535,  3578,  3697,  3702,  3703,  3704,  3745,  3752,  3753,
#         3793,  3826,  3863,  3864,  3892,  3897,  3969,  3980,  3988,
#         3991,  3994,  4006,  4015,  4052,  4054,  4105,  4133,  4226,
#         4232,  4235,  4246,  4262,  4299,  4306,  4340,  4343,  4366,
#         4370,  4388,  4446,  4492,  4533,  4571,  4638,  4643,  4718,
#         4792,  4850,  4868,  4878,  4887,  4896,  4973,  4974,  4993,
#         4995,  5046,  5151,  5152,  5171,  5219,  5220,  5225,  5266,
#         5283,  5299,  5323,  5349,  5377,  5378,  5400,  5444,  5445,
#         5459,  5463,  5502,  5618,  5669,  5782,  5816,  5882,  5903,
#         5952,  5971,  6016,  6094,  6250,  6264,  6281,  6283,  6287,
#         6291,  6294,  6333,  6365,  6377,  6378,  6383,  6502,  6503,
#         6534,  6537,  6539,  6541,  6548,  6586,  6624,  6659,  6711,
#         6731,  6795,  6863,  6874,  6934,  6953,  6979,  6996,  7022,
#         7099,  7153,  7163,  7173,  7254,  7293,  7345,  7361,  7439,
#         7444,  7458,  7481,  7541,  7845,  7846,  8169,  8361,  8368,
#         8371,  8578,  8622,  8636,  8640,  8641,  8644,  8800,  8810,
#         8861,  8865,  8870,  8907,  8965,  8972,  8973,  8977, 26462,
#        26509, 26887, 26913, 27311, 27338, 27368, 27441, 27608, 27660,
#        27728, 27793, 27865, 27904, 30707, 30793, 30812, 31184, 31429,
#        31553, 31555, 31658, 31660, 31878, 32031, 32213, 33085, 33166,
#        33493, 33585, 33660, 33679, 33794, 34048, 34150, 34319, 34334,
#        34338, 34542, 35836, 36401, 36509, 36931, 37380, 37386, 37830,
#        39446, 40339, 41566, 41569, 41571, 42718, 43419, 43556, 43928,
#        43932, 43936, 44189, 44191, 44225, 44731, 44828, 44849, 45361,
#        45499, 45722, 46530, 46578, 47124, 48304, 48394, 48516, 48738,
#        48774, 48943, 49205, 49278, 50162, 50442, 50872, 51412, 51662,
#        51666, 51698, 52281, 52287, 52328, 52722, 52885, 53000, 53125,
#        53464, 53953, 53996, 54001, 54278, 54771, 54995, 55232, 55282,
#        55999, 56003, 56145, 56174, 56251, 56757, 56801, 56949, 57223,
#        57368, 57640, 57949, 58025, 58293, 58559, 58652, 59014, 59315,
#        59418, 59615, 60037, 60040, 60069, 60161, 60514, 60516, 60684,
#        60760, 60832, 61248, 61465, 62265, 62956, 63859, 64034, 64497,
#        64508, 64614, 64997, 65037, 65514, 66171, 66297, 67197, 67295,
#        67799, 67867, 68263, 68319, 69526, 70305, 71282, 72641, 82095])

# %%
# len(user_movies_d[7])
# user_movie_tags_df = pd.DataFrame(index=user_movies_d[1], columns=range(1, 1129))

# collect tag genome scores for all movies that user X has watched

# user_id = 11
user_movie_tags_df = pd.DataFrame()
user_movies = ratings_df[ratings_df['userId'] == user_id]['movieId'].values
# print(len(user_movies_d[user_x]))
# user_movie_tags_df = genome_scores_df[genome_scores_df.index.isin(user_movies_d[user_x])]
user_movie_tags_df = genome_scores_df[genome_scores_df.index.isin(user_movies)]

user_movie_tags_df
# Out:
#              007    1920s    1930s    1950s    1960s    1970s    1980s  \
# movieId
# 1        0.00000  0.09675  0.14675  0.21700  0.06700  0.26275  0.26200
# 10       1.99950  0.00000  0.06675  0.05450  0.04550  0.12950  0.08550
# 19       0.09700  0.05675  0.06850  0.08000  0.00000  0.07075  0.00000
# 32       0.00000  0.13525  0.15775  0.14675  0.09400  0.12800  0.08800
# 39       0.06300  0.00000  0.07150  0.10225  0.02125  0.00000  0.12925
# 65       0.11100  0.04250  0.07725  0.05000  0.02175  0.07175  0.04700
# 110      0.06475  0.23900  0.26075  0.16900  0.18250  0.32175  0.24725
# 145      0.10525  0.00000  0.00000  0.00000  0.03275  0.08300  0.03725
# 150      0.08300  0.13700  0.15500  0.38375  0.19950  0.68600  0.19450
# 153      0.13375  0.04500  0.07300  0.04050  0.08200  0.07950  0.05475
# 158      0.09775  0.00000  0.07175  0.00000  0.04200  0.07725  0.06625
# 160      0.10625  0.00000  0.00000  0.03550  0.02700  0.07350  0.06550
# 165      0.08625  0.03850  0.00000  0.04575  0.02475  0.13875  0.08025
# 170      0.08575  0.00000  0.00000  0.04150  0.00000  0.08350  0.13200
# 172      0.08325  0.04300  0.06600  0.05850  0.00000  0.00000  0.10900
# 173      0.08775  0.04575  0.09275  0.06175  0.02000  0.08825  0.06725
# 185      0.10750  0.00000  0.00000  0.04525  0.02675  0.08750  0.04475
# 208      0.16475  0.00000  0.06600  0.05875  0.00000  0.07475  0.04950
# 231      0.09250  0.06725  0.10200  0.06525  0.00000  0.07900  0.03950
# 253      0.02800  0.07725  0.08125  0.05100  0.02975  0.14350  0.08625
# 256      0.10775  0.03750  0.07350  0.05875  0.02000  0.07300  0.05175
# 260      0.09600  0.18475  0.37050  0.39550  0.11925  0.41925  0.43025
# 286      0.13575  0.00000  0.06675  0.00000  0.00000  0.00000  0.04275
# 296      0.02725  0.04725  0.08250  0.05925  0.04675  0.28225  0.11450
# 316      0.10750  0.09400  0.00000  0.07825  0.02350  0.11150  0.06075
# 318      0.00000  0.14475  0.26675  0.56625  0.29650  0.32200  0.24250
# 344      0.09775  0.07025  0.08900  0.11200  0.00000  0.10125  0.04750
# 356      0.06650  0.10950  0.18650  0.71900  0.58550  0.36575  0.41775
# 364      0.06250  0.06800  0.09050  0.11975  0.11200  0.28600  0.16125
# 367      0.09600  0.12325  0.12300  0.10800  0.03050  0.11350  0.05850
# ...          ...      ...      ...      ...      ...      ...      ...
# 60514    0.06175  0.03975  0.08475  0.10950  0.00000  0.00000  0.00000
# 60516    0.08050  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 60684    0.02900  0.06850  0.17525  0.03925  0.02700  0.23650  0.43375
# 60760    0.02650  0.00000  0.00000  0.00000  0.00000  0.00000  0.04250
# 60832    0.07175  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 61248    0.09600  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 61465    0.11450  0.03975  0.09600  0.03825  0.02125  0.00000  0.03825
# 62265    0.08750  0.05100  0.00000  0.00000  0.00000  0.10000  0.00000
# 62956    0.07500  0.04025  0.00000  0.00000  0.00000  0.10225  0.04625
# 63859    0.06425  0.03900  0.07450  0.04900  0.00000  0.07775  0.00000
# 64034    0.02775  0.06200  0.31975  0.11675  0.09250  0.14350  0.08225
# 64497    0.07675  0.03725  0.00000  0.07125  0.00000  0.00000  0.00000
# 64508    0.10525  0.04175  0.00000  0.04500  0.00000  0.00000  0.07225
# 64614    0.06125  0.04700  0.14425  0.19075  0.11525  0.31800  0.20950
# 64997    0.08600  0.05725  0.08350  0.15725  0.00000  0.09550  0.05150
# 65037    0.12900  0.04300  0.06675  0.07625  0.02050  0.15700  0.04650
# 65514    0.05650  0.16100  0.78025  0.09800  0.03875  0.23450  0.16625
# 66171    0.02825  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 66297    0.09475  0.05225  0.08925  0.08450  0.02150  0.17300  0.13200
# 67197    0.07225  0.04100  0.07900  0.10800  0.02225  0.08800  0.00000
# 67295    0.12825  0.05275  0.07000  0.05250  0.02725  0.07625  0.00000
# 67799    0.06775  0.00000  0.00000  0.00000  0.02125  0.00000  0.00000
# 67867    0.17450  0.03850  0.07775  0.00000  0.00000  0.00000  0.04175
# 68263    0.06900  0.04550  0.08300  0.04125  0.02075  0.33275  0.06175
# 68319    0.07150  0.00000  0.00000  0.00000  0.02550  0.00000  0.00000
# 69526    0.10075  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 70305    0.05875  0.04600  0.07475  0.08225  0.02000  0.14450  0.00000
# 71282    0.00000  0.05375  0.10900  0.06975  0.04600  0.15325  0.06325
# 72641    0.06350  0.04325  0.15925  0.12125  0.06125  0.16775  0.05475
# 82095    0.06925  0.04250  0.09425  0.00000  0.00000  0.00000  0.00000
#
#               3d     70mm      80s  ...    witch    witty  wizards    women  \
# movieId                             ...
# 1        0.57700  0.11625  0.18800  ...  0.17925  0.77675  0.14500  0.00000
# 10       0.00000  0.07225  0.23225  ...  0.05400  0.26050  0.04150  0.19075
# 19       0.02575  0.02575  0.09050  ...  0.01800  0.12950  0.03500  0.07425
# 32       0.06225  0.04125  0.08850  ...  0.04125  0.39375  0.02575  0.00000
# 39       0.00000  0.00000  0.45275  ...  0.27600  0.42050  0.00000  0.41425
# 65       0.03000  0.04325  0.13350  ...  0.10075  0.13000  0.03825  0.20775
# 110      0.03450  0.19875  0.16550  ...  0.13800  0.39775  0.08075  0.21375
# 145      0.02450  0.06175  0.22000  ...  0.01325  0.11625  0.02625  0.35875
# 150      0.08675  0.19450  0.08450  ...  0.08650  0.21775  0.04075  0.00000
# 153      0.03250  0.03875  0.12600  ...  0.05725  0.16400  0.03650  0.22200
# 158      0.08850  0.11400  0.27225  ...  0.34900  0.25650  0.03700  0.23575
# 160      0.05250  0.05100  0.10400  ...  0.19925  0.00000  0.03925  0.21725
# 165      0.02375  0.11350  0.26725  ...  0.00000  0.18475  0.02525  0.22675
# 170      0.13550  0.05600  0.28775  ...  0.13225  0.00000  0.06275  0.26525
# 172      0.05800  0.02975  0.19950  ...  0.00000  0.00000  0.03175  0.20725
# 173      0.03850  0.07225  0.33125  ...  0.01675  0.00000  0.02900  0.21650
# 185      0.03125  0.07400  0.07650  ...  0.05050  0.00000  0.00000  0.19450
# 208      0.04800  0.13825  0.19525  ...  0.01525  0.00000  0.03850  0.00000
# 231      0.02675  0.03100  0.20400  ...  0.00000  0.17775  0.03200  0.00000
# 253      0.00000  0.02050  0.17700  ...  0.59025  0.18325  0.13975  0.25250
# 256      0.03475  0.06750  0.12425  ...  0.06725  0.17575  0.03500  0.54050
# 260      0.10475  0.76500  0.53050  ...  0.15650  0.47600  0.89175  0.09350
# 286      0.05025  0.04175  0.15075  ...  0.00000  0.00000  0.03325  0.42975
# 296      0.00000  0.04900  0.11450  ...  0.00000  0.71950  0.03825  0.16000
# 316      0.09725  0.14275  0.12775  ...  0.05650  0.00000  0.07450  0.08675
# 318      0.06475  0.10400  0.12275  ...  0.10225  0.49325  0.08900  0.00000
# 344      0.03125  0.03500  0.14250  ...  0.01425  0.17875  0.03450  0.06850
# 356      0.02825  0.10250  0.20175  ...  0.06100  0.36325  0.03575  0.00000
# 364      0.15125  0.40300  0.12350  ...  0.26000  0.41275  0.06525  0.21775
# 367      0.10350  0.08550  0.25050  ...  0.14900  0.22725  0.17625  0.12750
# ...          ...      ...      ...  ...      ...      ...      ...      ...
# 60514    0.92900  0.05400  0.12425  ...  0.31475  0.00000  0.17625  0.23500
# 60516    0.15325  0.05550  0.10500  ...  0.09375  0.18425  0.04050  0.24450
# 60684    0.06100  0.07175  0.14050  ...  0.06325  0.23675  0.06675  0.00000
# 60760    0.07025  0.02175  0.12200  ...  0.02000  0.11775  0.04425  0.27975
# 60832    0.03400  0.00000  0.08950  ...  0.06175  0.00000  0.03050  0.08175
# 61248    0.04150  0.02200  0.00000  ...  0.01825  0.00000  0.02700  0.60925
# 61465    0.02850  0.02150  0.13400  ...  0.01625  0.00000  0.03525  0.28350
# 62265    0.03325  0.02450  0.00000  ...  0.00000  0.33150  0.02625  0.54925
# 62956    0.08050  0.04700  0.00000  ...  0.11950  0.44100  0.08600  0.11250
# 63859    0.74750  0.02250  0.00000  ...  0.07725  0.49475  0.02975  0.08050
# 64034    0.02700  0.02225  0.00000  ...  0.13325  0.12750  0.02725  0.21925
# 64497    0.21475  0.03850  0.00000  ...  0.05800  0.00000  0.03625  0.26875
# 64508    0.10425  0.02450  0.17500  ...  0.02250  0.15625  0.07550  0.27925
# 64614    0.02500  0.02275  0.09475  ...  0.05450  0.39475  0.03250  0.12800
# 64997    0.14800  0.12025  0.09825  ...  0.07775  0.11800  0.05425  0.07350
# 65037    0.07075  0.04275  0.00000  ...  0.09800  0.18050  0.03925  0.07025
# 65514    0.03500  0.04925  0.16400  ...  0.12550  0.27475  0.05525  0.39925
# 66171    0.10425  0.00000  0.00000  ...  0.10575  0.00000  0.04375  0.32525
# 66297    0.17075  0.10600  0.08500  ...  0.00000  0.34225  0.04550  0.13200
# 67197    0.14175  0.02925  0.11225  ...  0.11875  0.00000  0.03225  0.13025
# 67295    0.43900  0.02775  0.00000  ...  0.05575  0.47200  0.07825  0.11225
# 67799    0.04825  0.00000  0.07650  ...  0.01700  0.00000  0.00000  0.24550
# 67867    0.27875  0.02100  0.24225  ...  0.09550  0.00000  0.23850  0.45175
# 68263    0.00000  0.00000  0.00000  ...  0.00000  0.12450  0.00000  0.00000
# 68319    0.15100  0.00000  0.00000  ...  0.02100  0.13725  0.03925  0.21825
# 69526    0.24550  0.03175  0.09175  ...  0.01900  0.00000  0.07100  0.27050
# 70305    0.17125  0.06325  0.15425  ...  1.21300  0.15525  0.08700  0.33850
# 71282    0.02350  0.00000  0.00000  ...  0.09500  0.38650  0.02575  0.47000
# 72641    0.00000  0.00000  0.00000  ...  0.18400  0.25250  0.00000  0.28225
# 82095    0.17650  0.08700  0.09800  ...  0.05825  0.00000  0.09750  0.16925
#
#          workplace    write  writers    wuxia     wwii   zombie
# movieId
# 1          0.10250  0.46825  0.00000  0.00000  0.03625  0.10075
# 10         0.07225  0.07825  0.18400  0.00000  0.01775  0.09125
# 19         0.11700  0.13575  0.00000  0.00000  0.01000  0.08225
# 32         0.15325  0.67200  0.33750  0.04300  0.01150  0.02650
# 39         0.07925  0.16300  0.00000  0.02725  0.01125  0.00000
# 65         0.09475  0.07125  0.17275  0.00000  0.00000  0.07750
# 110        0.00000  0.37925  0.00000  0.07275  0.19375  0.10150
# 145        0.07425  0.07550  0.00000  0.03800  0.01150  0.14650
# 150        0.00000  0.16825  0.16775  0.00000  0.07350  0.11525
# 153        0.00000  0.06650  0.00000  0.00000  0.01075  0.12375
# 158        0.00000  0.09775  0.00000  0.00000  0.01350  0.07625
# 160        0.00000  0.12550  0.24625  0.00000  0.00000  0.09800
# 165        0.00000  0.10550  0.00000  0.00000  0.01400  0.10925
# 170        0.08150  0.22650  0.22325  0.02975  0.01050  0.17275
# 172        0.11450  0.26900  0.27375  0.02650  0.00975  0.12550
# 173        0.07150  0.00000  0.21800  0.00000  0.01100  0.14475
# 185        0.14850  0.10550  0.31125  0.00000  0.01225  0.00000
# 208        0.00000  0.04975  0.17100  0.00000  0.01075  0.19200
# 231        0.20925  0.19000  0.17675  0.03575  0.01150  0.07825
# 253        0.00000  0.24700  0.17775  0.02850  0.01125  0.33050
# 256        0.08875  0.00000  0.00000  0.02150  0.01675  0.07575
# 260        0.00000  0.46025  0.00000  0.08850  0.05075  0.12625
# 286        0.12575  0.00000  0.23275  0.03150  0.00000  0.10575
# 296        0.06075  1.26525  0.32900  0.08250  0.01950  0.12825
# 316        0.00000  0.08050  0.22925  0.02775  0.01025  0.00000
# 318        0.11450  0.76850  0.19250  0.04225  0.10250  0.11875
# 344        0.26350  0.15525  0.00000  0.02325  0.01275  0.07775
# 356        0.06325  0.51750  0.16350  0.02375  0.13125  0.14050
# 364        0.00000  0.09100  0.00000  0.02025  0.02725  0.01925
# 367        0.16325  0.07850  0.00000  0.02150  0.01150  0.09925
# ...            ...      ...      ...      ...      ...      ...
# 60514      0.00000  0.00000  0.00000  0.00000  0.00000  0.17375
# 60516      0.08675  0.10075  0.24100  0.02700  0.01075  0.07200
# 60684      0.06225  0.35150  0.27425  0.06700  0.01550  0.10925
# 60760      0.08050  0.20750  0.39600  0.02200  0.01050  0.09475
# 60832      0.06875  0.22100  0.39350  0.02125  0.00000  0.10725
# 61248      0.10175  0.00000  0.00000  0.02725  0.00000  0.17275
# 61465      0.07575  0.14450  0.19725  0.02750  0.00950  0.08075
# 62265      0.00000  0.06875  0.25950  0.02425  0.00000  0.08575
# 62956      0.08050  0.30850  0.43525  0.05775  0.00000  0.11800
# 63859      0.13625  0.07800  0.00000  0.00000  0.01150  0.11800
# 64034      0.07200  0.14100  0.17325  0.00000  0.92800  0.01875
# 64497      0.06925  0.00000  0.20075  0.02950  0.01050  0.11200
# 64508      0.00000  0.05000  0.40225  0.03725  0.01725  0.08500
# 64614      0.07125  0.55900  0.30950  0.02175  0.13700  0.11525
# 64997      0.06225  0.30725  0.39675  0.00000  0.02075  0.12200
# 65037      0.07250  0.24875  0.20625  0.03000  0.01450  0.00000
# 65514      0.08925  0.17700  0.00000  0.98800  0.11375  0.16650
# 66171      0.00000  0.10475  0.23475  0.02750  0.01550  0.10075
# 66297      0.09225  0.30025  0.34550  0.04225  0.01350  0.01900
# 67197      0.00000  0.17525  0.36950  0.00000  0.01300  0.10475
# 67295      0.07750  0.00000  0.17175  0.06975  0.00950  0.16800
# 67799      0.00000  0.12150  0.25550  0.00000  0.01450  0.00000
# 67867      0.10000  0.07600  0.36725  0.16425  0.00000  0.09000
# 68263      0.28225  0.30375  0.26675  0.00000  0.01200  0.00000
# 68319      0.00000  0.08925  0.27825  0.00000  0.01450  0.11825
# 69526      0.05900  0.00000  0.19425  0.04425  0.01125  0.07700
# 70305      0.00000  0.00000  0.18100  0.00000  0.00000  0.11450
# 71282      0.13325  0.19600  0.00000  0.02375  0.01600  0.01750
# 72641      0.00000  0.18500  0.17225  0.00000  0.02900  0.11850
# 82095      0.00000  0.10800  0.41225  0.00000  0.00000  0.18000
#
# [495 rows x 702 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

# cluster_size = 8
n_movies = user_movie_tags_df.index.size

random_state = 171450

cluster_size_silhouette_score_d = dict()
highest_score = 0
optimal_cluster_size = 2

for cluster_size in range(2, n_movies-1, 1):
#     kmeans = KMeans(n_clusters=cluster_size, random_state=random_state, n_jobs=-1).fit(user_movie_tags_df.values)
    result = AgglomerativeClustering(n_clusters=cluster_size, affinity='euclidean', linkage='ward').fit_predict(user_movie_tags_df.values[:n_movies])

#     result = kmeans.predict(user_movie_tags_df.values)

    score = silhouette_score(user_movie_tags_df.values[:n_movies], result, metric='cosine')
    
    score_list = list()
    
#     if cluster_size in cluster_size_silhouette_score_d:
#             score_list = cluster_size_silhouette_score_d[cluster_size]
    
#     score_list.append(score)
    
    cluster_size_silhouette_score_d[cluster_size] = score
    if score >= highest_score:
        highest_score = score
        optimal_cluster_size = cluster_size
    print("N Clusters: ", cluster_size, ", Silhouette Score: ", score, "Result Unique Size", np.unique(result).size)

print(result)
print('best cluster size', optimal_cluster_size)
print('best silhouette score', highest_score)
# cluster_size_silhouette_score_d
# Out:
# N Clusters:  2 , Silhouette Score:  0.06287146502533343 Result Unique Size 2
# N Clusters:  3 , Silhouette Score:  0.05966002963415069 Result Unique Size 3
# N Clusters:  4 , Silhouette Score:  0.07275511587500658 Result Unique Size 4
# N Clusters:  5 , Silhouette Score:  0.0742140373720901 Result Unique Size 5
# N Clusters:  6 , Silhouette Score:  0.09774882400810586 Result Unique Size 6
# N Clusters:  7 , Silhouette Score:  0.06427238573120521 Result Unique Size 7
# N Clusters:  8 , Silhouette Score:  0.007839017384442435 Result Unique Size 8
# N Clusters:  9 , Silhouette Score:  0.02732091234200335 Result Unique Size 9
# N Clusters:  10 , Silhouette Score:  0.039027777009117644 Result Unique Size 10
# N Clusters:  11 , Silhouette Score:  0.035399982402992275 Result Unique Size 11
# N Clusters:  12 , Silhouette Score:  0.049922884793561786 Result Unique Size 12
# N Clusters:  13 , Silhouette Score:  0.030801399702975 Result Unique Size 13
# N Clusters:  14 , Silhouette Score:  0.04559561501937612 Result Unique Size 14
# N Clusters:  15 , Silhouette Score:  0.04117580570041639 Result Unique Size 15
# N Clusters:  16 , Silhouette Score:  0.05233643961878249 Result Unique Size 16
# N Clusters:  17 , Silhouette Score:  0.05770331327498837 Result Unique Size 17
# N Clusters:  18 , Silhouette Score:  0.04557121394681564 Result Unique Size 18
# N Clusters:  19 , Silhouette Score:  0.05843128804144201 Result Unique Size 19
# N Clusters:  20 , Silhouette Score:  0.04112225657853889 Result Unique Size 20
# N Clusters:  21 , Silhouette Score:  0.047755938963850685 Result Unique Size 21
# N Clusters:  22 , Silhouette Score:  0.05377630391789527 Result Unique Size 22
# N Clusters:  23 , Silhouette Score:  0.031250057341408545 Result Unique Size 23
# N Clusters:  24 , Silhouette Score:  0.026374746511144423 Result Unique Size 24
# N Clusters:  25 , Silhouette Score:  0.029977942133799264 Result Unique Size 25
# N Clusters:  26 , Silhouette Score:  0.027493094547811247 Result Unique Size 26
# N Clusters:  27 , Silhouette Score:  0.01815145675101476 Result Unique Size 27
# N Clusters:  28 , Silhouette Score:  0.027005446530373723 Result Unique Size 28
# N Clusters:  29 , Silhouette Score:  0.03133728498569676 Result Unique Size 29
# N Clusters:  30 , Silhouette Score:  0.023822242565614465 Result Unique Size 30
# N Clusters:  31 , Silhouette Score:  0.028935896379188048 Result Unique Size 31
# N Clusters:  32 , Silhouette Score:  0.03732891531878667 Result Unique Size 32
# N Clusters:  33 , Silhouette Score:  0.03918703819904623 Result Unique Size 33
# N Clusters:  34 , Silhouette Score:  0.0465421841396224 Result Unique Size 34
# N Clusters:  35 , Silhouette Score:  0.05167502930287687 Result Unique Size 35
# N Clusters:  36 , Silhouette Score:  0.051349286769511976 Result Unique Size 36
# N Clusters:  37 , Silhouette Score:  0.047543166472641875 Result Unique Size 37
# N Clusters:  38 , Silhouette Score:  0.052060267303253534 Result Unique Size 38
# N Clusters:  39 , Silhouette Score:  0.05631386758463649 Result Unique Size 39
# N Clusters:  40 , Silhouette Score:  0.04864726944015299 Result Unique Size 40
# N Clusters:  41 , Silhouette Score:  0.04540741326974795 Result Unique Size 41
# N Clusters:  42 , Silhouette Score:  0.042101573035979396 Result Unique Size 42
# N Clusters:  43 , Silhouette Score:  0.03538186034998959 Result Unique Size 43
# N Clusters:  44 , Silhouette Score:  0.040371413277614634 Result Unique Size 44
# N Clusters:  45 , Silhouette Score:  0.0439734017718915 Result Unique Size 45
# N Clusters:  46 , Silhouette Score:  0.03991740201171786 Result Unique Size 46
# N Clusters:  47 , Silhouette Score:  0.04096130706873333 Result Unique Size 47
# N Clusters:  48 , Silhouette Score:  0.04526879188165596 Result Unique Size 48
# N Clusters:  49 , Silhouette Score:  0.043961945779704234 Result Unique Size 49
# N Clusters:  50 , Silhouette Score:  0.047533524796546524 Result Unique Size 50
# N Clusters:  51 , Silhouette Score:  0.04529608484277515 Result Unique Size 51
# N Clusters:  52 , Silhouette Score:  0.047794449374866474 Result Unique Size 52
# N Clusters:  53 , Silhouette Score:  0.05445369490533735 Result Unique Size 53
# N Clusters:  54 , Silhouette Score:  0.05900326416512323 Result Unique Size 54
# N Clusters:  55 , Silhouette Score:  0.061930038108034526 Result Unique Size 55
# N Clusters:  56 , Silhouette Score:  0.06440304738915416 Result Unique Size 56
# N Clusters:  57 , Silhouette Score:  0.06747454298845519 Result Unique Size 57
# N Clusters:  58 , Silhouette Score:  0.06830699250644974 Result Unique Size 58
# N Clusters:  59 , Silhouette Score:  0.06768095447447456 Result Unique Size 59
# N Clusters:  60 , Silhouette Score:  0.07284152364365792 Result Unique Size 60
# N Clusters:  61 , Silhouette Score:  0.07227661273231191 Result Unique Size 61
# N Clusters:  62 , Silhouette Score:  0.07633015427244483 Result Unique Size 62
# N Clusters:  63 , Silhouette Score:  0.07886059266991044 Result Unique Size 63
# N Clusters:  64 , Silhouette Score:  0.07811579637798605 Result Unique Size 64
# N Clusters:  65 , Silhouette Score:  0.079459759945348 Result Unique Size 65
# N Clusters:  66 , Silhouette Score:  0.07989752939454578 Result Unique Size 66
# N Clusters:  67 , Silhouette Score:  0.08235600028297972 Result Unique Size 67
# N Clusters:  68 , Silhouette Score:  0.0834980124132183 Result Unique Size 68
# N Clusters:  69 , Silhouette Score:  0.08328240917379384 Result Unique Size 69
# N Clusters:  70 , Silhouette Score:  0.08776311039618376 Result Unique Size 70
# N Clusters:  71 , Silhouette Score:  0.09023757754670564 Result Unique Size 71
# N Clusters:  72 , Silhouette Score:  0.08949098968127345 Result Unique Size 72
# N Clusters:  73 , Silhouette Score:  0.09290609810793105 Result Unique Size 73
# N Clusters:  74 , Silhouette Score:  0.09498997170606932 Result Unique Size 74
# N Clusters:  75 , Silhouette Score:  0.09658967705059612 Result Unique Size 75
# N Clusters:  76 , Silhouette Score:  0.09601212575228824 Result Unique Size 76
# N Clusters:  77 , Silhouette Score:  0.09377692546121151 Result Unique Size 77
# N Clusters:  78 , Silhouette Score:  0.09673993698801692 Result Unique Size 78
# N Clusters:  79 , Silhouette Score:  0.0975780223801065 Result Unique Size 79
# N Clusters:  80 , Silhouette Score:  0.09861890361734853 Result Unique Size 80
# N Clusters:  81 , Silhouette Score:  0.09779846385743302 Result Unique Size 81
# N Clusters:  82 , Silhouette Score:  0.10117419588721902 Result Unique Size 82
# N Clusters:  83 , Silhouette Score:  0.10171489240250842 Result Unique Size 83
# N Clusters:  84 , Silhouette Score:  0.10266253021958259 Result Unique Size 84
# N Clusters:  85 , Silhouette Score:  0.10153944770894668 Result Unique Size 85
# N Clusters:  86 , Silhouette Score:  0.10410228380943765 Result Unique Size 86
# N Clusters:  87 , Silhouette Score:  0.1050356512376204 Result Unique Size 87
# N Clusters:  88 , Silhouette Score:  0.10468244147892672 Result Unique Size 88
# N Clusters:  89 , Silhouette Score:  0.10449180922520294 Result Unique Size 89
# N Clusters:  90 , Silhouette Score:  0.10796623797778171 Result Unique Size 90
# N Clusters:  91 , Silhouette Score:  0.10825916349706859 Result Unique Size 91
# N Clusters:  92 , Silhouette Score:  0.10737073311556729 Result Unique Size 92
# N Clusters:  93 , Silhouette Score:  0.10918071180396462 Result Unique Size 93
# N Clusters:  94 , Silhouette Score:  0.10934461507083869 Result Unique Size 94
# N Clusters:  95 , Silhouette Score:  0.11234434498475723 Result Unique Size 95
# N Clusters:  96 , Silhouette Score:  0.1157697546264404 Result Unique Size 96
# N Clusters:  97 , Silhouette Score:  0.11549542146033834 Result Unique Size 97
# N Clusters:  98 , Silhouette Score:  0.11887010164867737 Result Unique Size 98
# N Clusters:  99 , Silhouette Score:  0.11817585929107165 Result Unique Size 99
# N Clusters:  100 , Silhouette Score:  0.1181751857222015 Result Unique Size 100
# N Clusters:  101 , Silhouette Score:  0.12071905496830569 Result Unique Size 101
# N Clusters:  102 , Silhouette Score:  0.12220941331598485 Result Unique Size 102
# N Clusters:  103 , Silhouette Score:  0.12346428193085172 Result Unique Size 103
# N Clusters:  104 , Silhouette Score:  0.11973267988410514 Result Unique Size 104
# N Clusters:  105 , Silhouette Score:  0.11628643945466788 Result Unique Size 105
# N Clusters:  106 , Silhouette Score:  0.11637371425386499 Result Unique Size 106
# N Clusters:  107 , Silhouette Score:  0.11915559208383945 Result Unique Size 107
# N Clusters:  108 , Silhouette Score:  0.11739718790441034 Result Unique Size 108
# N Clusters:  109 , Silhouette Score:  0.1175381165408257 Result Unique Size 109
# N Clusters:  110 , Silhouette Score:  0.11841864511283477 Result Unique Size 110
# N Clusters:  111 , Silhouette Score:  0.11728304603954974 Result Unique Size 111
# N Clusters:  112 , Silhouette Score:  0.11556302816933568 Result Unique Size 112
# N Clusters:  113 , Silhouette Score:  0.11718010780832416 Result Unique Size 113
# N Clusters:  114 , Silhouette Score:  0.11565857425755066 Result Unique Size 114
# N Clusters:  115 , Silhouette Score:  0.11833215536449972 Result Unique Size 115
# N Clusters:  116 , Silhouette Score:  0.1162972264442845 Result Unique Size 116
# N Clusters:  117 , Silhouette Score:  0.11602657572881259 Result Unique Size 117
# N Clusters:  118 , Silhouette Score:  0.11882698464686024 Result Unique Size 118
# N Clusters:  119 , Silhouette Score:  0.11904632839308509 Result Unique Size 119
# N Clusters:  120 , Silhouette Score:  0.12015374469232455 Result Unique Size 120
# N Clusters:  121 , Silhouette Score:  0.11897864342860115 Result Unique Size 121
# N Clusters:  122 , Silhouette Score:  0.12005974017182429 Result Unique Size 122
# N Clusters:  123 , Silhouette Score:  0.12073292260678258 Result Unique Size 123
# N Clusters:  124 , Silhouette Score:  0.1186047614529224 Result Unique Size 124
# N Clusters:  125 , Silhouette Score:  0.11675145973384837 Result Unique Size 125
# N Clusters:  126 , Silhouette Score:  0.11700827048729226 Result Unique Size 126
# N Clusters:  127 , Silhouette Score:  0.11652377257773014 Result Unique Size 127
# N Clusters:  128 , Silhouette Score:  0.11965036388369152 Result Unique Size 128
# N Clusters:  129 , Silhouette Score:  0.11626453432269114 Result Unique Size 129
# N Clusters:  130 , Silhouette Score:  0.1175690865331726 Result Unique Size 130
# N Clusters:  131 , Silhouette Score:  0.11753757080491631 Result Unique Size 131
# N Clusters:  132 , Silhouette Score:  0.11832785984796526 Result Unique Size 132
# N Clusters:  133 , Silhouette Score:  0.12084380281763582 Result Unique Size 133
# N Clusters:  134 , Silhouette Score:  0.11763056321345039 Result Unique Size 134
# N Clusters:  135 , Silhouette Score:  0.11878897436400823 Result Unique Size 135
# N Clusters:  136 , Silhouette Score:  0.11891317467015496 Result Unique Size 136
# N Clusters:  137 , Silhouette Score:  0.11896391157644871 Result Unique Size 137
# N Clusters:  138 , Silhouette Score:  0.12017749976481498 Result Unique Size 138
# N Clusters:  139 , Silhouette Score:  0.12178111175511146 Result Unique Size 139
# N Clusters:  140 , Silhouette Score:  0.11721218949930898 Result Unique Size 140
# N Clusters:  141 , Silhouette Score:  0.11904521854140634 Result Unique Size 141
# N Clusters:  142 , Silhouette Score:  0.11946512621681833 Result Unique Size 142
# N Clusters:  143 , Silhouette Score:  0.12143746061202233 Result Unique Size 143
# N Clusters:  144 , Silhouette Score:  0.12312517111498002 Result Unique Size 144
# N Clusters:  145 , Silhouette Score:  0.12481966036849501 Result Unique Size 145
# N Clusters:  146 , Silhouette Score:  0.12606753932503154 Result Unique Size 146
# N Clusters:  147 , Silhouette Score:  0.12729682708152562 Result Unique Size 147
# N Clusters:  148 , Silhouette Score:  0.12729511643076222 Result Unique Size 148
# N Clusters:  149 , Silhouette Score:  0.12812514828540014 Result Unique Size 149
# N Clusters:  150 , Silhouette Score:  0.13105892983664522 Result Unique Size 150
# N Clusters:  151 , Silhouette Score:  0.13221886737927024 Result Unique Size 151
# N Clusters:  152 , Silhouette Score:  0.13233918900061611 Result Unique Size 152
# N Clusters:  153 , Silhouette Score:  0.13160024487653688 Result Unique Size 153
# N Clusters:  154 , Silhouette Score:  0.1330950242871904 Result Unique Size 154
# N Clusters:  155 , Silhouette Score:  0.13310765844442765 Result Unique Size 155
# N Clusters:  156 , Silhouette Score:  0.13294208053586215 Result Unique Size 156
# N Clusters:  157 , Silhouette Score:  0.13336246470228091 Result Unique Size 157
# N Clusters:  158 , Silhouette Score:  0.1343956328286775 Result Unique Size 158
# N Clusters:  159 , Silhouette Score:  0.13573687884083896 Result Unique Size 159
# N Clusters:  160 , Silhouette Score:  0.13574140956008812 Result Unique Size 160
# N Clusters:  161 , Silhouette Score:  0.13456417897286715 Result Unique Size 161
# N Clusters:  162 , Silhouette Score:  0.13597907462004769 Result Unique Size 162
# N Clusters:  163 , Silhouette Score:  0.13682609687060235 Result Unique Size 163
# N Clusters:  164 , Silhouette Score:  0.1386765191421272 Result Unique Size 164
# N Clusters:  165 , Silhouette Score:  0.1366396842418644 Result Unique Size 165
# N Clusters:  166 , Silhouette Score:  0.13821620370140525 Result Unique Size 166
# N Clusters:  167 , Silhouette Score:  0.1396852894080541 Result Unique Size 167
# N Clusters:  168 , Silhouette Score:  0.14016416237668702 Result Unique Size 168
# N Clusters:  169 , Silhouette Score:  0.13983982671160125 Result Unique Size 169
# N Clusters:  170 , Silhouette Score:  0.13913716999360815 Result Unique Size 170
# N Clusters:  171 , Silhouette Score:  0.13810492380136993 Result Unique Size 171
# N Clusters:  172 , Silhouette Score:  0.1385906852140958 Result Unique Size 172
# N Clusters:  173 , Silhouette Score:  0.13962941550653973 Result Unique Size 173
# N Clusters:  174 , Silhouette Score:  0.13994941553205587 Result Unique Size 174
# N Clusters:  175 , Silhouette Score:  0.13852614761522616 Result Unique Size 175
# N Clusters:  176 , Silhouette Score:  0.14007616948379623 Result Unique Size 176
# N Clusters:  177 , Silhouette Score:  0.14082977932742927 Result Unique Size 177
# N Clusters:  178 , Silhouette Score:  0.14216661436867423 Result Unique Size 178
# N Clusters:  179 , Silhouette Score:  0.14314139268419188 Result Unique Size 179
# N Clusters:  180 , Silhouette Score:  0.14642351348367497 Result Unique Size 180
# N Clusters:  181 , Silhouette Score:  0.14610230525196047 Result Unique Size 181
# N Clusters:  182 , Silhouette Score:  0.1451405810478336 Result Unique Size 182
# N Clusters:  183 , Silhouette Score:  0.14473983242734223 Result Unique Size 183
# N Clusters:  184 , Silhouette Score:  0.1462891429133005 Result Unique Size 184
# N Clusters:  185 , Silhouette Score:  0.14441754581498215 Result Unique Size 185
# N Clusters:  186 , Silhouette Score:  0.14546037247530133 Result Unique Size 186
# N Clusters:  187 , Silhouette Score:  0.14463049223481483 Result Unique Size 187
# N Clusters:  188 , Silhouette Score:  0.14486641168256717 Result Unique Size 188
# N Clusters:  189 , Silhouette Score:  0.1454835146594713 Result Unique Size 189
# N Clusters:  190 , Silhouette Score:  0.14538447180657846 Result Unique Size 190
# N Clusters:  191 , Silhouette Score:  0.14502912856966246 Result Unique Size 191
# N Clusters:  192 , Silhouette Score:  0.14722726631748484 Result Unique Size 192
# N Clusters:  193 , Silhouette Score:  0.14759786184797039 Result Unique Size 193
# N Clusters:  194 , Silhouette Score:  0.14704213462149274 Result Unique Size 194
# N Clusters:  195 , Silhouette Score:  0.1485810534745298 Result Unique Size 195
# N Clusters:  196 , Silhouette Score:  0.150185589930661 Result Unique Size 196
# N Clusters:  197 , Silhouette Score:  0.15065349860452576 Result Unique Size 197
# N Clusters:  198 , Silhouette Score:  0.1513811750271596 Result Unique Size 198
# N Clusters:  199 , Silhouette Score:  0.152847654091671 Result Unique Size 199
# N Clusters:  200 , Silhouette Score:  0.15081375797827976 Result Unique Size 200
# N Clusters:  201 , Silhouette Score:  0.1512612038784908 Result Unique Size 201
# N Clusters:  202 , Silhouette Score:  0.15178046581274574 Result Unique Size 202
# N Clusters:  203 , Silhouette Score:  0.15172651502227036 Result Unique Size 203
# N Clusters:  204 , Silhouette Score:  0.15134005256062844 Result Unique Size 204
# N Clusters:  205 , Silhouette Score:  0.15152879659970642 Result Unique Size 205
# N Clusters:  206 , Silhouette Score:  0.15084747465248638 Result Unique Size 206
# N Clusters:  207 , Silhouette Score:  0.15046063068874863 Result Unique Size 207
# N Clusters:  208 , Silhouette Score:  0.1522279752752567 Result Unique Size 208
# N Clusters:  209 , Silhouette Score:  0.15411819282790967 Result Unique Size 209
# N Clusters:  210 , Silhouette Score:  0.15330279611914896 Result Unique Size 210
# N Clusters:  211 , Silhouette Score:  0.15277555844817972 Result Unique Size 211
# N Clusters:  212 , Silhouette Score:  0.15381156360761253 Result Unique Size 212
# N Clusters:  213 , Silhouette Score:  0.15501064094405193 Result Unique Size 213
# N Clusters:  214 , Silhouette Score:  0.15678373174677612 Result Unique Size 214
# N Clusters:  215 , Silhouette Score:  0.1546352817608883 Result Unique Size 215
# N Clusters:  216 , Silhouette Score:  0.1533964866693558 Result Unique Size 216
# N Clusters:  217 , Silhouette Score:  0.15283419279667587 Result Unique Size 217
# N Clusters:  218 , Silhouette Score:  0.1525958239657799 Result Unique Size 218
# N Clusters:  219 , Silhouette Score:  0.1537536986358407 Result Unique Size 219
# N Clusters:  220 , Silhouette Score:  0.15409193403568797 Result Unique Size 220
# N Clusters:  221 , Silhouette Score:  0.15345930769476812 Result Unique Size 221
# N Clusters:  222 , Silhouette Score:  0.1542928711547788 Result Unique Size 222
# N Clusters:  223 , Silhouette Score:  0.1550538571461335 Result Unique Size 223
# N Clusters:  224 , Silhouette Score:  0.1525835196469645 Result Unique Size 224
# N Clusters:  225 , Silhouette Score:  0.15223515378671407 Result Unique Size 225
# N Clusters:  226 , Silhouette Score:  0.15295000365068112 Result Unique Size 226
# N Clusters:  227 , Silhouette Score:  0.15249394535613775 Result Unique Size 227
# N Clusters:  228 , Silhouette Score:  0.1527590785226962 Result Unique Size 228
# N Clusters:  229 , Silhouette Score:  0.15242930836105256 Result Unique Size 229
# N Clusters:  230 , Silhouette Score:  0.1526859713193955 Result Unique Size 230
# N Clusters:  231 , Silhouette Score:  0.15167385700284788 Result Unique Size 231
# N Clusters:  232 , Silhouette Score:  0.1514706000211001 Result Unique Size 232
# N Clusters:  233 , Silhouette Score:  0.15296473807730707 Result Unique Size 233
# N Clusters:  234 , Silhouette Score:  0.15323629835364222 Result Unique Size 234
# N Clusters:  235 , Silhouette Score:  0.15324377426790867 Result Unique Size 235
# N Clusters:  236 , Silhouette Score:  0.15232984665305904 Result Unique Size 236
# N Clusters:  237 , Silhouette Score:  0.14916363405714322 Result Unique Size 237
# N Clusters:  238 , Silhouette Score:  0.1483685854814378 Result Unique Size 238
# N Clusters:  239 , Silhouette Score:  0.14784719902609791 Result Unique Size 239
# N Clusters:  240 , Silhouette Score:  0.148523091493127 Result Unique Size 240
# N Clusters:  241 , Silhouette Score:  0.14785658826828565 Result Unique Size 241
# N Clusters:  242 , Silhouette Score:  0.14824748370741345 Result Unique Size 242
# N Clusters:  243 , Silhouette Score:  0.15003110964806046 Result Unique Size 243
# N Clusters:  244 , Silhouette Score:  0.15097035679816012 Result Unique Size 244
# N Clusters:  245 , Silhouette Score:  0.14923140670538487 Result Unique Size 245
# N Clusters:  246 , Silhouette Score:  0.1483564616220783 Result Unique Size 246
# N Clusters:  247 , Silhouette Score:  0.14883230523519309 Result Unique Size 247
# N Clusters:  248 , Silhouette Score:  0.1484368560733296 Result Unique Size 248
# N Clusters:  249 , Silhouette Score:  0.1496842315353943 Result Unique Size 249
# N Clusters:  250 , Silhouette Score:  0.14969055077460833 Result Unique Size 250
# N Clusters:  251 , Silhouette Score:  0.14996735791024815 Result Unique Size 251
# N Clusters:  252 , Silhouette Score:  0.14915233885582255 Result Unique Size 252
# N Clusters:  253 , Silhouette Score:  0.14827929015106708 Result Unique Size 253
# N Clusters:  254 , Silhouette Score:  0.14876435010542644 Result Unique Size 254
# N Clusters:  255 , Silhouette Score:  0.14789958527368033 Result Unique Size 255
# N Clusters:  256 , Silhouette Score:  0.1489466606889679 Result Unique Size 256
# N Clusters:  257 , Silhouette Score:  0.14677084384309516 Result Unique Size 257
# N Clusters:  258 , Silhouette Score:  0.14735085631294498 Result Unique Size 258
# N Clusters:  259 , Silhouette Score:  0.14916430347334175 Result Unique Size 259
# N Clusters:  260 , Silhouette Score:  0.14933688481124563 Result Unique Size 260
# N Clusters:  261 , Silhouette Score:  0.1479221063310821 Result Unique Size 261
# N Clusters:  262 , Silhouette Score:  0.14664844684061454 Result Unique Size 262
# N Clusters:  263 , Silhouette Score:  0.1468186876193415 Result Unique Size 263
# N Clusters:  264 , Silhouette Score:  0.14723929402726482 Result Unique Size 264
# N Clusters:  265 , Silhouette Score:  0.14507990140263552 Result Unique Size 265
# N Clusters:  266 , Silhouette Score:  0.14626644964635008 Result Unique Size 266
# N Clusters:  267 , Silhouette Score:  0.14541255398723285 Result Unique Size 267
# N Clusters:  268 , Silhouette Score:  0.14523625739578588 Result Unique Size 268
# N Clusters:  269 , Silhouette Score:  0.14543901814715327 Result Unique Size 269
# N Clusters:  270 , Silhouette Score:  0.14581958313472587 Result Unique Size 270
# N Clusters:  271 , Silhouette Score:  0.144795790049381 Result Unique Size 271
# N Clusters:  272 , Silhouette Score:  0.1451565224624658 Result Unique Size 272
# N Clusters:  273 , Silhouette Score:  0.1445869001854795 Result Unique Size 273
# N Clusters:  274 , Silhouette Score:  0.14488651386381363 Result Unique Size 274
# N Clusters:  275 , Silhouette Score:  0.14553155994632624 Result Unique Size 275
# N Clusters:  276 , Silhouette Score:  0.1460898410496745 Result Unique Size 276
# N Clusters:  277 , Silhouette Score:  0.1470846800892697 Result Unique Size 277
# N Clusters:  278 , Silhouette Score:  0.14748948734739134 Result Unique Size 278
# N Clusters:  279 , Silhouette Score:  0.14680895029158322 Result Unique Size 279
# N Clusters:  280 , Silhouette Score:  0.14565538388336371 Result Unique Size 280
# N Clusters:  281 , Silhouette Score:  0.14569616831808374 Result Unique Size 281
# N Clusters:  282 , Silhouette Score:  0.1470046404322726 Result Unique Size 282
# N Clusters:  283 , Silhouette Score:  0.14665587541266561 Result Unique Size 283
# N Clusters:  284 , Silhouette Score:  0.14590404276652827 Result Unique Size 284
# N Clusters:  285 , Silhouette Score:  0.14657101182585566 Result Unique Size 285
# N Clusters:  286 , Silhouette Score:  0.143832035853746 Result Unique Size 286
# N Clusters:  287 , Silhouette Score:  0.14406800639084794 Result Unique Size 287
# N Clusters:  288 , Silhouette Score:  0.144439918798556 Result Unique Size 288
# N Clusters:  289 , Silhouette Score:  0.14497951824681915 Result Unique Size 289
# N Clusters:  290 , Silhouette Score:  0.14518737009843477 Result Unique Size 290
# N Clusters:  291 , Silhouette Score:  0.1453816445261548 Result Unique Size 291
# N Clusters:  292 , Silhouette Score:  0.14532353324666317 Result Unique Size 292
# N Clusters:  293 , Silhouette Score:  0.145681092940964 Result Unique Size 293
# N Clusters:  294 , Silhouette Score:  0.14327507166477024 Result Unique Size 294
# N Clusters:  295 , Silhouette Score:  0.14252985448800376 Result Unique Size 295
# N Clusters:  296 , Silhouette Score:  0.14343699695375983 Result Unique Size 296
# N Clusters:  297 , Silhouette Score:  0.1416452451206433 Result Unique Size 297
# N Clusters:  298 , Silhouette Score:  0.1412488834834201 Result Unique Size 298
# N Clusters:  299 , Silhouette Score:  0.14184792417540015 Result Unique Size 299
# N Clusters:  300 , Silhouette Score:  0.1420768098812071 Result Unique Size 300
# N Clusters:  301 , Silhouette Score:  0.14085180143260903 Result Unique Size 301
# N Clusters:  302 , Silhouette Score:  0.14012412217575804 Result Unique Size 302
# N Clusters:  303 , Silhouette Score:  0.1395805242224317 Result Unique Size 303
# N Clusters:  304 , Silhouette Score:  0.13956469574286023 Result Unique Size 304
# N Clusters:  305 , Silhouette Score:  0.13762230018949764 Result Unique Size 305
# N Clusters:  306 , Silhouette Score:  0.13694369572216905 Result Unique Size 306
# N Clusters:  307 , Silhouette Score:  0.13815712996507504 Result Unique Size 307
# N Clusters:  308 , Silhouette Score:  0.13862617757177648 Result Unique Size 308
# N Clusters:  309 , Silhouette Score:  0.14012123668350387 Result Unique Size 309
# N Clusters:  310 , Silhouette Score:  0.1402150426429499 Result Unique Size 310
# N Clusters:  311 , Silhouette Score:  0.14129768658964859 Result Unique Size 311
# N Clusters:  312 , Silhouette Score:  0.14128561585092891 Result Unique Size 312
# N Clusters:  313 , Silhouette Score:  0.14124896087045527 Result Unique Size 313
# N Clusters:  314 , Silhouette Score:  0.14129068657152058 Result Unique Size 314
# N Clusters:  315 , Silhouette Score:  0.14038692885348775 Result Unique Size 315
# N Clusters:  316 , Silhouette Score:  0.14052566768036148 Result Unique Size 316
# N Clusters:  317 , Silhouette Score:  0.14048802818281694 Result Unique Size 317
# N Clusters:  318 , Silhouette Score:  0.1403616598374971 Result Unique Size 318
# N Clusters:  319 , Silhouette Score:  0.13987971618482445 Result Unique Size 319
# N Clusters:  320 , Silhouette Score:  0.14029156631990497 Result Unique Size 320
# N Clusters:  321 , Silhouette Score:  0.13849258763816819 Result Unique Size 321
# N Clusters:  322 , Silhouette Score:  0.1381466079966659 Result Unique Size 322
# N Clusters:  323 , Silhouette Score:  0.13858302545023635 Result Unique Size 323
# N Clusters:  324 , Silhouette Score:  0.13820647767056324 Result Unique Size 324
# N Clusters:  325 , Silhouette Score:  0.1367495226651052 Result Unique Size 325
# N Clusters:  326 , Silhouette Score:  0.13737446130711006 Result Unique Size 326
# N Clusters:  327 , Silhouette Score:  0.13620356016356588 Result Unique Size 327
# N Clusters:  328 , Silhouette Score:  0.1380894896973476 Result Unique Size 328
# N Clusters:  329 , Silhouette Score:  0.13763087057608128 Result Unique Size 329
# N Clusters:  330 , Silhouette Score:  0.13834281547347385 Result Unique Size 330
# N Clusters:  331 , Silhouette Score:  0.13817780019740084 Result Unique Size 331
# N Clusters:  332 , Silhouette Score:  0.13792416587772574 Result Unique Size 332
# N Clusters:  333 , Silhouette Score:  0.13734055245436133 Result Unique Size 333
# N Clusters:  334 , Silhouette Score:  0.13643043997177254 Result Unique Size 334
# N Clusters:  335 , Silhouette Score:  0.1356551675911307 Result Unique Size 335
# N Clusters:  336 , Silhouette Score:  0.13445223164339415 Result Unique Size 336
# N Clusters:  337 , Silhouette Score:  0.13534022689516562 Result Unique Size 337
# N Clusters:  338 , Silhouette Score:  0.1355110232855738 Result Unique Size 338
# N Clusters:  339 , Silhouette Score:  0.13474851117234263 Result Unique Size 339
# N Clusters:  340 , Silhouette Score:  0.13612506581322031 Result Unique Size 340
# N Clusters:  341 , Silhouette Score:  0.13707726000464904 Result Unique Size 341
# N Clusters:  342 , Silhouette Score:  0.13681405500221905 Result Unique Size 342
# N Clusters:  343 , Silhouette Score:  0.13616718706585906 Result Unique Size 343
# N Clusters:  344 , Silhouette Score:  0.13694313732666114 Result Unique Size 344
# N Clusters:  345 , Silhouette Score:  0.1372504128546345 Result Unique Size 345
# N Clusters:  346 , Silhouette Score:  0.13726395590347265 Result Unique Size 346
# N Clusters:  347 , Silhouette Score:  0.13720248971629045 Result Unique Size 347
# N Clusters:  348 , Silhouette Score:  0.13576396861167198 Result Unique Size 348
# N Clusters:  349 , Silhouette Score:  0.13671412498040167 Result Unique Size 349
# N Clusters:  350 , Silhouette Score:  0.1358542868497873 Result Unique Size 350
# N Clusters:  351 , Silhouette Score:  0.13311124704977614 Result Unique Size 351
# N Clusters:  352 , Silhouette Score:  0.13167235250051096 Result Unique Size 352
# N Clusters:  353 , Silhouette Score:  0.13178974141521038 Result Unique Size 353
# N Clusters:  354 , Silhouette Score:  0.13115963575572553 Result Unique Size 354
# N Clusters:  355 , Silhouette Score:  0.13190556644525625 Result Unique Size 355
# N Clusters:  356 , Silhouette Score:  0.12993559554744533 Result Unique Size 356
# N Clusters:  357 , Silhouette Score:  0.12823007775765913 Result Unique Size 357
# N Clusters:  358 , Silhouette Score:  0.1279059444824865 Result Unique Size 358
# N Clusters:  359 , Silhouette Score:  0.12819061469870857 Result Unique Size 359
# N Clusters:  360 , Silhouette Score:  0.12924546170726173 Result Unique Size 360
# N Clusters:  361 , Silhouette Score:  0.12974066153937353 Result Unique Size 361
# N Clusters:  362 , Silhouette Score:  0.1289417941971457 Result Unique Size 362
# N Clusters:  363 , Silhouette Score:  0.12927309807224924 Result Unique Size 363
# N Clusters:  364 , Silhouette Score:  0.12804167363164787 Result Unique Size 364
# N Clusters:  365 , Silhouette Score:  0.12884167059332483 Result Unique Size 365
# N Clusters:  366 , Silhouette Score:  0.12735700453627516 Result Unique Size 366
# N Clusters:  367 , Silhouette Score:  0.12655641377322932 Result Unique Size 367
# N Clusters:  368 , Silhouette Score:  0.12658895987941876 Result Unique Size 368
# N Clusters:  369 , Silhouette Score:  0.12660719980638097 Result Unique Size 369
# N Clusters:  370 , Silhouette Score:  0.12564232561019284 Result Unique Size 370
# N Clusters:  371 , Silhouette Score:  0.12313955032945839 Result Unique Size 371
# N Clusters:  372 , Silhouette Score:  0.12033074546306248 Result Unique Size 372
# N Clusters:  373 , Silhouette Score:  0.11860293800238113 Result Unique Size 373
# N Clusters:  374 , Silhouette Score:  0.11788185274638349 Result Unique Size 374
# N Clusters:  375 , Silhouette Score:  0.11781807714595766 Result Unique Size 375
# N Clusters:  376 , Silhouette Score:  0.11670894628773149 Result Unique Size 376
# N Clusters:  377 , Silhouette Score:  0.11703335032187474 Result Unique Size 377
# N Clusters:  378 , Silhouette Score:  0.11796873078056026 Result Unique Size 378
# N Clusters:  379 , Silhouette Score:  0.1178396415092983 Result Unique Size 379
# N Clusters:  380 , Silhouette Score:  0.11499204627571369 Result Unique Size 380
# N Clusters:  381 , Silhouette Score:  0.11468570578324698 Result Unique Size 381
# N Clusters:  382 , Silhouette Score:  0.11429062269085996 Result Unique Size 382
# N Clusters:  383 , Silhouette Score:  0.11422910468924291 Result Unique Size 383
# N Clusters:  384 , Silhouette Score:  0.11378015156253708 Result Unique Size 384
# N Clusters:  385 , Silhouette Score:  0.11379205176069253 Result Unique Size 385
# N Clusters:  386 , Silhouette Score:  0.11091462818485028 Result Unique Size 386
# N Clusters:  387 , Silhouette Score:  0.1105183907704476 Result Unique Size 387
# N Clusters:  388 , Silhouette Score:  0.11017474640147375 Result Unique Size 388
# N Clusters:  389 , Silhouette Score:  0.11095611121945174 Result Unique Size 389
# N Clusters:  390 , Silhouette Score:  0.1085903146563099 Result Unique Size 390
# N Clusters:  391 , Silhouette Score:  0.10770469893103064 Result Unique Size 391
# N Clusters:  392 , Silhouette Score:  0.10706300945280676 Result Unique Size 392
# N Clusters:  393 , Silhouette Score:  0.10762485631057181 Result Unique Size 393
# N Clusters:  394 , Silhouette Score:  0.10529984371492201 Result Unique Size 394
# N Clusters:  395 , Silhouette Score:  0.10610522147766477 Result Unique Size 395
# N Clusters:  396 , Silhouette Score:  0.10601887508271085 Result Unique Size 396
# N Clusters:  397 , Silhouette Score:  0.10464677589059461 Result Unique Size 397
# N Clusters:  398 , Silhouette Score:  0.10095121524039784 Result Unique Size 398
# N Clusters:  399 , Silhouette Score:  0.0997712827682053 Result Unique Size 399
# N Clusters:  400 , Silhouette Score:  0.10043429211374302 Result Unique Size 400
# N Clusters:  401 , Silhouette Score:  0.10145772717601109 Result Unique Size 401
# N Clusters:  402 , Silhouette Score:  0.099767075105514 Result Unique Size 402
# N Clusters:  403 , Silhouette Score:  0.09792942471358827 Result Unique Size 403
# N Clusters:  404 , Silhouette Score:  0.0987811397385534 Result Unique Size 404
# N Clusters:  405 , Silhouette Score:  0.09783924769380237 Result Unique Size 405
# N Clusters:  406 , Silhouette Score:  0.09919058874871346 Result Unique Size 406
# N Clusters:  407 , Silhouette Score:  0.09988403251605905 Result Unique Size 407
# N Clusters:  408 , Silhouette Score:  0.09905492285813329 Result Unique Size 408
# N Clusters:  409 , Silhouette Score:  0.09864580328188738 Result Unique Size 409
# N Clusters:  410 , Silhouette Score:  0.0976040850857665 Result Unique Size 410
# N Clusters:  411 , Silhouette Score:  0.09542922291578312 Result Unique Size 411
# N Clusters:  412 , Silhouette Score:  0.09739277664574297 Result Unique Size 412
# N Clusters:  413 , Silhouette Score:  0.09520148375091736 Result Unique Size 413
# N Clusters:  414 , Silhouette Score:  0.09455492643343177 Result Unique Size 414
# N Clusters:  415 , Silhouette Score:  0.09449047264381048 Result Unique Size 415
# N Clusters:  416 , Silhouette Score:  0.09501302678425898 Result Unique Size 416
# N Clusters:  417 , Silhouette Score:  0.09415005912433952 Result Unique Size 417
# N Clusters:  418 , Silhouette Score:  0.09362941942721034 Result Unique Size 418
# N Clusters:  419 , Silhouette Score:  0.09323350260884375 Result Unique Size 419
# N Clusters:  420 , Silhouette Score:  0.09306172918959998 Result Unique Size 420
# N Clusters:  421 , Silhouette Score:  0.09191138843875643 Result Unique Size 421
# N Clusters:  422 , Silhouette Score:  0.09185259662123871 Result Unique Size 422
# N Clusters:  423 , Silhouette Score:  0.08946356502159052 Result Unique Size 423
# N Clusters:  424 , Silhouette Score:  0.08775645950746949 Result Unique Size 424
# N Clusters:  425 , Silhouette Score:  0.08829990923930343 Result Unique Size 425
# N Clusters:  426 , Silhouette Score:  0.08704112793851868 Result Unique Size 426
# N Clusters:  427 , Silhouette Score:  0.0855408524977896 Result Unique Size 427
# N Clusters:  428 , Silhouette Score:  0.08611558480416917 Result Unique Size 428
# N Clusters:  429 , Silhouette Score:  0.08481950828367205 Result Unique Size 429
# N Clusters:  430 , Silhouette Score:  0.08414700900519988 Result Unique Size 430
# N Clusters:  431 , Silhouette Score:  0.0840952926699284 Result Unique Size 431
# N Clusters:  432 , Silhouette Score:  0.08464649386630878 Result Unique Size 432
# N Clusters:  433 , Silhouette Score:  0.08369014612607319 Result Unique Size 433
# N Clusters:  434 , Silhouette Score:  0.08424566887241264 Result Unique Size 434
# N Clusters:  435 , Silhouette Score:  0.08411763756909102 Result Unique Size 435
# N Clusters:  436 , Silhouette Score:  0.08246967896188435 Result Unique Size 436
# N Clusters:  437 , Silhouette Score:  0.08096429105272174 Result Unique Size 437
# N Clusters:  438 , Silhouette Score:  0.08073376040911112 Result Unique Size 438
# N Clusters:  439 , Silhouette Score:  0.08028620363988465 Result Unique Size 439
# N Clusters:  440 , Silhouette Score:  0.08031440057099419 Result Unique Size 440
# N Clusters:  441 , Silhouette Score:  0.07991072787617995 Result Unique Size 441
# N Clusters:  442 , Silhouette Score:  0.07738772251316131 Result Unique Size 442
# N Clusters:  443 , Silhouette Score:  0.07709460902109852 Result Unique Size 443
# N Clusters:  444 , Silhouette Score:  0.07727499361682165 Result Unique Size 444
# N Clusters:  445 , Silhouette Score:  0.0763792158276617 Result Unique Size 445
# N Clusters:  446 , Silhouette Score:  0.07511026682318434 Result Unique Size 446
# N Clusters:  447 , Silhouette Score:  0.07487831176532793 Result Unique Size 447
# N Clusters:  448 , Silhouette Score:  0.07357577215105031 Result Unique Size 448
# N Clusters:  449 , Silhouette Score:  0.0727735674972367 Result Unique Size 449
# N Clusters:  450 , Silhouette Score:  0.07229146301114306 Result Unique Size 450
# N Clusters:  451 , Silhouette Score:  0.07172895615962648 Result Unique Size 451
# N Clusters:  452 , Silhouette Score:  0.07148756059990104 Result Unique Size 452
# N Clusters:  453 , Silhouette Score:  0.0687583954689989 Result Unique Size 453
# N Clusters:  454 , Silhouette Score:  0.06722534601054465 Result Unique Size 454
# N Clusters:  455 , Silhouette Score:  0.06786618571431487 Result Unique Size 455
# N Clusters:  456 , Silhouette Score:  0.06573266712263401 Result Unique Size 456
# N Clusters:  457 , Silhouette Score:  0.06475142835793725 Result Unique Size 457
# N Clusters:  458 , Silhouette Score:  0.06272666219742701 Result Unique Size 458
# N Clusters:  459 , Silhouette Score:  0.06164602282060588 Result Unique Size 459
# N Clusters:  460 , Silhouette Score:  0.05961977066076107 Result Unique Size 460
# N Clusters:  461 , Silhouette Score:  0.05999356626925165 Result Unique Size 461
# N Clusters:  462 , Silhouette Score:  0.05978977479090467 Result Unique Size 462
# N Clusters:  463 , Silhouette Score:  0.057851065550169285 Result Unique Size 463
# N Clusters:  464 , Silhouette Score:  0.05544878295661665 Result Unique Size 464
# N Clusters:  465 , Silhouette Score:  0.055492050360554844 Result Unique Size 465
# N Clusters:  466 , Silhouette Score:  0.05281245092360557 Result Unique Size 466
# N Clusters:  467 , Silhouette Score:  0.052180530483748974 Result Unique Size 467
# N Clusters:  468 , Silhouette Score:  0.050438567454901564 Result Unique Size 468
# N Clusters:  469 , Silhouette Score:  0.04930460447044729 Result Unique Size 469
# N Clusters:  470 , Silhouette Score:  0.04880076655662903 Result Unique Size 470
# N Clusters:  471 , Silhouette Score:  0.0461744091034222 Result Unique Size 471
# N Clusters:  472 , Silhouette Score:  0.04388681706798087 Result Unique Size 472
# N Clusters:  473 , Silhouette Score:  0.04016017799126414 Result Unique Size 473
# N Clusters:  474 , Silhouette Score:  0.03710588939527087 Result Unique Size 474
# N Clusters:  475 , Silhouette Score:  0.03534928906130392 Result Unique Size 475
# N Clusters:  476 , Silhouette Score:  0.033985448401164756 Result Unique Size 476
# N Clusters:  477 , Silhouette Score:  0.03294117949360017 Result Unique Size 477
# N Clusters:  478 , Silhouette Score:  0.03098393591308818 Result Unique Size 478
# N Clusters:  479 , Silhouette Score:  0.02825484415137607 Result Unique Size 479
# N Clusters:  480 , Silhouette Score:  0.027080426661937527 Result Unique Size 480
# N Clusters:  481 , Silhouette Score:  0.025813803205407698 Result Unique Size 481
# N Clusters:  482 , Silhouette Score:  0.025171545776693362 Result Unique Size 482
# N Clusters:  483 , Silhouette Score:  0.023098444327522328 Result Unique Size 483
# N Clusters:  484 , Silhouette Score:  0.021388749996076074 Result Unique Size 484
# N Clusters:  485 , Silhouette Score:  0.020446250944399023 Result Unique Size 485
# N Clusters:  486 , Silhouette Score:  0.020052950763216254 Result Unique Size 486
# N Clusters:  487 , Silhouette Score:  0.017663547439361733 Result Unique Size 487
# N Clusters:  488 , Silhouette Score:  0.014533914057233052 Result Unique Size 488
# N Clusters:  489 , Silhouette Score:  0.012558012063407594 Result Unique Size 489
# N Clusters:  490 , Silhouette Score:  0.011109882534858647 Result Unique Size 490
# N Clusters:  491 , Silhouette Score:  0.008499578477232945 Result Unique Size 491
# N Clusters:  492 , Silhouette Score:  0.007743347322726307 Result Unique Size 492
# N Clusters:  493 , Silhouette Score:  0.0032827064533055127 Result Unique Size 493
# [445 463 416 477 404 469 356 407 303 399 318 315 274 288 362 294 462 357
#  476 452 388 389 394 361 311 400 307 247 441 314 346 272 377 487 373 374
#  322 305 447 351 296 290 252 199 280 251 375 464 488 475 421 456 352 459
#  284 437 451 443 471 297 349 382 358 422 264 256 387 411 302 371 468 295
#  480 273 431 298 301 425 397 313 277 257 336 310 478 489 385 370 366 293
#  453 470 413 276 275 440 260 438 391 486 372 386 342 259 324 424 231 460
#  255 442 210 326 444 359 344 339 225 306 420 396 125 353 192 323 450 238
#  304 454 479 258 150 268 127 340 467 279 401 426 186 321 148 419 403 423
#  229 334 312 316 289 381 415 376 360 491 237 169 300 402 355 492 363 209
#  220 365 291 267 182 392 265 139 271 329 378 292 449 287 408 278 188 485
#  327 286 343 152 331 201 263 175 473 354 367 145 472 317 433 436 484 328
#  490 200 345 405 207 233 155 131 383 393 104 248 185 384 299 196 325 137
#  347 129 151 350 250 235 179 465 435 395 446 147 333 364 412 243 212 205
#  191 414 417 118 166   0 270 418   2 135 123 172 261 128 448 171 224 234
#  217 406 337 483 195 281 143  95 136 149 158 461 398 335 178   0  92 319
#    2 309 379 221 474 390  67 266 208 193 197 320 236 410 254 174 138 202
#  439 481 241 160 308  74 190 253 285 428  68 144 466 348 230 219 262 332
#  146 245 222 181 226 165 283 126 153 380 369 206 103 114 157 249  63 239
#  432 282 232 218 156 458 338 109 244 121 194 173 159  85 124 141 154 429
#  246 430 203 434 457  79 409  72 215  86 228  62  96 341 187 162  90 163
#  180 214  82 427 130 122 108 216 168 117 211 455 110 198 105  58 189 330
#  140  71 142 133 164  60 269 213 176  77  93  35  81 161 368  75 100 177
#  204  78 134 101  40  87  99  38  49 242 115  73  89 112  88 183 223 167
#  132 170 106  98  54  33  76  42  44  84 227 113  37  64  52 111  80 184
#   97  70  39  91  19 120  66 107 116  18  65  48  56 482  36 240 119  45
#   47  17  69 102  55  34  53  26  94  43  31  23  27  16  57  46  51  83
#   21   8  22  59  61  25  32  50  12  24  15  41  10  11   7  20   9  29
#    4  30  14  28   3  13   1   6   5]
# best cluster size 214
# best silhouette score 0.15678373174677612

# %%
cluster_size_silhouette_score_d
print(highest_score)
x = cluster_size_silhouette_score_d.values()
y = cluster_size_silhouette_score_d.keys()
plt.plot(y, x)
plt.xlabel('N-clusters')
plt.ylabel('Silhouette Score')
plt.show()
# Out:
# 0.15678373174677612

# %%
np_y = np.array(list(x))
np_y[np_y >= np.quantile(np_y, 0.80)]
# Out:
# array([0.15368521, 0.14143105, 0.13459806, 0.13746379, 0.1393827 ,
#        0.13818097, 0.1442761 , 0.14656809, 0.13637793, 0.13858604,
#        0.13594284, 0.13881432])

# %%
scores_df = pd.DataFrame.from_dict(cluster_size_silhouette_score_d, orient='index')
# scores_df.quantile(q=0.9)
scores_df[scores_df[0] >= scores_df[0].quantile(q=0.9)][0]
# Out:
# 7     0.153685
# 8     0.141431
# 19    0.139383
# 29    0.144276
# 30    0.146568
# 42    0.138814
# Name: 0, dtype: float64

# %%
# optimal_cluster_size = cluster_size_silhouette_score_d[highest_score]
# optimal_cluster_size = 58
print("highest_score: ", highest_score)
print("optimal_cluster_size: ", optimal_cluster_size)
result = AgglomerativeClustering(n_clusters=optimal_cluster_size, affinity='euclidean', linkage='ward').fit_predict(user_movie_tags_df.values[:n_movies])
np.unique(result).size
new_df = pd.DataFrame(result, columns = ['cluster'])

# len(user_movies_d[user_id])
# new_df['movie'] = user_movies_d[user_id]
new_df['movie'] = user_movie_tags_df.index.values[:n_movies]

# cluster ranking and sorting in ascending order
print('cluster ranks', (new_df.groupby('cluster')['movie'].count()/new_df.size).sort_values().index.tolist())

print(new_df.size)
clusters = new_df.groupby('cluster')['movie'].apply(list)
clusters
# new_df
# new_df.set_index(user_movies_d[user_x], drop=True, inplace=True)
# kmeans.labels_
# genome_tags_df['tag'].values.size
# Out:
# highest_score:  0.1536852131220328
# optimal_cluster_size:  7
# cluster ranks [4, 5, 6, 2, 0, 3, 1]
# 122
# cluster
# 0    [70, 908, 1249, 1259, 1673, 2291, 2858, 2948, ...
# 1    [3, 62, 242, 469, 1121, 1327, 1965, 2454, 2455...
# 2         [110, 260, 480, 589, 1196, 1210, 1270, 1580]
# 3    [891, 1969, 1970, 1971, 1972, 1973, 1974, 1986...
# 4                              [266, 3513, 3555, 3753]
# 5                               [541, 924, 1214, 1748]
# 6                 [1356, 1544, 3926, 3927, 3937, 3959]
# Name: movie, dtype: object

# %%
cluster_size_df = pd.DataFrame(index=clusters.index)
# cluster_size_df

def process(x):
    x['size'] = len(clusters[x.name])
    
    return x

cluster_size_df['size'] = None
cluster_size_df

cluster_size_df.apply(lambda x: process(x), axis=1)
# Out:
#          size
# cluster
# 0          11
# 1          17
# 2           8
# 3          11
# 4           4
# 5           4
# 6           6

# %%
# below_mean_clusters_df['rank'] = below_mean_clusters_df.rank(method='dense')
from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# smaller the cluster size, higher the score
cluster_size_df['Cluster_Score'] = cluster_size_df.rank(method='dense', ascending=False).astype(np.int)
# cluster_size_df['rank'] = scaler.fit_transform(cluster_size_df['rank'].values.reshape(-1, 1))
cluster_size_df
# below_mean_clusters_df
# Out:
#         size  Cluster_Score
# cluster
# 0         11              2
# 1         17              1
# 2          8              3
# 3         11              2
# 4          4              5
# 5          4              5
# 6          6              4

# %%
cluster_size_df.shape
# Out:
# (7, 2)

# %%
# clusters
# dict(map(reversed, d.items()))
# pd.DataFrame(d)
num = 70
# num in d.values()

def cluster_movie_cluster_id(num):
    for cluster in clusters.index.tolist():
        if num in clusters[cluster]:
            return cluster_size_df.loc[cluster, ['rank']].values[0]
    
    return 0

cluster_movie_cluster_id(num)
# cluster_size_df.loc[0, ['rank']]
# cluster_size_df[0]

# len(d.keys())
# list(d.values())[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-0bb608890ca4> in <module>
#      12     return 0
#      13
# ---> 14 cluster_movie_cluster_id(num)
#      15 # cluster_size_df.loc[0, ['rank']]
#      16 # cluster_size_df[0]
#
# <ipython-input-42-0bb608890ca4> in cluster_movie_cluster_id(num)
#       8     for cluster in clusters.index.tolist():
#       9         if num in clusters[cluster]:
# ---> 10             return cluster_size_df.loc[cluster, ['rank']].values[0]
#      11
#      12     return 0
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     866     def _getitem_tuple(self, tup):
#     867         try:
# --> 868             return self._getitem_lowerdim(tup)
#     869         except IndexingError:
#     870             pass
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1015                     return section
#    1016                 # This is an elided recursive call to iloc/loc/etc'
# -> 1017                 return getattr(section, self.name)[new_key]
#    1018
#    1019         raise IndexingError('not applicable')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1900                     raise ValueError('Cannot index with multidimensional key')
#    1901
# -> 1902                 return self._getitem_iterable(key, axis=axis)
#    1903
#    1904             # nested tuple slicing
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1203             # A collection of keys
#    1204             keyarr, indexer = self._get_listlike_indexer(key, axis,
# -> 1205                                                          raise_missing=False)
#    1206             return self.obj._reindex_with_indexers({axis: [keyarr, indexer]},
#    1207                                                    copy=True, allow_dups=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['rank'], dtype='object')] are in the [index]"

# %%
below_mean_clusters_df['rank'].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-00f456d05557> in <module>
# ----> 1 below_mean_clusters_df['rank'].values
#
# NameError: name 'below_mean_clusters_df' is not defined

# %%
# map movie to its cluster#
new_df[new_df['movie'] == 2]['cluster'].values[0]
# Out:
# 4
