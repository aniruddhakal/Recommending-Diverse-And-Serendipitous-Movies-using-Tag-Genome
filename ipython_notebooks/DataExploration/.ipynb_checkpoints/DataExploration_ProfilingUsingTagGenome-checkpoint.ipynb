# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_base_dir = '../../../datasets/Movielens/'
data_dir2 = data_base_dir + 'Movielens Latest/ml-latest/'
data_dir = data_base_dir + 'ml-20m/'

genome_scores = data_dir + 'genome-scores.csv'
genome_tags = data_dir + 'genome-tags.csv'
movies = data_dir + 'movies.csv'
ratings = data_dir + 'ratings.csv'
tags = data_dir + 'tags.csv'

# %%
# movies_df = pd.read_csv(movies)
# movies_df
genome_scores_df = pd.read_csv(genome_scores)
genome_score_movies = genome_scores_df['movieId'].unique()

ratings_df = pd.read_csv(ratings, usecols=range(3), dtype={'userId':np.int64, 'movieId':np.int64, 'rating':np.float64}, low_memory=False)
ratings_df = ratings_df[ratings_df['movieId'].isin(genome_score_movies)]
ratings_df
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# 5              1      112     3.5
# 6              1      151     4.0
# 7              1      223     4.0
# 8              1      253     4.0
# 9              1      260     4.0
# 10             1      293     4.0
# 11             1      296     4.0
# 12             1      318     4.0
# 13             1      337     3.5
# 14             1      367     3.5
# 15             1      541     4.0
# 16             1      589     3.5
# 17             1      593     3.5
# 18             1      653     3.0
# 19             1      919     3.5
# 20             1      924     3.5
# 21             1     1009     3.5
# 22             1     1036     4.0
# 23             1     1079     4.0
# 24             1     1080     3.5
# 25             1     1089     3.5
# 26             1     1090     4.0
# 27             1     1097     4.0
# 28             1     1136     3.5
# 29             1     1193     3.5
# ...          ...      ...     ...
# 20000232  138493    50601     3.5
# 20000233  138493    50872     3.5
# 20000234  138493    51086     3.5
# 20000235  138493    51662     4.5
# 20000236  138493    51884     4.5
# 20000237  138493    52579     4.0
# 20000238  138493    52975     4.0
# 20000239  138493    53123     4.0
# 20000240  138493    53125     3.0
# 20000241  138493    53322     4.0
# 20000242  138493    53464     4.0
# 20000243  138493    53996     4.5
# 20000244  138493    55269     5.0
# 20000245  138493    55814     5.0
# 20000246  138493    56757     3.0
# 20000247  138493    56801     3.0
# 20000248  138493    58879     4.5
# 20000249  138493    59315     4.0
# 20000250  138493    59725     3.0
# 20000251  138493    59784     5.0
# 20000252  138493    60069     4.0
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [19800443 rows x 3 columns]

# %%
# genome_scores_df = genome_scores_df.pivot(index='movieId', columns='tagId', values='relevance')
# file_name = 'threshold_0.4_float_movie_genomes_bz2'
file_name = 'movies_lemmatized_threshold_0.25_float_movie_genomes_bz2'
genome_scores_df = pd.read_pickle(data_dir + '/output/' + file_name, compression='bz2')
genome_scores_df
# Out:
#              007    1920s    1930s    1950s    1960s    1970s    1980s  \
# movieId
# 1        0.00000  0.09675  0.14675  0.21700  0.06700  0.26275  0.26200
# 2        0.08350  0.04800  0.11025  0.07250  0.04775  0.10975  0.09925
# 3        0.09825  0.07700  0.00000  0.06850  0.05600  0.18500  0.04925
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.057750      0.080500      0.162500      0.020250      0.009250
# 50%        0.080750      0.166250      0.219750      0.027000      0.013000
# 75%        0.136000      0.284750      0.302250      0.038062      0.021250
# max        0.996750      1.505500      0.980000      0.999750      0.997500
#
#              zombie
# count  10380.000000
# mean       0.123272
# std        0.183958
# min        0.000000
# 25%        0.069750
# 50%        0.100000
# 75%        0.128000
# max        1.989000
#
# [8 rows x 702 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

n_clusters = [2, 3, 4, 5, 6, 8, 10, 12, 15, 17, 20, 25]
metrics = ['cosine', 'euclidean', 'cityblock', 'braycurtis', 'canberra', 'chebyshev', 'correlation', 'dice', 'hamming', 'jaccard', 'kulsinski', 'mahalanobis', 'minkowski', 'rogerstanimoto', 'russellrao', 'seuclidean', 'sokalmichener', 'sokalsneath', 'sqeuclidean', 'yule']
# cosine_ eps = [0.04, 0.07, 0.1, 0.11, 0.13, 0.15, 0.17, 0.2, 0.25, 0.27, 0.29, 0.3, 0.35]
eps = [0.04, 0.07, 0.1, 0.11, 0.13, 0.15, 0.17, 0.2, 0.25, 0.27, 0.29, 0.3, 0.35]
# for e in eps:
for cluster_size in range(2, 100, 5):
# with cluster_size as 1100:
# cluster_size = 700
#     for metric in metrics:
    result = KMeans(n_clusters=cluster_size, random_state=171450, n_jobs=-1).fit_predict(genome_scores_df.values)
#     print("e", e)
    
#     result = DBSCAN(eps=e, metric='cosine').fit_predict(genome_scores_df.values)

    # linkage : {“ward”, “complete”, “average”, “single”}
#     result = AgglomerativeClustering(n_clusters=cluster_size, affinity='euclidean', linkage='ward').fit_predict(genome_scores_df.values)

    score = silhouette_score(genome_scores_df.values, result)
    print("N Clusters: ", cluster_size, ", Silhouette Score: ", score, "Result Unique Size", np.unique(result).size)
#     print("EPS: ", e, ", Silhouette Score: ", score, "Result Unique Size", np.unique(result).size)
#     print(", Silhouette Score: ", score, ", Metric: ", metric)
# result.tolist()
# result = kmeans.predict(genome_scores_df.values)
# result
# silhouette_score(genome_scores_df.values)
# Out:
# N Clusters:  2 , Silhouette Score:  0.1744646733869272 Result Unique Size 2
# N Clusters:  7 , Silhouette Score:  0.06814525400572943 Result Unique Size 7
# N Clusters:  12 , Silhouette Score:  0.06471435571374477 Result Unique Size 12
# N Clusters:  17 , Silhouette Score:  0.060764266458886815 Result Unique Size 17
# N Clusters:  22 , Silhouette Score:  0.06179578352131875 Result Unique Size 22
# N Clusters:  27 , Silhouette Score:  0.0614509154482531 Result Unique Size 27
# N Clusters:  32 , Silhouette Score:  0.05753023252665672 Result Unique Size 32
# N Clusters:  37 , Silhouette Score:  0.057836438392839015 Result Unique Size 37
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-7ce2e64e33cc> in <module>
#      13 # cluster_size = 700
#      14 #     for metric in metrics:
# ---> 15     result = KMeans(n_clusters=cluster_size, random_state=171450, n_jobs=-1).fit_predict(genome_scores_df.values)
#      16 #     print("e", e)
#      17
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/k_means_.py in fit_predict(self, X, y, sample_weight)
#     995             Index of the cluster each sample belongs to.
#     996         """
# --> 997         return self.fit(X, sample_weight=sample_weight).labels_
#     998
#     999     def fit_transform(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/k_means_.py in fit(self, X, y, sample_weight)
#     969                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     970                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 971                 return_n_iter=True)
#     972         return self
#     973
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     396                                    # Change seed to ensure variety
#     397                                    random_state=seed)
# --> 398             for seed in seeds)
#     399         # Get results with the lowest inertia
#     400         labels, inertia, centers, n_iters = zip(*results)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# /usr/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

n_clusters = [2, 3, 4, 5, 6, 8, 10, 12, 15, 17, 20, 25]
metrics = ['cosine', 'euclidean', 'cityblock', 'braycurtis', 'canberra', 'chebyshev', 'correlation', 'dice', 'hamming', 'jaccard', 'kulsinski', 'mahalanobis', 'minkowski', 'rogerstanimoto', 'russellrao', 'seuclidean', 'sokalmichener', 'sokalsneath', 'sqeuclidean', 'yule']
# cosine_ eps = [0.04, 0.07, 0.1, 0.11, 0.13, 0.15, 0.17, 0.2, 0.25, 0.27, 0.29, 0.3, 0.35]
eps = [0.04, 0.07, 0.1, 0.11, 0.13, 0.15, 0.17, 0.2, 0.25, 0.27, 0.29, 0.3, 0.35]
for e in eps[1:]:
# for cluster_size in range(150,900, 30):
# with cluster_size as 1100:
# cluster_size = 700
#     for metric in metrics:
#     result = KMeans(n_clusters=cluster_size, random_state=171450, n_jobs=-1).fit_predict(genome_scores_df.values)
#     print("e", e)
    
    result = DBSCAN(eps=e, metric='cosine').fit_predict(genome_scores_df.values)

    # linkage : {“ward”, “complete”, “average”, “single”}
#     result = AgglomerativeClustering(n_clusters=cluster_size, affinity='euclidean', linkage='ward').fit_predict(genome_scores_df.values)

    score = silhouette_score(genome_scores_df.values, result)
#     print("N Clusters: ", cluster_size, ", Silhouette Score: ", score, "Result Unique Size", np.unique(result).size)
    print("EPS: ", e, ", Silhouette Score: ", score, "Result Unique Size", np.unique(result).size)
#     print(", Silhouette Score: ", score, ", Metric: ", metric)
# result.tolist()
# result = kmeans.predict(genome_scores_df.values)
# result
# silhouette_score(genome_scores_df.values)
# Out:
# EPS:  0.07 , Silhouette Score:  -0.1980779212933372 Result Unique Size 27
# EPS:  0.1 , Silhouette Score:  -0.027744617535022283 Result Unique Size 4
# EPS:  0.11 , Silhouette Score:  -0.018905033594489914 Result Unique Size 4
# EPS:  0.13 , Silhouette Score:  0.007207571946548393 Result Unique Size 2
# EPS:  0.15 , Silhouette Score:  -0.0030695347557712195 Result Unique Size 2
# EPS:  0.17 , Silhouette Score:  -0.01079702187564545 Result Unique Size 2
# EPS:  0.2 , Silhouette Score:  -0.01748933381636901 Result Unique Size 2
# EPS:  0.25 , Silhouette Score:  -0.0162044702259937 Result Unique Size 2
# EPS:  0.27 , Silhouette Score:  -0.00819931950234936 Result Unique Size 2
# EPS:  0.29 , Silhouette Score:  -0.0002170245789662934 Result Unique Size 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-a028fe2dbfb4> in <module>
#      16 #     print("e", e)
#      17
# ---> 18     result = DBSCAN(eps=e, metric='cosine').fit_predict(genome_scores_df.values)
#      19
#      20     # linkage : {“ward”, “complete”, “average”, “single”}
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/dbscan_.py in fit_predict(self, X, y, sample_weight)
#     351             cluster labels
#     352         """
# --> 353         self.fit(X, sample_weight=sample_weight)
#     354         return self.labels_
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/dbscan_.py in fit(self, X, y, sample_weight)
#     319         X = check_array(X, accept_sparse='csr')
#     320         clust = dbscan(X, sample_weight=sample_weight,
# --> 321                        **self.get_params())
#     322         self.core_sample_indices_, self.labels_ = clust
#     323         if len(self.core_sample_indices_):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/dbscan_.py in dbscan(X, eps, min_samples, metric, metric_params, algorithm, leaf_size, p, sample_weight, n_jobs)
#     159         # This has worst case O(n^2) memory complexity
#     160         neighborhoods = neighbors_model.radius_neighbors(X, eps,
# --> 161                                                          return_distance=False)
#     162
#     163     if sample_weight is None:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/base.py in radius_neighbors(self, X, radius, return_distance)
#     724                 results = dist, neigh_ind
#     725             else:
# --> 726                 neigh_ind_list = sum(results, [])
#     727                 results = np.empty(len(neigh_ind_list), dtype='object')
#     728                 results[:] = neigh_ind_list
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1309         if reduce_func is not None:
#    1310             chunk_size = D_chunk.shape[0]
# -> 1311             D_chunk = reduce_func(D_chunk, sl.start)
#    1312             _check_chunk_size(D_chunk, chunk_size)
#    1313         yield D_chunk
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/base.py in _radius_neighbors_reduce_func(self, dist, start, radius, return_distance)
#     604         neigh : list of n_samples_chunk 1d arrays
#     605         """
# --> 606         neigh_ind = [np.where(d <= radius)[0] for d in dist]
#     607
#     608         if return_distance:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/base.py in <listcomp>(.0)
#     604         neigh : list of n_samples_chunk 1d arrays
#     605         """
# --> 606         neigh_ind = [np.where(d <= radius)[0] for d in dist]
#     607
#     608         if return_distance:
#
# KeyboardInterrupt:

# %%
from sklearn.decomposition import PCA

# result = PCA(n_components=10).fit_transform(genome_scores_df.values)
result = PCA(n_components=400).fit(genome_scores_df.values)
result
# Out:
# PCA(copy=True, iterated_power='auto', n_components=400, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
result.explained_variance_.sum()
# Out:
# 35.91605607796155

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering

# e = 0.095
eps = [0.04, 0.07, 0.1, 0.11, 0.13, 0.15, 0.17, 0.2, 0.25, 0.27, 0.29, 0.3, 0.35]
e = 0.105
# for e in eps:
metric = 'cosine'
# metrics = ['cosine', 'euclidean', 'cityblock', 'braycurtis', 'canberra', 'chebyshev', 'correlation', 'dice', 'hamming', 'jaccard', 'kulsinski', 'mahalanobis', 'minkowski', 'rogerstanimoto', 'russellrao', 'seuclidean', 'sokalmichener', 'sokalsneath', 'sqeuclidean', 'yule']
result = DBSCAN(eps=e, metric=metric).fit_predict(genome_scores_df.values)

# linkage : {“ward”, “complete”, “average”, “single”}

# result = AgglomerativeClustering(affinity='cosine', 'linkage='ward')
score = silhouette_score(genome_scores_df.values, result)
print("EPS: ", e, ", Silhouette Score: ", score)

np.unique(result)


movie_clusters_df = pd.DataFrame(index=genome_scores_df.index.values)
movie_clusters_df['cluster'] = result
movie_clusters_df['dummy'] = 1

count_df = movie_clusters_df.groupby('cluster').count()
count_df['dummy'].tolist()
# Out:
# EPS:  0.105 , Silhouette Score:  -0.012012122587014926
# [3050, 7325, 5]

# %%
# from __future__ import print_function

# from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, genome_scores_df.values.size + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(genome_scores_df.values)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(genome_scores_df.values, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(genome_scores_df.values, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.13071085073696848
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-79f06706b75d> in <module>
#      74     # 2nd Plot showing the actual clusters formed
#      75     colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
# ---> 76     ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
#      77                 c=colors, edgecolor='k')
#      78
#
# NameError: name 'X' is not defined

# %%
# ratings_df[ratings_df['userId'] == 33]
users_whole_count = ratings_df['userId'].unique().size

# %%
# user's watched movies:
user_id = 10
# type(ratings_matrix_df.loc[user_id, :][3]
# ratings_matrix_df.loc[user_id, :].notnull()
# ratings_matrix_df.index[ratings_matrix_df[user_id].notnull()]
ratings_df[ratings_df['userId'] == user_id]['movieId'].values
# Out:
# array([   1,   11,   25,  260,  356,  527,  858,  912,  969, 1094, 1136,
#        1196, 1198, 1204, 1208, 1210, 1221, 1222, 1230, 1240, 1242, 1247,
#        1250, 1304, 1387, 1721, 1960, 2028, 2058, 2194, 2384, 2529, 2657,
#        2797, 2944, 2948, 3062, 3107])

# %%
# len(user_movies_d[7])
# user_movie_tags_df = pd.DataFrame(index=user_movies_d[1], columns=range(1, 1129))

# collect tag genome scores for all movies that user X has watched

user_id = 1
user_movie_tags_df = pd.DataFrame()
user_movies = ratings_df[ratings_df['userId'] == user_id]['movieId'].values
# print(len(user_movies_d[user_x]))
# user_movie_tags_df = genome_scores_df[genome_scores_df.index.isin(user_movies_d[user_x])]
user_movie_tags_df = genome_scores_df[genome_scores_df.index.isin(user_movies)]

user_movie_tags_df
# Out:
# 6754       0.06950  0.06025  0.19325  0.03500  0.01425  0.29000
# 6755       0.23125  0.27925  0.23550  0.05475  0.01625  0.53725
# 6774       0.09650  0.21650  0.35300  0.02325  0.00000  0.23350
# 6807       0.31875  0.36975  0.19875  0.06250  0.02125  0.11650
# 6888       0.08150  0.11275  0.32400  0.03075  0.00000  0.16425
# 7001       0.00000  0.26050  0.19275  0.03300  0.01150  0.31025
# 7045       0.08125  0.14875  0.20575  0.02900  0.01425  0.01800
# 7046       0.11000  0.22525  0.22400  0.02550  0.01325  0.09950
# 7153       0.06450  0.34400  0.00000  0.07125  0.03700  0.10400
# 7164       0.06050  0.05400  0.00000  0.02950  0.00000  0.00000
# 7247       0.00000  0.00000  0.00000  0.02375  0.04450  0.00000
# 7387       0.08825  0.33250  0.17725  0.03525  0.01500  1.94550
# 7389       0.06525  0.00000  0.00000  0.04625  0.01025  0.23075
# 7438       0.11875  0.66425  0.20925  0.98725  0.01575  0.02225
# 7449       0.06700  0.11775  0.32450  0.00000  0.00000  0.09300
# 7454       0.05800  0.05450  0.20150  0.02825  0.00000  0.49275
# 7482       0.07950  0.25525  0.00000  0.53400  0.01725  0.15675
# 7757       0.11175  0.19875  0.00000  0.04775  0.01125  0.22375
# 8368       0.00000  0.21125  0.20825  0.02725  0.00975  0.01850
# 8482       0.13950  0.29825  0.22975  0.02600  0.01925  0.08975
# 8507       0.09375  0.37800  0.18100  0.03600  0.01225  0.30475
# 8636       0.08400  0.18225  0.25850  0.06500  0.01400  0.15600
# 8690       0.06300  0.48400  0.35575  0.03925  0.46575  0.01850
# 8961       0.14200  0.20950  0.00000  0.02800  0.01700  0.13175
# 31696      0.06025  0.15200  0.34425  0.00000  0.01150  0.15375
#
# [174 rows x 702 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

# cluster_size = 8
n_movies = user_movie_tags_df.index.size

random_state = 171450

cluster_size_silhouette_score_d = dict()
highest_score = 0

for cluster_size in range(2, n_movies-1, 1):
#     kmeans = KMeans(n_clusters=cluster_size, random_state=random_state, n_jobs=-1).fit(user_movie_tags_df.values)
    result = AgglomerativeClustering(n_clusters=cluster_size, affinity='euclidean', linkage='ward').fit_predict(user_movie_tags_df.values[:n_movies])

#     result = kmeans.predict(user_movie_tags_df.values)

    score = silhouette_score(user_movie_tags_df.values[:n_movies], result)
    
    score_list = list()
    
#     if cluster_size in cluster_size_silhouette_score_d:
#             score_list = cluster_size_silhouette_score_d[cluster_size]
    
#     score_list.append(score)
    
    cluster_size_silhouette_score_d[cluster_size] = score
    if score >= highest_score:
        highest_score = score
    print("N Clusters: ", cluster_size, ", Silhouette Score: ", score, "Result Unique Size", np.unique(result).size)

result
# cluster_size_silhouette_score_d
# Out:
# N Clusters:  2 , Silhouette Score:  0.14970924001577313 Result Unique Size 2
# N Clusters:  3 , Silhouette Score:  0.11079243073172025 Result Unique Size 3
# N Clusters:  4 , Silhouette Score:  0.1269858900100462 Result Unique Size 4
# N Clusters:  5 , Silhouette Score:  0.11559245264735253 Result Unique Size 5
# N Clusters:  6 , Silhouette Score:  0.1036049041040094 Result Unique Size 6
# N Clusters:  7 , Silhouette Score:  0.11002499060449475 Result Unique Size 7
# N Clusters:  168 , Silhouette Score:  0.03082613529354331 Result Unique Size 168
# N Clusters:  169 , Silhouette Score:  0.027135983939805788 Result Unique Size 169
# N Clusters:  170 , Silhouette Score:  0.02190254327482078 Result Unique Size 170
# N Clusters:  171 , Silhouette Score:  0.015822995269722025 Result Unique Size 171
# N Clusters:  172 , Silhouette Score:  0.0050766887820475086 Result Unique Size 172
# array([119,  94, 107, 101, 126, 105, 153, 102, 120, 158, 141, 161,  86,
#        162, 104, 103, 170, 143, 129, 139, 135, 154, 149, 110,  80,  89,
#         51, 131,  50,  99, 128, 147, 144,  87, 146, 111, 100, 132, 133,
#         90, 106, 145, 142,  72, 136, 171, 165, 138, 130, 123, 155, 117,
#         65, 109, 167, 159, 108,  59, 157, 160, 152, 118, 156, 134, 140,
#        125, 124,  88,  66, 121,  67,  54,  77, 151, 137, 122,  97, 113,
#         58, 116, 169,  84,  75,  49, 127,  79,  53,  93, 168,  92,  63,
#        166,  96,  43,  46,  91,  60, 163,  76,  44,  98,  39,  37,  68,
#         64,  71, 114, 148,  83,  35,  26,  95,  85,  33,  70,  29,  73,
#         24, 115,  47, 164,  61,  62,  48, 112,  30,   0,  31,  78, 150,
#         45,   2,  55,  14,  69,  52,  38,  32,  41,  21,   0,  22,   2,
#         15,  34,  81,  82,  56,  74,  36,  18,  40,  16,   7,  17,  57,
#         28,  42,  27,  10,   8,  13,   3,  20,  23,  11,  19,   9,  25,
#          4,   6,  12,   5,   1])

# %%
cluster_size_silhouette_score_d
x = cluster_size_silhouette_score_d.values()
y = cluster_size_silhouette_score_d.keys()
plt.plot(y, x)
plt.xlabel('N-clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
np_y = np.array(list(x))
np_y[np_y >= np.quantile(np_y, 0.80)]
# Out:
# array([0.15379256, 0.15397433, 0.15552167, 0.15958789, 0.157002  ,
#        0.15791176, 0.15445079, 0.15474278, 0.1537436 , 0.15490407,
#        0.1553431 , 0.15395956, 0.15476531, 0.15629358, 0.15814577,
#        0.15710365, 0.15591462, 0.15580609, 0.15600528, 0.1573692 ,
#        0.15858536, 0.15907839, 0.15735231, 0.15692316, 0.15634181,
#        0.15600076, 0.15650703, 0.15497998, 0.15529544, 0.15434692,
#        0.1540462 , 0.15403704, 0.15363193, 0.15517693, 0.15421595])

# %%
scores_df = pd.DataFrame.from_dict(cluster_size_silhouette_score_d, orient='index')
# scores_df.quantile(q=0.9)
scores_df[scores_df[0] >= scores_df[0].quantile(q=0.9)][0]
# Out:
# 43    0.155522
# 44    0.159588
# 45    0.157002
# 46    0.157912
# 58    0.156294
# 59    0.158146
# 60    0.157104
# 61    0.155915
# 62    0.155806
# 63    0.156005
# 64    0.157369
# 65    0.158585
# 66    0.159078
# 67    0.157352
# 68    0.156923
# 69    0.156342
# 70    0.156001
# 71    0.156507
# Name: 0, dtype: float64

# %%
# optimal_cluster_size = cluster_size_silhouette_score_d[highest_score]
optimal_cluster_size = 58
print("highest_score: ", highest_score)
print("optimal_cluster_size: ", optimal_cluster_size)
result = AgglomerativeClustering(n_clusters=optimal_cluster_size, affinity='euclidean', linkage='ward').fit_predict(user_movie_tags_df.values[:n_movies])
np.unique(result).size
new_df = pd.DataFrame(result, columns = ['cluster'])

# len(user_movies_d[user_id])
# new_df['movie'] = user_movies_d[user_id]
new_df['movie'] = user_movie_tags_df.index.values[:n_movies]

# cluster ranking and sorting in ascending order
print((new_df.groupby('cluster')['movie'].count()/new_df.size).sort_values().index.tolist())

print(new_df.size)
clusters = new_df.groupby('cluster')['movie'].apply(list)
clusters
# new_df
# new_df.set_index(user_movies_d[user_x], drop=True, inplace=True)
# kmeans.labels_
# genome_tags_df['tag'].values.size
# Out:
# highest_score:  0.15958789473867466
# optimal_cluster_size:  58
# [56, 51, 47, 28, 29, 31, 33, 34, 36, 37, 38, 43, 26, 44, 45, 49, 50, 52, 53, 54, 41, 24, 57, 7, 20, 17, 15, 23, 46, 39, 48, 6, 35, 3, 30, 18, 19, 27, 55, 21, 8, 9, 1, 5, 40, 11, 22, 12, 13, 14, 0, 4, 2, 25, 42, 16, 32, 10]
# 348
# cluster
# 0                            [47, 50, 593, 4226]
# 1                         [32, 2692, 2959, 4878]
# 2                 [1370, 3889, 4915, 5040, 5898]
# 3                            [6754, 7454, 31696]
# 4                  [253, 2118, 5146, 7046, 8690]
# 5                       [2872, 3081, 5026, 7482]
# 6                             [2918, 4128, 4571]
# 7                                    [924, 1584]
# 8                             [2021, 2968, 4467]
# 9                              [223, 1243, 4027]
# 10     [112, 1920, 4133, 4941, 4980, 5999, 7389]
# 11                      [3476, 4754, 6774, 8507]
# 12                       [296, 1089, 2542, 4011]
# 13                       [293, 1249, 3265, 7438]
# 14                      [1079, 1080, 1136, 6807]
# 15                                  [1374, 2628]
# 16    [1215, 1261, 1321, 2174, 4105, 6755, 7387]
# 17                                  [4306, 8961]
# 18                            [2138, 2761, 3000]
# 19                            [1219, 1333, 4720]
# 20                                   [151, 2100]
# 21                            [5679, 6242, 6502]
# 22                      [1350, 1387, 1994, 1997]
# 23                            [6093, 7045, 7164]
# 24                                    [29, 2291]
# 25                [1525, 2173, 2253, 4911, 5797]
# 26                                  [2716, 6539]
# 27                            [3153, 5540, 7757]
# 28                                  [4446, 5171]
# 29                                   [919, 1097]
# 30                            [2288, 2664, 7001]
# 31                                  [1198, 1291]
# 32     [653, 1967, 2140, 2143, 2193, 3479, 5039]
# 33                                  [1036, 2947]
# 34                                   [337, 8482]
# 35                            [1090, 1208, 1222]
# 36                                   [367, 3438]
# 37                                   [318, 2762]
# 38                                   [260, 1196]
# 39                            [1193, 1266, 1358]
# 40                      [1348, 2644, 2648, 3932]
# 41                                  [1246, 1259]
# 42             [2, 1009, 1750, 1848, 3489, 7247]
# 43                                   [589, 1240]
# 44                                  [1200, 1214]
# 45                                  [1262, 2944]
# 46                            [1201, 1304, 3037]
# 47                                        [3996]
# 48                            [4993, 5952, 7153]
# 49                                  [6333, 8636]
# 50                                  [1278, 2804]
# 51                                         [541]
# 52                                  [1217, 3030]
# 53                                  [2683, 6888]
# 54                                  [3997, 7449]
# 55                            [4896, 5816, 8368]
# 56                                        [2194]
# 57                                  [1258, 3499]
# Name: movie, dtype: object

# %%
cluster_size_df = pd.DataFrame(index=clusters.index)
# cluster_size_df

def process(x):
    x['size'] = len(clusters[x.name])
    
    return x

cluster_size_df['size'] = None
cluster_size_df

cluster_size_df.apply(lambda x: process(x), axis=1)
# Out:
#          size
# cluster
# 0           5
# 1          10
# 2           3
# 3           4
# 4           6
# 5           3
# 6           3
# 7           2
# 8           4
# 9           5
# 10         11
# 11          3
# 12          2
# 13          2
# 14          2
# 15          3
# 16          3
# 17          2
# 18          2
# 19          9
# 20          2
# 21          2
# 22          4
# 23          2
# 24          3
# 25          5
# 26          2
# 27          2
# 28          3
# 29          3
# 30          3
# 31          3
# 32          2
# 33          3
# 34          3
# 35          2
# 36          2
# 37          2
# 38          2
# 39          2
# 40          5
# 41          2
# 42          2
# 43          2
# 44          2
# 45          3
# 46          2
# 47          1
# 48          2
# 49          2
# 50          3
# 51          1
# 52          2
# 53          1
# 54          2
# 55          1
# 56          3
# 57          2

# %%
# below_mean_clusters_df['rank'] = below_mean_clusters_df.rank(method='dense')
from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# smaller the cluster size, higher the score
cluster_size_df['Cluster_Score'] = cluster_size_df.rank(method='dense', ascending=False).astype(np.int)
# cluster_size_df['rank'] = scaler.fit_transform(cluster_size_df['rank'].values.reshape(-1, 1))
cluster_size_df
# below_mean_clusters_df
# Out:
#         size  Cluster_Score
# cluster
# 0         10              3
# 1          7              5
# 2          7              5
# 3         14              1
# 4         11              2
# 5          4              8
# 6          4              8
# 7         10              3
# 8          4              8
# 9          4              8
# 10         4              8
# 11         7              5
# 12         4              8
# 13         4              8
# 14         3              9
# 15         4              8
# 16         3              9
# 17         7              5
# 18         4              8
# 19         9              4
# 20        11              2
# 21         6              6
# 22        11              2
# 23         3              9
# 24         4              8
# 25         5              7
# 26         4              8
# 27         3              9
# 28         3              9

# %%
cluster_size_df.shape
# Out:
# (29, 2)

# %%
# clusters
# dict(map(reversed, d.items()))
# pd.DataFrame(d)
num = 2021
# num in d.values()

def cluster_movie_cluster_id(num):
    for cluster in clusters.index.tolist():
        if num in clusters[cluster]:
            return cluster_size_df.loc[cluster, ['rank']].values[0]
    
    return 0

cluster_movie_cluster_id(2021)
# cluster_size_df.loc[0, ['rank']]
# cluster_size_df[0]

# len(d.keys())
# list(d.values())[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-170-7a5b415ba469> in <module>
#      12     return 0
#      13
# ---> 14 cluster_movie_cluster_id(2021)
#      15 # cluster_size_df.loc[0, ['rank']]
#      16 # cluster_size_df[0]
#
# <ipython-input-170-7a5b415ba469> in cluster_movie_cluster_id(num)
#       8     for cluster in clusters.index.tolist():
#       9         if num in clusters[cluster]:
# ---> 10             return cluster_size_df.loc[cluster, ['rank']].values[0]
#      11
#      12     return 0
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     866     def _getitem_tuple(self, tup):
#     867         try:
# --> 868             return self._getitem_lowerdim(tup)
#     869         except IndexingError:
#     870             pass
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1015                     return section
#    1016                 # This is an elided recursive call to iloc/loc/etc'
# -> 1017                 return getattr(section, self.name)[new_key]
#    1018
#    1019         raise IndexingError('not applicable')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1900                     raise ValueError('Cannot index with multidimensional key')
#    1901
# -> 1902                 return self._getitem_iterable(key, axis=axis)
#    1903
#    1904             # nested tuple slicing
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1203             # A collection of keys
#    1204             keyarr, indexer = self._get_listlike_indexer(key, axis,
# -> 1205                                                          raise_missing=False)
#    1206             return self.obj._reindex_with_indexers({axis: [keyarr, indexer]},
#    1207                                                    copy=True, allow_dups=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['rank'], dtype='object')] are in the [index]"

# %%
below_mean_clusters_df['rank'].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-164-00f456d05557> in <module>
# ----> 1 below_mean_clusters_df['rank'].values
#
# NameError: name 'below_mean_clusters_df' is not defined

# %%
# map movie to its cluster#
new_df[new_df['movie'] == 2]['cluster'].values[0]
# Out:
# 4
