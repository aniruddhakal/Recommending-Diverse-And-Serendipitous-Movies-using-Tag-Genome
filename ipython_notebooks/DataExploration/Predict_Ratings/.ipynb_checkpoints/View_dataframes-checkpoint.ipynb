# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_base_dir = '../../../../datasets/Movielens/'
data_dir = data_base_dir + 'serendipity-sac2018/'
data_dir2 = data_base_dir + 'ml-20m/'
output_dir = data_dir + 'output/'

# t1 = 'movies_lemmatized_threshold_0.7_float_movie_genomes_bz2'
# t1 = 'threshold_0.25_float_movie_genomes_bz2'
t1 = 'threshold_0.25_user_full_genome_terms_df_gzip'

target_file = output_dir + t1
target_df = pd.read_pickle(target_file, compression='bz2')
target_df
# Out:
#              007     1920s     1930s     1950s     1960s     1970s     1980s  \
# userId
# 100000  0.011437  0.102563  0.150813  0.335062  0.174000  0.306062  0.293375
# 100001  0.015175  0.085687  0.149100  0.189787  0.075575  0.199125  0.174837
# 100002  0.010396  0.104042  0.167313  0.230313  0.105250  0.230062  0.134646
# 100004  0.023632  0.088706  0.134559  0.221912  0.100721  0.277397  0.246706
# 100005  0.007458  0.138375  0.231708  0.293167  0.143250  0.279875  0.251208
# 100006  0.014917  0.101167  0.213750  0.224417  0.055833  0.341417  0.273583
# 100007  0.011437  0.102563  0.150813  0.335062  0.174000  0.306062  0.293375
# 100008  0.011437  0.094563  0.163562  0.408500  0.213687  0.327000  0.274625
# 100009  0.000000  0.132750  0.199750  0.525250  0.250750  0.318750  0.189750
# 100010  0.045375  0.104125  0.227875  0.186500  0.057250  0.357000  0.517000
# 100011  0.025750  0.064989  0.103693  0.160852  0.081477  0.168205  0.117455
# ...

# %%
target_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92849 entries, 100000 to 206985
# Columns: 702 entries, 007 to zombie
# dtypes: float64(702)
# memory usage: 498.0 MB

# %%
from sklearn.metrics import pairwise_distances

distances = pairwise_distances()
