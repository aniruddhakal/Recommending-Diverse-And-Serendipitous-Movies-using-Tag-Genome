# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt

data_base_dir = '../../datasets/Movielens/'
data_dir2 = data_base_dir + 'Movielens Latest/ml-latest/'
data_dir = data_base_dir + 'ml-20m/'

genome_scores = data_dir + 'genome-scores.csv'
genome_tags = data_dir + 'genome-tags.csv'
movies = data_dir + 'movies.csv'
ratings = data_dir + 'ratings.csv'
tags = data_dir + 'tags.csv'

# %%
genome_tags_df = pd.read_csv(genome_tags)
genome_tags_df
# Out:
#       tagId                 tag
# 0         1                 007
# 1         2        007 (series)
# 2         3        18th century
# 3         4               1920s
# 4         5               1930s
# 5         6               1950s
# 6         7               1960s
# 7         8               1970s
# 8         9               1980s
# 9        10        19th century
# 10       11                  3d
# 11       12                70mm
# 12       13                 80s
# 13       14                9/11
# 14       15             aardman
# 15       16     aardman studios
# 16       17            abortion
# 17       18              absurd
# 18       19              action
# 19       20       action packed
# 20       21          adaptation
# 21       22   adapted from:book
# 22       23  adapted from:comic
# 23       24   adapted from:game
# 24       25           addiction
# 25       26         adolescence
# 26       27            adoption
# 27       28            adultery
# 28       29           adventure
# 29       30        affectionate
# ...     ...                 ...
# 1098   1099       waste of time
# 1099   1100   watch the credits
# 1100   1101             weapons
# 1101   1102             wedding
# 1102   1103                weed
# 1103   1104               weird
# 1104   1105            werewolf
# 1105   1106          werewolves
# 1106   1107             western
# 1107   1108           whimsical
# 1108   1109          wilderness
# 1109   1110                wine
# 1110   1111             wistful
# 1111   1112               witch
# 1112   1113             witches
# 1113   1114               witty
# 1114   1115             wizards
# 1115   1116               women
# 1116   1117       working class
# 1117   1118           workplace
# 1118   1119      world politics
# 1119   1120         world war i
# 1120   1121        world war ii
# 1121   1122       writer's life
# 1122   1123             writers
# 1123   1124             writing
# 1124   1125               wuxia
# 1125   1126                wwii
# 1126   1127              zombie
# 1127   1128             zombies
#
# [1128 rows x 2 columns]

# %%
# stemmed_word = 'ser'


# def map_stemmed_word(x, stemmed_word):
#     x = x.split()
    
#     for w in x:
#         w1 = w.replace("(", "")
#         w1 = w1.replace(")", "")
        
#         if w1.startswith(stemmed_word):
#             return True

#     return False

# # match_condition = genome_tags_df.apply(lambda x: x['tag'].find(stemmed_word) >= 0, axis=1)
# match_condition = genome_tags_df.apply(lambda x: map_stemmed_word(x['tag'], stemmed_word), axis=1)
# genome_tags_df[match_condition]

# %%
# genome_scores_df.loc[:, ['tag']].apply(lambda x: x['tag'], axis=1)
# genome_scores_df[genome_scores_df['tag']['tag'].endswith('s')]
stemming_phrases = ['ies', 's']
stemming_dict = {}

def map_stemmed_word(x, stemmed_word):
    x = x.split()

    for w in x:
        w1 = w.replace("(", "")
        w1 = w1.replace(")", "")

        if w1.startswith(stemmed_word):
            return True

    return False


for sp in stemming_phrases:
    ending_with_s_condition = genome_tags_df.apply(lambda x: x['tag'].endswith(sp), axis=1).values

    candidate_words = genome_tags_df[ending_with_s_condition]['tag'].values

    for w in candidate_words:
        stemmed_word = w[:-len(sp)]
        
        if(len(stemmed_word) > 2):
            match_condition = genome_tags_df.apply(lambda x: map_stemmed_word(x['tag'], stemmed_word), axis=1)

            mapped_list = genome_tags_df[match_condition]['tag'].values.tolist()
        
            if len(mapped_list) > 0:
                stemming_dict[stemmed_word] = genome_tags_df[match_condition]['tag'].values.tolist()
        
stemming_dict

# genome_scores_df['tag']
# x
# Out:
# {'ser': ['007 (series)', 'secret service', 'serial killer', 'series'],
#  'zomb': ['zombie', 'zombies'],
#  '1920': ['1920s'],
#  '1930': ['1930s'],
#  '1950': ['1950s'],
#  '1960': ['1960s'],
#  '1970': ['1970s'],
#  '1980': ['1980s'],
#  'aid': ['aids'],
#  'alien': ['alien', 'alien invasion', 'aliens'],
#  'android': ['android(s)/cyborg(s)', 'androids'],
#  'animal': ['animal movie', 'animals', 'talking animals'],
#  'assassin': ['assassin', 'assassination', 'assassins'],
#  'astronaut': ['astronauts'],
#  'beatle': ['beatles'],
#  'bird': ['birds'],
#  'blindnes': ['blindness'],
#  'bomb': ['bombs', 'nuclear bomb'],
#  'book': ['based on a book',
#   'based on book',
#   'book',
#   'book was better',
#   'books',
#   'comic book',
#   'comic book adaption'],
#  'brother': ['brothers', 'coen brothers', 'marx brothers'],
#  'busines': ['business', 'movie business', 'music business'],
#  'car': ['car chase', 'carrie-anne moss', 'cars', 'cartoon', 'classic car'],
#  'ches': ['chess'],
#  'christma': ['christmas'],
#  'circu': ['circus'],
#  'clone': ['clones'],
#  'clown': ['clowns'],
#  'comic': ['based on a comic',
#   'based on comic',
#   'comic',
#   'comic book',
#   'comic book adaption',
#   'comics',
#   'dc comics'],
#  'computer': ['computer animation', 'computer game', 'computers'],
#  'cyborg': ['cyborgs'],
#  'demon': ['demons'],
#  'dinosaur': ['dinosaurs'],
#  'doctor': ['doctors'],
#  'dog': ['dog', 'dogs'],
#  'dolphin': ['dolphins'],
#  'dragon': ['dragon', 'dragons'],
#  'dream': ['dreamlike', 'dreams', 'dreamworks'],
#  'dreamwork': ['dreamworks'],
#  'drug': ['drug abuse', 'drug addiction', 'drugs'],
#  'effect': ['effects',
#   'oscar (best effects - visual effects)',
#   'saturn award (best special effects)',
#   'special effects'],
#  'explosion': ['explosions'],
#  'flashback': ['flashbacks'],
#  'gang': ['gangs', 'gangster', 'gangsters'],
#  'gangster': ['gangster', 'gangsters'],
#  'geek': ['geek', 'geeks'],
#  'genetic': ['genetics'],
#  'geniu': ['genius'],
#  'ghost': ['ghosts', 'ghosts/afterlife'],
#  'gun': ['gunfight', 'guns'],
#  'hacker': ['hackers'],
#  'hilariou': ['hilarious'],
#  'hillariou': ['hillarious'],
#  'homeles': ['homeless'],
#  'horse': ['horses'],
#  'humorou': ['humorous'],
#  'immigrant': ['immigrants'],
#  'indian': ['indiana jones', 'indians'],
#  'jesu': ['jesus'],
#  'jew': ['jewish', 'jews'],
#  'kid': ['kidnapping', 'kids', 'kids and family'],
#  'lawyer': ['lawyer', 'lawyers'],
#  'lion': ['lions'],
#  'lonelines': ['loneliness'],
#  'mar': ['marijuana',
#   'marriage',
#   'mars',
#   'martial arts',
#   'marvel',
#   'marx brothers'],
#  'mathematic': ['mathematics'],
#  'metaphysic': ['metaphysics'],
#  'monster': ['monster', 'monsters'],
#  'muppet': ['muppets'],
#  'musician': ['musicians'],
#  'mutant': ['mutants'],
#  'nazi': ['nazi', 'nazis'],
#  'neo-nazi': ['neo-nazis'],
#  'nerd': ['nerds'],
#  'olympic': ['olympics'],
#  'ominou': ['ominous'],
#  'orphan': ['orphans'],
#  'pari': ['paris'],
#  'penguin': ['penguins'],
#  'pig': ['pigs'],
#  'pirate': ['pirates'],
#  'pointles': ['pointless'],
#  'politic': ['political',
#   'political corruption',
#   'politics',
#   'world politics'],
#  'pretentiou': ['pretentious'],
#  'puppet': ['puppets'],
#  'rabbit': ['rabbits'],
#  'rat': ['rats'],
#  'relationship': ['father daughter relationship',
#   'father son relationship',
#   'father-son relationship',
#   'mother daughter relationship',
#   'mother-son relationship',
#   'relationships'],
#  'ridiculou': ['ridiculous'],
#  'robot': ['giant robots', 'robot', 'robots'],
#  'secret': ['secret service', 'secrets'],
#  'sequel': ['bad sequel', 'crappy sequel', 'good sequel', 'sequel', 'sequels'],
#  'serie': ['007 (series)', 'series'],
#  'sister': ['sisters'],
#  'slacker': ['slackers'],
#  'snake': ['snakes'],
#  'spider': ['spiders'],
#  'spie': ['spielberg', 'spies'],
#  'sport': ['sports'],
#  'stereotype': ['stereotypes'],
#  'stripper': ['strippers'],
#  'superheroe': ['superheroes'],
#  'teenager': ['teenager', 'teenagers'],
#  'teen': ['teen', 'teen movie', 'teenager', 'teenagers', 'teens'],
#  'texa': ['texas'],
#  'toy': ['toys'],
#  'train': ['train', 'trains'],
#  'vampire': ['vampire', 'vampire human love', 'vampires'],
#  'viru': ['virus'],
#  'visual': ['oscar (best effects - visual effects)',
#   'visual',
#   'visually appealing',
#   'visually stunning',
#   'visuals'],
#  'weapon': ['weapons'],
#  'werewolve': ['werewolves'],
#  'wildernes': ['wilderness'],
#  'witche': ['witches'],
#  'wizard': ['wizards'],
#  'writer': ["writer's life", 'writers'],
#  'zombie': ['zombie', 'zombies']}

# %%
# only keeping keys with 
print(len(stemming_dict))
stemming_dict = {k: v for k, v in stemming_dict.items() if len(v) > 1}
print(len(stemming_dict))
stemming_dict

#TODO
# Out:
# 116
# 44
# {'ser': ['007 (series)', 'secret service', 'serial killer', 'series'],
#  'zomb': ['zombie', 'zombies'],
#  'alien': ['alien', 'alien invasion', 'aliens'],
#  'android': ['android(s)/cyborg(s)', 'androids'],
#  'animal': ['animal movie', 'animals', 'talking animals'],
#  'assassin': ['assassin', 'assassination', 'assassins'],
#  'bomb': ['bombs', 'nuclear bomb'],
#  'book': ['based on a book',
#   'based on book',
#   'book',
#   'book was better',
#   'books',
#   'comic book',
#   'comic book adaption'],
#  'brother': ['brothers', 'coen brothers', 'marx brothers'],
#  'busines': ['business', 'movie business', 'music business'],
#  'car': ['car chase', 'carrie-anne moss', 'cars', 'cartoon', 'classic car'],
#  'comic': ['based on a comic',
#   'based on comic',
#   'comic',
#   'comic book',
#   'comic book adaption',
#   'comics',
#   'dc comics'],
#  'computer': ['computer animation', 'computer game', 'computers'],
#  'dog': ['dog', 'dogs'],
#  'dragon': ['dragon', 'dragons'],
#  'dream': ['dreamlike', 'dreams', 'dreamworks'],
#  'drug': ['drug abuse', 'drug addiction', 'drugs'],
#  'effect': ['effects',
#   'oscar (best effects - visual effects)',
#   'saturn award (best special effects)',
#   'special effects'],
#  'gang': ['gangs', 'gangster', 'gangsters'],
#  'gangster': ['gangster', 'gangsters'],
#  'geek': ['geek', 'geeks'],
#  'ghost': ['ghosts', 'ghosts/afterlife'],
#  'gun': ['gunfight', 'guns'],
#  'indian': ['indiana jones', 'indians'],
#  'jew': ['jewish', 'jews'],
#  'kid': ['kidnapping', 'kids', 'kids and family'],
#  'lawyer': ['lawyer', 'lawyers'],
#  'mar': ['marijuana',
#   'marriage',
#   'mars',
#   'martial arts',
#   'marvel',
#   'marx brothers'],
#  'monster': ['monster', 'monsters'],
#  'nazi': ['nazi', 'nazis'],
#  'politic': ['political',
#   'political corruption',
#   'politics',
#   'world politics'],
#  'relationship': ['father daughter relationship',
#   'father son relationship',
#   'father-son relationship',
#   'mother daughter relationship',
#   'mother-son relationship',
#   'relationships'],
#  'robot': ['giant robots', 'robot', 'robots'],
#  'secret': ['secret service', 'secrets'],
#  'sequel': ['bad sequel', 'crappy sequel', 'good sequel', 'sequel', 'sequels'],
#  'serie': ['007 (series)', 'series'],
#  'spie': ['spielberg', 'spies'],
#  'teenager': ['teenager', 'teenagers'],
#  'teen': ['teen', 'teen movie', 'teenager', 'teenagers', 'teens'],
#  'train': ['train', 'trains'],
#  'vampire': ['vampire', 'vampire human love', 'vampires'],
#  'visual': ['oscar (best effects - visual effects)',
#   'visual',
#   'visually appealing',
#   'visually stunning',
#   'visuals'],
#  'writer': ["writer's life", 'writers'],
#  'zombie': ['zombie', 'zombies']}

# %%
stemming_dict
stem_dict = stemming_dict

value_list = list(stem_dict.values())

# value = 'gangster'
# 'based on book' in stem_dict.values()
# remove 
for l in value_list:
    for w in l:
        w = w.replace("(", "")
        w = w.replace(")", "")
        
        if w in stem_dict:
            del stem_dict[w]
            
print(len(stem_dict))
stem_dict
# Out:
# 25
# {'ser': ['007 (series)', 'secret service', 'serial killer', 'series'],
#  'zomb': ['zombie', 'zombies'],
#  'android': ['android(s)/cyborg(s)', 'androids'],
#  'animal': ['animal movie', 'animals', 'talking animals'],
#  'bomb': ['bombs', 'nuclear bomb'],
#  'brother': ['brothers', 'coen brothers', 'marx brothers'],
#  'busines': ['business', 'movie business', 'music business'],
#  'car': ['car chase', 'carrie-anne moss', 'cars', 'cartoon', 'classic car'],
#  'computer': ['computer animation', 'computer game', 'computers'],
#  'dream': ['dreamlike', 'dreams', 'dreamworks'],
#  'drug': ['drug abuse', 'drug addiction', 'drugs'],
#  'effect': ['effects',
#   'oscar (best effects - visual effects)',
#   'saturn award (best special effects)',
#   'special effects'],
#  'gang': ['gangs', 'gangster', 'gangsters'],
#  'ghost': ['ghosts', 'ghosts/afterlife'],
#  'gun': ['gunfight', 'guns'],
#  'indian': ['indiana jones', 'indians'],
#  'jew': ['jewish', 'jews'],
#  'kid': ['kidnapping', 'kids', 'kids and family'],
#  'mar': ['marijuana',
#   'marriage',
#   'mars',
#   'martial arts',
#   'marvel',
#   'marx brothers'],
#  'politic': ['political',
#   'political corruption',
#   'politics',
#   'world politics'],
#  'relationship': ['father daughter relationship',
#   'father son relationship',
#   'father-son relationship',
#   'mother daughter relationship',
#   'mother-son relationship',
#   'relationships'],
#  'secret': ['secret service', 'secrets'],
#  'serie': ['007 (series)', 'series'],
#  'spie': ['spielberg', 'spies'],
#  'writer': ["writer's life", 'writers']}

# %%
# TODO apply similar value mapping for remaining values
    # all values from dictionary
all_dict_values = list()
for l in list(stemming_dict.values()):
    #     for v in l:
    all_dict_values.extend(l)

all_dict_values = np.array(all_dict_values)
all_tags = genome_tags_df['tag'].values

# difference
remaining_tags = np.setdiff1d(all_tags, all_dict_values)

#TODO remove or keep
remaining_tags = all_tags

# TODO now apply similar value mapping for remaining tags
new_stemming_dict = {}

for stemmed_word in remaining_tags:
    match_condition = genome_tags_df.apply(lambda x: map_stemmed_word(x['tag'], stemmed_word), axis=1)
    mapped_list = genome_tags_df[match_condition]['tag'].values.tolist()

    if len(mapped_list) > 0:
        new_stemming_dict[stemmed_word] = mapped_list

new_stemming_dict
# Out:
# {'007': ['007', '007 (series)'],
#  '1920s': ['1920s'],
#  '1930s': ['1930s'],
#  '1950s': ['1950s'],
#  '1960s': ['1960s'],
#  '1970s': ['1970s'],
#  '1980s': ['1980s'],
#  '3d': ['3d'],
#  '70mm': ['70mm'],
#  '80s': ['80s'],
#  '9/11': ['9/11'],
#  'aardman': ['aardman', 'aardman studios'],
#  'abortion': ['abortion'],
#  'absurd': ['absurd'],
#  'action': ['action',
#   'action packed',
#   'dynamic cgi action',
#   'good action',
#   'realistic action'],
#  'adaptation': ['adaptation', 'literary adaptation', 'video game adaptation'],
#  'addiction': ['addiction', 'drug addiction'],
#  'adolescence': ['adolescence'],
#  'adoption': ['adoption'],
#  'adultery': ['adultery'],
#  'adventure': ['adventure'],
#  'affectionate': ['affectionate'],
#  'africa': ['africa', 'south africa'],
#  'afterlife': ['afterlife'],
#  'aging': ['aging'],
#  'aids': ['aids'],
#  'airplane': ['airplane'],
#  'airport': ['airport'],
#  'alaska': ['alaska'],
#  'alcatraz': ['alcatraz'],
#  'alcoholism': ['alcoholism'],
#  'alien': ['alien', 'alien invasion', 'aliens'],
#  'aliens': ['aliens'],
#  'allegory': ['allegory'],
#  'almodovar': ['almodovar'],
#  'amnesia': ['amnesia'],
#  'androids': ['android(s)/cyborg(s)', 'androids'],
#  'animals': ['animals', 'talking animals'],
#  'animated': ['animated',
#   'disney animated feature',
#   'oscar (best animated feature)'],
#  'animation': ['animation', 'computer animation', 'pixar animation'],
#  'anime': ['anime'],
#  'antarctica': ['antarctica'],
#  'anti-hero': ['anti-hero'],
#  'anti-semitism': ['anti-semitism'],
#  'anti-war': ['anti-war'],
#  'apocalypse': ['apocalypse'],
#  'archaeology': ['archaeology'],
#  'argentina': ['argentina'],
#  'arnold': ['arnold'],
#  'art': ['art',
#   'art house',
#   'artificial intelligence',
#   'artist',
#   'artistic',
#   'artsy',
#   'con artists',
#   'king arthur',
#   'martial arts'],
#  'artist': ['artist', 'artistic', 'con artists'],
#  'artistic': ['artistic'],
#  'artsy': ['artsy'],
#  'assassin': ['assassin', 'assassination', 'assassins'],
#  'assassination': ['assassination'],
#  'assassins': ['assassins'],
#  'astronauts': ['astronauts'],
#  'atheism': ['atheism'],
#  'atmospheric': ['atmospheric'],
#  'australia': ['australia', 'australian'],
#  'australian': ['australian'],
#  'autism': ['autism'],
#  'aviation': ['aviation'],
#  'awesome': ['awesome', 'awesome soundtrack'],
#  'awful': ['awful'],
#  'bad': ['bad',
#   'bad acting',
#   'bad cgi',
#   'bad ending',
#   'bad plot',
#   'bad science',
#   'bad script',
#   'bad sequel',
#   "so bad it's funny",
#   "so bad it's good"],
#  'ballet': ['ballet'],
#  'baseball': ['baseball'],
#  'basketball': ['basketball'],
#  'batman': ['batman'],
#  'bdsm': ['bdsm'],
#  'beatles': ['beatles'],
#  'beautiful': ['beautiful', 'beautiful scenery', 'beautifully filmed'],
#  'beer': ['beer'],
#  'berlin': ['berlin'],
#  'betrayal': ['betrayal'],
#  'biblical': ['biblical'],
#  'biographical': ['biographical'],
#  'biography': ['biography'],
#  'biopic': ['biopic'],
#  'birds': ['birds'],
#  'biting': ['biting'],
#  'bittersweet': ['bittersweet'],
#  'bizarre': ['bizarre'],
#  'blaxploitation': ['blaxploitation'],
#  'bleak': ['bleak'],
#  'blindness': ['blindness'],
#  'blood': ['blood', 'bloody'],
#  'bloody': ['bloody'],
#  'boat': ['boat'],
#  'bollywood': ['bollywood'],
#  'bombs': ['bombs'],
#  'bond': ['bond', 'family bonds', 'james bond'],
#  'book': ['based on a book',
#   'based on book',
#   'book',
#   'book was better',
#   'books',
#   'comic book',
#   'comic book adaption'],
#  'books': ['books'],
#  'boring': ['boring', 'boring!'],
#  'boring!': ['boring!'],
#  'boston': ['boston'],
#  'bowling': ['bowling'],
#  'boxing': ['boxing'],
#  'brainwashing': ['brainwashing'],
#  'brazil': ['brazil'],
#  'breathtaking': ['breathtaking'],
#  'brilliant': ['brilliant'],
#  'british': ['british', 'british comedy'],
#  'broadway': ['broadway'],
#  'brothers': ['brothers', 'coen brothers', 'marx brothers'],
#  'brutal': ['brutal', 'brutality'],
#  'brutality': ['brutality'],
#  'bullying': ['bullying'],
#  'business': ['business', 'movie business', 'music business'],
#  'california': ['california'],
#  'camp': ['camp', 'campy'],
#  'campy': ['campy'],
#  'canada': ['canada'],
#  'cancer': ['cancer'],
#  'cannibalism': ['cannibalism'],
#  'caper': ['caper'],
#  'capitalism': ['capitalism'],
#  'cars': ['cars'],
#  'cartoon': ['cartoon'],
#  'casino': ['casino'],
#  'catastrophe': ['catastrophe'],
#  'cathartic': ['cathartic'],
#  'catholicism': ['catholicism'],
#  'censorship': ['censorship'],
#  'cerebral': ['cerebral'],
#  'cgi': ['bad cgi', 'cgi', 'dynamic cgi action'],
#  'chase': ['car chase', 'chase'],
#  'cheating': ['cheating'],
#  'cheerleading': ['cheerleading'],
#  'cheesy': ['cheesy'],
#  'chess': ['chess'],
#  'chicago': ['chicago'],
#  'childhood': ['childhood'],
#  'children': ['children'],
#  'china': ['china'],
#  'chocolate': ['chocolate'],
#  'christian': ['christian', 'christianity'],
#  'christianity': ['christianity'],
#  'christmas': ['christmas'],
#  'cia': ['cia'],
#  'cinematography': ['amazing cinematography',
#   'cinematography',
#   'great cinematography',
#   'oscar (best cinematography)'],
#  'circus': ['circus'],
#  'classic': ['classic', 'classic car', 'classical music', 'cult classic'],
#  'claustrophobic': ['claustrophobic'],
#  'claymation': ['claymation'],
#  'clever': ['clever', 'suprisingly clever'],
#  'clones': ['clones'],
#  'cloning': ['cloning'],
#  'clowns': ['clowns'],
#  'college': ['college'],
#  'colonialism': ['colonialism'],
#  'colourful': ['colourful'],
#  'comedy': ['black comedy',
#   'british comedy',
#   'comedy',
#   'dark comedy',
#   'off-beat comedy',
#   'romantic comedy',
#   'screwball comedy',
#   'sex comedy',
#   'stand-up comedy'],
#  'comic': ['based on a comic',
#   'based on comic',
#   'comic',
#   'comic book',
#   'comic book adaption',
#   'comics',
#   'dc comics'],
#  'comics': ['comics', 'dc comics'],
#  'coming-of-age': ['coming-of-age'],
#  'communism': ['communism'],
#  'compassionate': ['compassionate'],
#  'competition': ['competition'],
#  'complex': ['complex', 'complex characters'],
#  'complicated': ['complicated', 'complicated plot'],
#  'computers': ['computers'],
#  'confrontational': ['confrontational'],
#  'confusing': ['confusing'],
#  'conspiracy': ['conspiracy', 'conspiracy theory'],
#  'controversial': ['controversial'],
#  'cooking': ['cooking'],
#  'cool': ['cool'],
#  'corny': ['corny'],
#  'corruption': ['corruption', 'police corruption', 'political corruption'],
#  'courage': ['courage'],
#  'court': ['court', 'courtroom', 'courtroom drama'],
#  'courtroom': ['courtroom', 'courtroom drama'],
#  'crazy': ['crazy'],
#  'creativity': ['creativity'],
#  'creepy': ['creepy'],
#  'crime': ['crime', 'crime gone awry', 'organized crime'],
#  'criterion': ['criterion'],
#  'cuba': ['cuba'],
#  'cult': ['cult', 'cult classic', 'cult film', 'culture clash', 'scifi cult'],
#  'cute': ['cute', 'cute!'],
#  'cute!': ['cute!'],
#  'cyberpunk': ['cyberpunk'],
#  'cyborgs': ['cyborgs'],
#  'cynical': ['cynical'],
#  'dance': ['dance'],
#  'dancing': ['dancing'],
#  'dark': ['dark', 'dark comedy', 'dark fantasy', 'dark hero', 'dark humor'],
#  'deadpan': ['deadpan'],
#  'death': ['death', 'death penalty', 'life & death'],
#  'demons': ['demons'],
#  'depressing': ['depressing'],
#  'depression': ['depression'],
#  'desert': ['desert'],
#  'destiny': ['destiny'],
#  'detective': ['detective', 'private detective'],
#  'devil': ['devil'],
#  'dialogue': ['dialogue',
#   'dialogue driven',
#   'entirely dialogue',
#   'good dialogue',
#   'great dialogue',
#   'no dialogue'],
#  'dinosaurs': ['dinosaurs'],
#  'disability': ['disability'],
#  'disappointing': ['disappointing'],
#  'disaster': ['disaster', 'natural disaster'],
#  'disney': ['disney', 'disney animated feature'],
#  'distopia': ['distopia'],
#  'disturbing': ['disturbing'],
#  'divorce': ['divorce'],
#  'doctors': ['doctors'],
#  'documentary': ['documentary', 'fake documentary'],
#  'dog': ['dog', 'dogs'],
#  'dogs': ['dogs'],
#  'dolphins': ['dolphins'],
#  'downbeat': ['downbeat'],
#  'dragon': ['dragon', 'dragons'],
#  'dragons': ['dragons'],
#  'drama': ['costume drama',
#   'courtroom drama',
#   'drama',
#   'dramatic',
#   'family drama'],
#  'dramatic': ['dramatic'],
#  'dreamlike': ['dreamlike'],
#  'dreams': ['dreams'],
#  'dreamworks': ['dreamworks'],
#  'drinking': ['drinking'],
#  'drugs': ['drugs'],
#  'dumb': ['dumb', 'dumb but funny'],
#  'dystopia': ['dystopia'],
#  'earnest': ['earnest'],
#  'eccentricity': ['eccentricity'],
#  'ecology': ['ecology'],
#  'educational': ['educational'],
#  'eerie': ['eerie'],
#  'effects': ['effects',
#   'oscar (best effects - visual effects)',
#   'saturn award (best special effects)',
#   'special effects'],
#  'egypt': ['egypt'],
#  'emotional': ['emotional'],
#  'england': ['england'],
#  'enigmatic': ['enigmatic'],
#  'entertaining': ['entertaining'],
#  'environment': ['environment', 'environmental'],
#  'environmental': ['environmental'],
#  'epic': ['epic'],
#  'erotic': ['erotic'],
#  'espionage': ['espionage'],
#  'evolution': ['evolution'],
#  'excellent': ['excellent', 'excellent script'],
#  'exciting': ['exciting'],
#  'existentialism': ['existentialism'],
#  'explosions': ['explosions'],
#  'factual': ['factual'],
#  'family': ['dysfunctional family',
#   'family',
#   'family bonds',
#   'family drama',
#   'kids and family'],
#  'fantasy': ['dark fantasy',
#   'fantasy',
#   'fantasy world',
#   'high fantasy',
#   'modern fantasy'],
#  'farce': ['farce'],
#  'fascism': ['fascism'],
#  'fashion': ['fashion'],
#  'fbi': ['fbi'],
#  'feel-good': ['feel-good'],
#  'fighting': ['fighting', 'fighting the system', 'sword fighting'],
#  'finnish': ['finnish'],
#  'firefly': ['firefly'],
#  'fish': ['fish'],
#  'flashbacks': ['flashbacks'],
#  'food': ['food'],
#  'football': ['football'],
#  'forceful': ['forceful'],
#  'foreign': ['foreign', 'oscar (best foreign language film)'],
#  'france': ['france'],
#  'franchise': ['franchise'],
#  'freedom': ['freedom'],
#  'french': ['french'],
#  'friendship': ['friendship', 'unlikely friendships'],
#  'frightening': ['frightening'],
#  'fun': ['dumb but funny',
#   'fun',
#   'fun movie',
#   'funniest movies',
#   'funny',
#   'funny as hell',
#   'not funny',
#   'silly fun',
#   "so bad it's funny",
#   'unintentionally funny',
#   'very funny'],
#  'funny': ['dumb but funny',
#   'funny',
#   'funny as hell',
#   'not funny',
#   "so bad it's funny",
#   'unintentionally funny',
#   'very funny'],
#  'future': ['dystopic future', 'future'],
#  'futuristic': ['futuristic'],
#  'gambling': ['gambling'],
#  'gangs': ['gangs', 'gangster', 'gangsters'],
#  'gangster': ['gangster', 'gangsters'],
#  'gangsters': ['gangsters'],
#  'gay': ['gay', 'gay character'],
#  'geek': ['geek', 'geeks'],
#  'geeks': ['geeks'],
#  'genetics': ['genetics'],
#  'genius': ['genius'],
#  'genocide': ['genocide'],
#  'german': ['east germany', 'german', 'germany'],
#  'germany': ['east germany', 'germany'],
#  'ghosts': ['ghosts', 'ghosts/afterlife'],
#  'ghosts/afterlife': ['ghosts/afterlife'],
#  'gilliam': ['gilliam'],
#  'glbt': ['glbt'],
#  'god': ['god', 'mission from god'],
#  'golf': ['golf'],
#  'good': ['feel good movie',
#   'good',
#   'good acting',
#   'good action',
#   'good dialogue',
#   'good music',
#   'good romantic comedies',
#   'good sequel',
#   'good soundtrack',
#   'good story',
#   'good versus evil',
#   'not as good as the first',
#   'sad but good',
#   "so bad it's good",
#   'very good'],
#  'goofy': ['goofy'],
#  'gore': ['gore', 'goretastic'],
#  'goretastic': ['goretastic'],
#  'gory': ['gory'],
#  'goth': ['goth', 'gothic'],
#  'gothic': ['gothic'],
#  'great': ['great',
#   'great acting',
#   'great cinematography',
#   'great dialogue',
#   'great ending',
#   'great movie',
#   'great music',
#   'great soundtrack'],
#  'greed': ['greed'],
#  'grim': ['grim'],
#  'grindhouse': ['grindhouse'],
#  'gritty': ['gritty'],
#  'gross-out': ['gross-out'],
#  'gruesome': ['gruesome'],
#  'guilt': ['guilt', 'guilty pleasure'],
#  'gunfight': ['gunfight'],
#  'guns': ['guns'],
#  'hackers': ['hackers'],
#  'hacking': ['hacking'],
#  'halloween': ['halloween'],
#  'hallucinatory': ['hallucinatory'],
#  'handycam': ['handycam'],
#  'harsh': ['harsh'],
#  'hawaii': ['hawaii'],
#  'heartbreaking': ['heartbreaking'],
#  'heartwarming': ['heartwarming'],
#  'heist': ['heist'],
#  'heroin': ['heroin', 'heroine', 'heroine in tight suit'],
#  'heroine': ['heroine', 'heroine in tight suit'],
#  'hilarious': ['hilarious'],
#  'hillarious': ['hillarious'],
#  'historical': ['historical'],
#  'history': ['alternate history', 'bullshit history', 'history', 'us history'],
#  'hitchcock': ['hitchcock'],
#  'hitman': ['hitman'],
#  'holiday': ['holiday'],
#  'hollywood': ['hollywood'],
#  'holocaust': ['holocaust'],
#  'homeless': ['homeless'],
#  'homophobia': ['homophobia'],
#  'homosexuality': ['homosexuality'],
#  'honest': ['honest'],
#  'horrible': ['horrible'],
#  'horror': ['horror'],
#  'horses': ['horses'],
#  'hospital': ['hospital', 'mental hospital'],
#  'hostage': ['hostage'],
#  'hotel': ['hotel'],
#  'humanity': ['humanity'],
#  'humor': ['crude humor', 'dark humor', 'humor', 'humorous'],
#  'humorous': ['humorous'],
#  'hunting': ['hunting'],
#  'idealism': ['idealism'],
#  'identity': ['identity', 'mistaken identity'],
#  'idiotic': ['idiotic'],
#  'imagination': ['imagination'],
#  'immigrants': ['immigrants'],
#  'immortality': ['immortality'],
#  'incest': ['incest'],
#  'india': ['india', 'indiana jones', 'indians'],
#  'indians': ['indians'],
#  'indie': ['indie'],
#  'infidelity': ['infidelity'],
#  'insanity': ['insanity'],
#  'inspirational': ['inspirational'],
#  'inspiring': ['inspiring'],
#  'intellectual': ['intellectual'],
#  'intelligent': ['intelligent', 'intelligent sci-fi'],
#  'intense': ['intense'],
#  'interesting': ['interesting', 'very interesting'],
#  'internet': ['internet'],
#  'intimate': ['intimate'],
#  'investigation': ['investigation', 'police investigation'],
#  'iran': ['iran'],
#  'iraq': ['iraq', 'iraq war'],
#  'ireland': ['ireland'],
#  'irish': ['irish', 'irish accent'],
#  'ironic': ['ironic'],
#  'irreverent': ['irreverent'],
#  'islam': ['islam'],
#  'island': ['island'],
#  'isolation': ['isolation'],
#  'israel': ['israel'],
#  'italian': ['italian'],
#  'italy': ['italy'],
#  'japan': ['japan', 'japanese'],
#  'japanese': ['japanese'],
#  'jazz': ['jazz'],
#  'jesus': ['jesus'],
#  'jewish': ['jewish'],
#  'jews': ['jews'],
#  'journalism': ['journalism'],
#  'judaism': ['judaism'],
#  'jungle': ['jungle'],
#  'justice': ['justice'],
#  'kidnapping': ['kidnapping'],
#  'kids': ['kids', 'kids and family'],
#  'kubrick': ['kubrick'],
#  'kurosawa': ['kurosawa'],
#  'lame': ['lame'],
#  'lawyer': ['lawyer', 'lawyers'],
#  'lawyers': ['lawyers'],
#  'lesbian': ['lesbian'],
#  'life': ['life', 'life & death', 'life philosophy', "writer's life"],
#  'light': ['light'],
#  'lions': ['lions'],
#  'literature': ['literature'],
#  'london': ['london'],
#  'loneliness': ['loneliness'],
#  'long': ['enormously long battle scene', 'long', 'too long'],
#  'love': ['love', 'love story', 'love triangles', 'vampire human love'],
#  'lynch': ['lynch'],
#  'lyrical': ['lyrical'],
#  'macabre': ['macabre'],
#  'mafia': ['mafia'],
#  'magic': ['magic', 'magic realism', 'stage magic'],
#  'manipulation': ['manipulation'],
#  'marijuana': ['marijuana'],
#  'marriage': ['marriage'],
#  'mars': ['mars'],
#  'marvel': ['marvel'],
#  'masterpiece': ['masterpiece'],
#  'math': ['math', 'mathematics'],
#  'mathematics': ['mathematics'],
#  'maze': ['maze'],
#  'medieval': ['medieval'],
#  'meditative': ['meditative'],
#  'melancholic': ['melancholic'],
#  'melancholy': ['melancholy'],
#  'memory': ['memory', 'memory loss', 'short-term memory loss'],
#  'mentor': ['mentor'],
#  'metaphysics': ['metaphysics'],
#  'mexico': ['mexico'],
#  'military': ['military'],
#  'mindfuck': ['mindfuck'],
#  'mining': ['mining'],
#  'minnesota': ['minnesota'],
#  'miyazaki': ['miyazaki'],
#  'mob': ['mob'],
#  'mockumentary': ['mockumentary'],
#  'money': ['money'],
#  'monkey': ['monkey'],
#  'monster': ['monster', 'monsters'],
#  'monsters': ['monsters'],
#  'moody': ['moody'],
#  'moon': ['moon'],
#  'morality': ['morality'],
#  'motorcycle': ['motorcycle'],
#  'moving': ['moving'],
#  'mozart': ['mozart'],
#  'mtv': ['mtv'],
#  'mummy': ['mummy'],
#  'muppets': ['muppets'],
#  'murder': ['murder', 'murder mystery'],
#  'music': ['classical music',
#   'good music',
#   'great music',
#   'music',
#   'music business',
#   'musical',
#   'musicians',
#   'oscar (best music - original score)',
#   'oscar (best music - original song)'],
#  'musical': ['musical'],
#  'musicians': ['musicians'],
#  'mutants': ['mutants'],
#  'mystery': ['murder mystery', 'mystery'],
#  'mythology': ['mythology'],
#  'narrated': ['narrated'],
#  'nasa': ['nasa'],
#  'nature': ['nature'],
#  'nazi': ['nazi', 'nazis'],
#  'nazis': ['nazis'],
#  'neo-nazis': ['neo-nazis'],
#  'neo-noir': ['neo-noir'],
#  'nerds': ['nerds'],
#  'ninja': ['ninja'],
#  'nocturnal': ['nocturnal'],
#  'noir': ['film noir', 'noir', 'noir thriller'],
#  'non-linear': ['non-linear'],
#  'nonlinear': ['nonlinear'],
#  'nostalgia': ['nostalgia'],
#  'nostalgic': ['nostalgic'],
#  'nuclear': ['nuclear', 'nuclear bomb', 'nuclear war'],
#  'nudity': ['male nudity',
#   'notable nudity',
#   'nudity',
#   'nudity (full frontal - brief)',
#   'nudity (full frontal - notable)',
#   'nudity (full frontal)',
#   'nudity (rear)',
#   'nudity (topless - brief)',
#   'nudity (topless - notable)',
#   'nudity (topless)'],
#  'obsession': ['obsession'],
#  'ocean': ['ocean'],
#  'office': ['office'],
#  'oil': ['oil'],
#  'olympics': ['olympics'],
#  'ominous': ['ominous'],
#  'opera': ['opera', 'space opera'],
#  'original': ['original',
#   'original plot',
#   'oscar (best music - original score)',
#   'oscar (best music - original song)'],
#  'orphans': ['orphans'],
#  'oscar': ['oscar',
#   'oscar (best actor)',
#   'oscar (best actress)',
#   'oscar (best animated feature)',
#   'oscar (best cinematography)',
#   'oscar (best directing)',
#   'oscar (best editing)',
#   'oscar (best effects - visual effects)',
#   'oscar (best foreign language film)',
#   'oscar (best music - original score)',
#   'oscar (best music - original song)',
#   'oscar (best picture)',
#   'oscar (best sound)',
#   'oscar (best supporting actor)',
#   'oscar (best supporting actress)',
#   'oscar (best writing - screenplay written directly for the screen)',
#   'oscar winner',
#   'potential oscar nom'],
#  'overrated': ['overrated'],
#  'palestine': ['palestine'],
#  'paranoia': ['paranoia'],
#  'paranoid': ['paranoid'],
#  'parenthood': ['parenthood'],
#  'paris': ['paris'],
#  'parody': ['parody'],
#  'passionate': ['passionate'],
#  'penguins': ['penguins'],
#  'perfect': ['perfect'],
#  'pg': ['pg', 'pg-13'],
#  'pg-13': ['pg-13'],
#  'philosophical': ['philosophical'],
#  'philosophy': ['life philosophy', 'philosophy'],
#  'photographer': ['photographer'],
#  'photography': ['amazing photography', 'photography'],
#  'pigs': ['pigs'],
#  'pirates': ['pirates'],
#  'pixar': ['pixar', 'pixar animation'],
#  'plot': ['bad plot',
#   'complicated plot',
#   'no plot',
#   'original plot',
#   'plot',
#   'plot holes',
#   'plot twist',
#   'unusual plot structure'],
#  'poetry': ['poetry'],
#  'poignant': ['poignant'],
#  'pointless': ['pointless'],
#  'poker': ['poker'],
#  'poland': ['poland'],
#  'police': ['police', 'police corruption', 'police investigation'],
#  'political': ['political', 'political corruption'],
#  'politics': ['politics', 'world politics'],
#  'pornography': ['pornography'],
#  'post-apocalyptic': ['post-apocalyptic'],
#  'poverty': ['poverty'],
#  'predictable': ['predictable'],
#  'pregnancy': ['pregnancy'],
#  'prejudice': ['prejudice'],
#  'prequel': ['prequel'],
#  'president': ['president'],
#  'pretentious': ['pretentious'],
#  'prison': ['prison', 'prison escape'],
#  'prohibition': ['prohibition'],
#  'propaganda': ['propaganda'],
#  'prostitution': ['prostitution'],
#  'psychedelic': ['psychedelic'],
#  'psychiatrist': ['psychiatrist'],
#  'psychiatry': ['psychiatry'],
#  'psychological': ['psychological'],
#  'psychology': ['psychology'],
#  'pulp': ['pulp'],
#  'punk': ['punk'],
#  'puppets': ['puppets'],
#  'queer': ['queer'],
#  'quirky': ['quirky'],
#  'quotable': ['highly quotable', 'quotable'],
#  'rabbits': ['rabbits'],
#  'race': ['race', 'race issues'],
#  'racing': ['racing'],
#  'racism': ['racism'],
#  'radio': ['radio'],
#  'rape': ['rape'],
#  'rats': ['rats'],
#  'realistic': ['realistic', 'realistic action'],
#  'rebellion': ['rebellion'],
#  'redemption': ['redemption'],
#  'reflective': ['reflective'],
#  'relationships': ['relationships'],
#  'religion': ['religion'],
#  'remade': ['remade'],
#  'remake': ['remake'],
#  'revenge': ['revenge'],
#  'revolution': ['revolution'],
#  'ridiculous': ['ridiculous'],
#  'robbery': ['bank robbery', 'robbery'],
#  'robot': ['giant robots', 'robot', 'robots'],
#  'robots': ['giant robots', 'robots'],
#  'romance': ['interracial romance', 'romance'],
#  'romantic': ['good romantic comedies', 'romantic', 'romantic comedy'],
#  'rome': ['rome'],
#  'runaway': ['runaway'],
#  'russia': ['russia', 'russian'],
#  'russian': ['russian'],
#  'sacrifice': ['sacrifice'],
#  'sad': ['sad', 'sad but good'],
#  'samurai': ['samurai'],
#  'sappy': ['sappy'],
#  'sarcasm': ['sarcasm'],
#  'satire': ['satire'],
#  'satirical': ['satirical'],
#  'scary': ['scary'],
#  'scenic': ['scenic'],
#  'schizophrenia': ['schizophrenia'],
#  'school': ['boarding school', 'high school', 'school'],
#  'sci-fi': ['intelligent sci-fi', 'sci-fi'],
#  'science': ['bad science',
#   'saturn award (best science fiction film)',
#   'science',
#   'science fiction'],
#  'scifi': ['scifi', 'scifi cult'],
#  'scotland': ['scotland'],
#  'screwball': ['screwball', 'screwball comedy'],
#  'script': ['bad script', 'excellent script', 'script'],
#  'secrets': ['secrets'],
#  'segregation': ['segregation'],
#  'sentimental': ['sentimental'],
#  'sequel': ['bad sequel', 'crappy sequel', 'good sequel', 'sequel', 'sequels'],
#  'sequels': ['sequels'],
#  'series': ['007 (series)', 'series'],
#  'sex': ['sex',
#   'sex comedy',
#   'sexual',
#   'sexual abuse',
#   'sexuality',
#   'sexualized violence',
#   'sexy'],
#  'sexual': ['sexual', 'sexual abuse', 'sexuality', 'sexualized violence'],
#  'sexuality': ['sexuality'],
#  'sexy': ['sexy'],
#  'shakespeare': ['shakespeare'],
#  'shallow': ['shallow'],
#  'shark': ['shark'],
#  'shopping': ['shopping'],
#  'short': ['short', 'short-term memory loss', 'too short'],
#  'silent': ['jay and silent bob', 'silent'],
#  'silly': ['silly', 'silly fun'],
#  'simple': ['simple'],
#  'sisters': ['sisters'],
#  'skinhead': ['skinhead'],
#  'slackers': ['slackers'],
#  'slapstick': ['slapstick'],
#  'slasher': ['slasher'],
#  'slavery': ['slavery'],
#  'slow': ['slow', 'slow paced'],
#  'snakes': ['snakes'],
#  'soccer': ['soccer'],
#  'solitude': ['solitude'],
#  'space': ['space', 'space opera', 'space program', 'space travel'],
#  'spain': ['spain'],
#  'spanish': ['spanish', 'spanish civil war'],
#  'special': ['saturn award (best special effects)',
#   'special',
#   'special effects'],
#  'spiders': ['spiders'],
#  'spielberg': ['spielberg'],
#  'spies': ['spies'],
#  'splatter': ['splatter'],
#  'spock': ['spock'],
#  'spoof': ['spoof'],
#  'sports': ['sports'],
#  'spy': ['spy', 'spying'],
#  'spying': ['spying'],
#  'steampunk': ['steampunk'],
#  'stereotypes': ['stereotypes'],
#  'stop-motion': ['stop-motion'],
#  'story': ['based on a true story',
#   'based on true story',
#   'good story',
#   'love story',
#   'multiple storylines',
#   'story',
#   'storytelling',
#   'true story'],
#  'storytelling': ['storytelling'],
#  'stranded': ['stranded'],
#  'strange': ['strange'],
#  'strippers': ['strippers'],
#  'stunning': ['stunning', 'visually stunning'],
#  'stupid': ['stupid', 'stupid as hell', 'stupidity'],
#  'stupidity': ['stupidity'],
#  'stylish': ['stylish'],
#  'stylized': ['stylized'],
#  'submarine': ['submarine'],
#  'suburbia': ['suburbia'],
#  'suicide': ['suicide', 'suicide attempt'],
#  'super-hero': ['super-hero'],
#  'superhero': ['superhero', 'superheroes'],
#  'superheroes': ['superheroes'],
#  'supernatural': ['supernatural'],
#  'surfing': ['surfing'],
#  'surreal': ['surreal', 'surrealism'],
#  'surrealism': ['surrealism'],
#  'surveillance': ['surveillance'],
#  'survival': ['survival'],
#  'suspense': ['suspense', 'suspenseful'],
#  'suspenseful': ['suspenseful'],
#  'swashbuckler': ['swashbuckler'],
#  'swedish': ['swedish'],
#  'sweet': ['sweet'],
#  'talky': ['talky'],
#  'tarantino': ['tarantino'],
#  'teacher': ['teacher'],
#  'technology': ['technology'],
#  'teen': ['teen', 'teen movie', 'teenager', 'teenagers', 'teens'],
#  'teenager': ['teenager', 'teenagers'],
#  'teenagers': ['teenagers'],
#  'teens': ['teens'],
#  'teleportation': ['teleportation'],
#  'television': ['television'],
#  'tense': ['tense'],
#  'terrorism': ['terrorism'],
#  'texas': ['texas'],
#  'thought-provoking': ['thought-provoking'],
#  'thriller': ['noir thriller', 'thriller'],
#  'time': ['time', 'time loop', 'time travel', 'waste of time'],
#  'tokyo': ['tokyo'],
#  'tolkien': ['tolkien'],
#  'torture': ['torture'],
#  'touching': ['touching'],
#  'toys': ['toys'],
#  'tragedy': ['tragedy'],
#  'train': ['train', 'trains'],
#  'trains': ['trains'],
#  'transformation': ['transformation'],
#  'transgender': ['transgender'],
#  'travel': ['space travel', 'time travel', 'travel'],
#  'treasure': ['treasure', 'treasure hunt'],
#  'tricky': ['tricky'],
#  'trilogy': ['trilogy'],
#  'twist': ['plot twist', 'twist', 'twist ending', 'twists & turns'],
#  'underdog': ['underdog'],
#  'underrated': ['underrated'],
#  'understated': ['understated'],
#  'underwater': ['underwater'],
#  'unfunny': ['unfunny'],
#  'unique': ['unique'],
#  'unrealistic': ['unrealistic'],
#  'utopia': ['utopia'],
#  'vampire': ['vampire', 'vampire human love', 'vampires'],
#  'vampires': ['vampires'],
#  'vengeance': ['vengeance'],
#  'videogame': ['videogame'],
#  'vienna': ['vienna'],
#  'vietnam': ['vietnam', 'vietnam war'],
#  'vigilante': ['vigilante'],
#  'vigilantism': ['vigilantism'],
#  'violence': ['gratuitous violence', 'sexualized violence', 'violence'],
#  'violent': ['violent'],
#  'virginity': ['virginity'],
#  'virus': ['virus'],
#  'visceral': ['visceral'],
#  'visual': ['oscar (best effects - visual effects)',
#   'visual',
#   'visually appealing',
#   'visually stunning',
#   'visuals'],
#  'visuals': ['visuals'],
#  'voodoo': ['voodoo'],
#  'voyeurism': ['voyeurism'],
#  'war': ['american civil war',
#   'best war films',
#   'civil war',
#   'cold war',
#   'global warming',
#   'gulf war',
#   'iraq war',
#   'nuclear war',
#   'spanish civil war',
#   'star wars',
#   'vietnam war',
#   'war',
#   'war movie',
#   'wartime',
#   'world war i',
#   'world war ii'],
#  'wartime': ['wartime'],
#  'weapons': ['weapons'],
#  'wedding': ['wedding'],
#  'weed': ['weed'],
#  'weird': ['weird'],
#  'werewolf': ['werewolf'],
#  'werewolves': ['werewolves'],
#  'western': ['spaghetti western', 'western'],
#  'whimsical': ['whimsical'],
#  'wilderness': ['wilderness'],
#  'wine': ['wine'],
#  'wistful': ['wistful'],
#  'witch': ['witch', 'witches'],
#  'witches': ['witches'],
#  'witty': ['witty'],
#  'wizards': ['wizards'],
#  'women': ['kick-butt women', 'women'],
#  'workplace': ['workplace'],
#  'writers': ['writers'],
#  'writing': ['oscar (best writing - screenplay written directly for the screen)',
#   'writing'],
#  'wuxia': ['wuxia'],
#  'wwii': ['wwii'],
#  'zombie': ['zombie', 'zombies'],
#  'zombies': ['zombies']}

# %%
value_list = list(stemming_dict.values())

count = 0

for l in value_list:
    count += len(l)
    
print(count)
# Out:
# 208

# %%
all_values = list()
for l in list(stemming_dict.values()):
#     for v in l:
    all_values.extend(l)
all_values
# Out:
# 208

# %%
len(stemming_dict)
# Out:
# 116

# %%
stemming_dict
# Out:
# {'ser': ['007 (series)', 'secret service', 'serial killer', 'series'],
#  'zomb': ['zombie', 'zombies'],
#  '1920': ['1920s'],
#  '1930': ['1930s'],
#  '1950': ['1950s'],
#  '1960': ['1960s'],
#  '1970': ['1970s'],
#  '1980': ['1980s'],
#  'aid': ['aids'],
#  'alien': ['alien', 'alien invasion', 'aliens'],
#  'android': ['android(s)/cyborg(s)', 'androids'],
#  'animal': ['animal movie', 'animals', 'talking animals'],
#  'assassin': ['assassin', 'assassination', 'assassins'],
#  'astronaut': ['astronauts'],
#  'beatle': ['beatles'],
#  'bird': ['birds'],
#  'blindnes': ['blindness'],
#  'bomb': ['bombs', 'nuclear bomb'],
#  'book': ['based on a book',
#   'based on book',
#   'book',
#   'book was better',
#   'books',
#   'comic book',
#   'comic book adaption'],
#  'brother': ['brothers', 'coen brothers', 'marx brothers'],
#  'busines': ['business', 'movie business', 'music business'],
#  'car': ['car chase', 'carrie-anne moss', 'cars', 'cartoon', 'classic car'],
#  'ches': ['chess'],
#  'christma': ['christmas'],
#  'circu': ['circus'],
#  'clone': ['clones'],
#  'clown': ['clowns'],
#  'comic': ['based on a comic',
#   'based on comic',
#   'comic',
#   'comic book',
#   'comic book adaption',
#   'comics',
#   'dc comics'],
#  'computer': ['computer animation', 'computer game', 'computers'],
#  'cyborg': ['cyborgs'],
#  'demon': ['demons'],
#  'dinosaur': ['dinosaurs'],
#  'doctor': ['doctors'],
#  'dog': ['dog', 'dogs'],
#  'dolphin': ['dolphins'],
#  'dragon': ['dragon', 'dragons'],
#  'dream': ['dreamlike', 'dreams', 'dreamworks'],
#  'dreamwork': ['dreamworks'],
#  'drug': ['drug abuse', 'drug addiction', 'drugs'],
#  'effect': ['effects',
#   'oscar (best effects - visual effects)',
#   'saturn award (best special effects)',
#   'special effects'],
#  'explosion': ['explosions'],
#  'flashback': ['flashbacks'],
#  'gang': ['gangs', 'gangster', 'gangsters'],
#  'gangster': ['gangster', 'gangsters'],
#  'geek': ['geek', 'geeks'],
#  'genetic': ['genetics'],
#  'geniu': ['genius'],
#  'ghost': ['ghosts', 'ghosts/afterlife'],
#  'gun': ['gunfight', 'guns'],
#  'hacker': ['hackers'],
#  'hilariou': ['hilarious'],
#  'hillariou': ['hillarious'],
#  'homeles': ['homeless'],
#  'horse': ['horses'],
#  'humorou': ['humorous'],
#  'immigrant': ['immigrants'],
#  'indian': ['indiana jones', 'indians'],
#  'jesu': ['jesus'],
#  'jew': ['jewish', 'jews'],
#  'kid': ['kidnapping', 'kids', 'kids and family'],
#  'lawyer': ['lawyer', 'lawyers'],
#  'lion': ['lions'],
#  'lonelines': ['loneliness'],
#  'mar': ['marijuana',
#   'marriage',
#   'mars',
#   'martial arts',
#   'marvel',
#   'marx brothers'],
#  'mathematic': ['mathematics'],
#  'metaphysic': ['metaphysics'],
#  'monster': ['monster', 'monsters'],
#  'muppet': ['muppets'],
#  'musician': ['musicians'],
#  'mutant': ['mutants'],
#  'nazi': ['nazi', 'nazis'],
#  'neo-nazi': ['neo-nazis'],
#  'nerd': ['nerds'],
#  'olympic': ['olympics'],
#  'ominou': ['ominous'],
#  'orphan': ['orphans'],
#  'pari': ['paris'],
#  'penguin': ['penguins'],
#  'pig': ['pigs'],
#  'pirate': ['pirates'],
#  'pointles': ['pointless'],
#  'politic': ['political',
#   'political corruption',
#   'politics',
#   'world politics'],
#  'pretentiou': ['pretentious'],
#  'puppet': ['puppets'],
#  'rabbit': ['rabbits'],
#  'rat': ['rats'],
#  'relationship': ['father daughter relationship',
#   'father son relationship',
#   'father-son relationship',
#   'mother daughter relationship',
#   'mother-son relationship',
#   'relationships'],
#  'ridiculou': ['ridiculous'],
#  'robot': ['giant robots', 'robot', 'robots'],
#  'secret': ['secret service', 'secrets'],
#  'sequel': ['bad sequel', 'crappy sequel', 'good sequel', 'sequel', 'sequels'],
#  'serie': ['007 (series)', 'series'],
#  'sister': ['sisters'],
#  'slacker': ['slackers'],
#  'snake': ['snakes'],
#  'spider': ['spiders'],
#  'spie': ['spielberg', 'spies'],
#  'sport': ['sports'],
#  'stereotype': ['stereotypes'],
#  'stripper': ['strippers'],
#  'superheroe': ['superheroes'],
#  'teenager': ['teenager', 'teenagers'],
#  'teen': ['teen', 'teen movie', 'teenager', 'teenagers', 'teens'],
#  'texa': ['texas'],
#  'toy': ['toys'],
#  'train': ['train', 'trains'],
#  'vampire': ['vampire', 'vampire human love', 'vampires'],
#  'viru': ['virus'],
#  'visual': ['oscar (best effects - visual effects)',
#   'visual',
#   'visually appealing',
#   'visually stunning',
#   'visuals'],
#  'weapon': ['weapons'],
#  'werewolve': ['werewolves'],
#  'wildernes': ['wilderness'],
#  'witche': ['witches'],
#  'wizard': ['wizards'],
#  'writer': ["writer's life", 'writers'],
#  'zombie': ['zombie', 'zombies']}

# %%
# remove keys for words that are also present as values completely as same as key

# %%
keys = np.array(list(stemming_dict.keys()))
x = []
i = 0
for the_list in list(stemming_dict.values()):
    x.extend(the_list)
    i += 1

# x
values = np.array(x)

values
# Out:
# array(['007 (series)', 'desert', 'secret service', 'serial killer',
#        'series', 'atmospheric', 'conspiracy', 'conspiracy theory',
#        'espionage', 'free speech', 'hospital', 'inspirational',
#        'inspiring', 'mental hospital',
#        'saturn award (best special effects)', 'shakespeare', 'space',
#        'space opera', 'space program', 'space travel',
#        'spaghetti western', 'spain', 'spanish', 'spanish civil war',
#        'special', 'special effects', 'spelling bee', 'spiders',
#        'spielberg', 'spies', 'splatter', 'spock', 'spoof', 'sports',
#        'spy', 'spying', 'suspense', 'suspenseful', 'zombie', 'zombies',
#        '1980s', '80s', 'alien', 'alien invasion', 'aliens',
#        'android(s)/cyborg(s)', 'androids', 'animal movie', 'animals',
#        'talking animals', 'assassin', 'assassination', 'assassins',
#        'bombs', 'nuclear bomb', 'adapted from:book', 'based on a book',
#        'based on book', 'book', 'book was better', 'books', 'comic book',
#        'comic book adaption', 'brothers', 'coen brothers',
#        'marx brothers', 'business', 'movie business', 'music business',
#        'car chase', 'carrie-anne moss', 'cars', 'cartoon', 'classic car',
#        'oscar', 'oscar (best actor)', 'oscar (best actress)',
#        'oscar (best animated feature)', 'oscar (best cinematography)',
#        'oscar (best directing)', 'oscar (best editing)',
#        'oscar (best effects - visual effects)',
#        'oscar (best foreign language film)',
#        'oscar (best music - original score)',
#        'oscar (best music - original song)', 'oscar (best picture)',
#        'oscar (best sound)', 'oscar (best supporting actor)',
#        'oscar (best supporting actress)',
#        'oscar (best writing - screenplay written directly for the screen)',
#        'oscar winner', 'potential oscar nom', 'scary', 'chess',
#        'rags to riches', 'witches', 'coen bros', 'coen brothers',
#        'adapted from:comic', 'based on a comic', 'based on comic',
#        'comic', 'comic book', 'comic book adaption', 'comics',
#        'dc comics', 'computer animation', 'computer game', 'computers',
#        'android(s)/cyborg(s)', 'cyborgs', 'dog', 'dogs', 'underdog',
#        'dragon', 'dragons', 'dreamlike', 'dreams', 'dreamworks',
#        'drug abuse', 'drug addiction', 'drugs', 'effects',
#        'oscar (best effects - visual effects)',
#        'saturn award (best special effects)', 'special effects',
#        'fairy tale', 'fairy tales', 'gangs', 'gangster', 'gangsters',
#        'gangster', 'gangsters', 'geek', 'geeks', 'ghosts',
#        'ghosts/afterlife', 'gunfight', 'guns', 'indiana jones', 'indians',
#        'jewish', 'jews', 'kidnapping', 'kids', 'kids and family',
#        'lawyer', 'lawyers', 'lions', 'rebellion', 'amy smart',
#        'marijuana', 'marriage', 'mars', 'martial arts', 'marvel',
#        'marx brothers', 'submarine', 'memory loss',
#        'short-term memory loss', 'monster', 'monsters', 'nazi', 'nazis',
#        'neo-nazis', 'political', 'political corruption', 'politics',
#        'world politics', 'corporate america', 'gratuitous violence',
#        'inspirational', 'literature', 'narrated', 'overrated', 'pirates',
#        'rats', 'underrated', 'father daughter relationship',
#        'father son relationship', 'father-son relationship',
#        'mother daughter relationship', 'mother-son relationship',
#        'relationships', 'giant robots', 'robot', 'robots',
#        'secret service', 'secrets', 'bad sequel', 'crappy sequel',
#        'good sequel', 'sequel', 'sequels', '007 (series)', 'series',
#        'saturn award (best special effects)', 'special effects',
#        'spielberg', 'spies', 'teenager', 'teenagers', 'teen',
#        'teen movie', 'teenager', 'teenagers', 'teens', 'train', 'trains',
#        'vampire', 'vampire human love', 'vampires',
#        'based on a video game', 'video game', 'video game adaptation',
#        'video games', 'oscar (best effects - visual effects)', 'visual',
#        'visually appealing', 'visually stunning', 'visuals',
#        "writer's life", 'writers', 'zombie', 'zombies'], dtype='<U65')

# %%
keys.size
# Out:
# 55

# %%
redundant_keys = np.setdiff1d(keys, values)
keys_to_remove = np.setdiff1d(keys, redundant_keys)
keys_to_remove
# Out:
# array(['alien', 'assassin', 'book', 'comic', 'dog', 'dragon',
#        'fairy tale', 'gangster', 'geek', 'lawyer', 'monster', 'nazi',
#        'robot', 'sequel', 'teen', 'teenager', 'train', 'vampire',
#        'video game', 'visual', 'zombie'], dtype='<U14')

# %%
stemming_dict['comic']
# Out:
# ['adapted from:comic',
#  'based on a comic',
#  'based on comic',
#  'comic',
#  'comic book',
#  'comic book adaption',
#  'comics',
#  'dc comics']
